# %% [markdown]
# <a href="https://colab.research.google.com/github/liliansom/API_SindromeGripal/blob/main/Colab_SindromeGripal_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. Definição do Problema

# %% [markdown]
# A realização de notificações de Síndromes Gripais são obrigatórias para todos os casos suspeitos de Covid-19 e devem ser enviadas até 24 horas após a ocorrência de suspeita ou confirmação de doença, agravo ou evento de saúde pública.
#
# Os dados utilizados neste estudo são oriundos do sistema e-SUS NOTIFICA, que foi desenvolvido para registro de casos de Síndrome Gripal suspeitos de Covid-19, e contém dados referentes ao local de residência do paciente (campos: estado, município), independentemente de terem sido notificados em outro estado ou município (Campos: estadoNotificação, municípioNotificação), além de demográficos e clínicos epidemiológicos dos casos.

# %% [markdown]
# ### Questões Principais:<br>
# <li> Quantas são as notificações dos casos de síndrome gripal neste momento: no Brasil e em São Paulo?</li>
#
# ### Questões secundárias:<br>
# <li> Quais são os principais testes para detecção de COVID utilizados no país?</li>
# <li> Quais são os principais sintomas listados na notificação dos casos?</li>
# <li> Está ocorrendo um aumento dos casos de Covid-19 no Brasil?</li>

# %% [markdown]
# ## 2. Obtenção dos Dados
# Iremos realizar a importação das bibliotecas que serão utilizadas e, também, a ingestão da API locada no ElasticSearch com os dados de Notificações de Síndromes Gripais do Brasil.

# %%
import requests
import pandas as pd
import json
import datetime
import matplotlib.pyplot as plt
from datetime import date
from google.colab import drive
import warnings

warnings.filterwarnings('ignore')
drive.mount('/content/drive')
# %matplotlib inline
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# URL com Todos os Estados, /count
url = 'https://elasticsearch-saps.saude.gov.br/desc-esus-notifica-estado-*/_count'
auth = ('user-public-notificacoes', 'Za4qNXdyQNSa9YaA')

# Notificações BR
r_br = requests.get(url, auth=auth)

if r_br.status_code == 200:
    data_br = r_br.json()
else:
    print(f"Erro na solicitação: {r_br.status_code}")

# %%
# URL com estado de SP, /count
url_sp = 'https://elasticsearch-saps.saude.gov.br/desc-esus-notifica-estado-sp/_count'
auth = ('user-public-notificacoes', 'Za4qNXdyQNSa9YaA')

# Notificações SP

r_sp = requests.get(url_sp, auth=auth)

if r_sp.status_code == 200:
    data_sp = r_sp.json()
else:
    print(f"Erro na solicitação: {r_sp.status_code}")

# %%
# Importação BR Sintomas
# URL com Todos os Estados, /search, scroll (sintomas)
url_sint = "https://elasticsearch-saps.saude.gov.br/desc-esus-notifica-estado-*/_search?scroll=1m"

payload = json.dumps({
  "size": 10000,
  "_source": [
    "sintomas"
  ],
  "query": {
    "bool": {
      "filter": {
        "exists": {
          "field": "sintomas"
        }
      }
    }
  }
})
headers = {
  'Authorization': 'Basic dXNlci1wdWJsaWMtbm90aWZpY2Fjb2VzOlphNHFOWGR5UU5TYTlZYUE=',
  'Content-Type': 'application/json'
}

r_sint_br = requests.request("POST", url_sint, headers=headers, data=payload)

if r_sint_br.status_code == 200:
    data_bra = r_sint_br.json()
else:
    print(f"Erro na solicitação: {r_sint_br.status_code}")

# %%
#URL com todos os Estados, /search (testes e diário)
url_testes = "https://elasticsearch-saps.saude.gov.br/desc-esus-notifica-estado-*/_search"

# Importação Testes BR
payload = json.dumps({
  "track_total_hits": True,
  "size": 0,
  "query": {
    "term": {
      "registroAtual": {
        "value": True
      }
    }
  },
  "aggs": {
    "TopTestes": {
      "terms": {
        "field": "testes.tipoTeste.keyword",
        "size": 10
      }
    }
  }
})
headers = {
  'Authorization': 'Basic dXNlci1wdWJsaWMtbm90aWZpY2Fjb2VzOlphNHFOWGR5UU5TYTlZYUE=',
  'Content-Type': 'application/json'
}

r_testes_br = requests.request("POST", url_testes, headers=headers, data=payload)

if r_testes_br.status_code == 200:
    data_testes = r_testes_br.json()
else:
    print(f"Erro na solicitação: {r_testes_br.status_code}")

# %%
#URL com todos os Estados, /search (testes e diário)
url_testes = "https://elasticsearch-saps.saude.gov.br/desc-esus-notifica-estado-*/_search"

# Importação diário BR
payload = json.dumps({
  "track_total_hits": True,
  "size": 0,
  "query": {
    "bool": {
      "filter": [
        {
          "range": {
            "@timestamp": {
              "gte": "2021-08-20T00:00:00Z",
              "lte": "now",
              "time_zone": "-03:00"
            }
          }
        },
        {
          "term": {
            "registroAtual": {
              "value": True
            }
          }
        }
      ]
    }
  },
  "aggs": {
    "AtualizacaoDia": {
      "date_histogram": {
        "field": "@timestamp",
        "interval": "day"
      }
    }
  }
})
headers = {
  'Authorization': 'Basic dXNlci1wdWJsaWMtbm90aWZpY2Fjb2VzOlphNHFOWGR5UU5TYTlZYUE=',
  'Content-Type': 'application/json'
}

r_dia_br = requests.request("GET", url_testes, headers=headers, data=payload)

if r_dia_br.status_code == 200:
    data_dias = r_dia_br.json()
else:
    print(f"Erro na solicitação: {r_dia_br.status_code}")

# %% [markdown]
# ## Etapas 3-5: Exploração, Preparação e Armazenamento dos Dados
# Estas etapas serão realizadas todas em conjunto para que possamos organizar por informação e não por etapas e, com isso, possamos iniciar e terminar cada informação de uma só vez e o leitor possa visualizar e compreender o processo.
#
# De maneira geral, a etapa de exploração é onde iremos explorar os dados e visualizar de que maneira eles estão dispostos.
# Já a etapa de preparação dos dados é quando iremos tratar os dados e transformá-los em um dataframe em que os dados estarão mais fáceis de serem analisados.
#
# Na etapa de armazenamento, iremos guardar a informação tratada para não perdermos a informação e, também, podermos realizar estudos comparatórios (nos casos das notificações diárias, por exemplo, podemos verificar se houve ou não um aumento no número de notificações de um dia para o outro).

# %% [markdown]
# ## Total de notificações

# %% [markdown]
# #### Exploração e Preparação dos Dados

# %%
# Normaliza o objeto JSON para um DataFrame
data_br = pd.json_normalize(data_br)

# %%
# Exibe a mensagem com o total de notificações no Brasil
total_notificacoes = data_br['count'][0]
print(f"O total de notificações no Brasil é de {total_notificacoes}.")
# Out:
# O total de notificações no Brasil é de 127966729.

# %%
# Cria um DataFrame com o valor total de notificações
df_br = pd.DataFrame({'Total de Notificações': [total_notificacoes]})
display(df_br)
#df_br.to_csv('/content/drive/My Drive/ColabNotebooks/GOAT/data/total_sp.csv', index=False)
# Out:
#    Total de Notificações
# 0              127966729

# %%
# Inserindo a data no dataframe
data = date.today().strftime('%Y-%m-%d')

# Cria um DataFrame com o valor total de notificações
df_br = pd.DataFrame({'Total de Notificações BR': [total_notificacoes], 'Data':[data]})
display(df_br)
# Out:
#    Total de Notificações        Data
# 0              127966729  2023-04-19

# %%
# Atualização dos dados em arquivo CSV: neste passo iremos atualizar os novos dados no arquivo CSV existente

# Leitura dos arquivos
notificacoes_br = pd.read_csv('/content/drive/My Drive/Colab Notebooks/API_SindromeGripal/data/total_br.csv')
novas_notif_br = df_br

# Concatenar os DataFrames verticalmente
notificacoes_br = pd.concat([notificacoes_br, novas_notif_br], ignore_index=True)

# Remover linhas duplicadas
notificacoes_br = notificacoes_br.drop_duplicates(subset='Data')
display(notificacoes_br)
notificacoes_br.to_csv('/content/drive/My Drive/Colab Notebooks/API_SindromeGripal/data/total_br.csv', index=False)
# Out:
#    Total de Notificações        Data
# 0              127691318  2023-04-13
# 1              127764417  2023-04-14
# 2              127910687  2023-04-18
# 3              127966061  2023-04-19

# %%
data_sp = pd.json_normalize(data_sp)

# %%
# Exibe a mensagem com o total de notificações em São Paulo
total_notificacoes_sp = data_sp['count'][0]
print(f"O total de notificações no Brasil é de {total_notificacoes_sp}.")
# Out:
# O total de notificações no Brasil é de 37378030.

# %%
# Inserindo a data no dataframe
data = date.today().strftime('%Y-%m-%d')

# Cria um DataFrame com o valor total de notificações
data_sp = pd.DataFrame({'Total de Notificações': [total_notificacoes_sp], 'Data':[data]})
display(data_sp)
# Out:
#    Total de Notificações        Data
# 0               37378030  2023-04-19

# %%
# Atualização dos dados em arquivo CSV: neste passo iremos atualizar os novos dados no arquivo CSV existente

# Leitura dos arquivos
notificacoes_sp = pd.read_csv('/content/drive/My Drive/Colab Notebooks/API_SindromeGripal/data/total_sp.csv')
novas_notif_sp = data_sp

# Concatenar os DataFrames verticalmente
notificacoes_sp = pd.concat([notificacoes_sp, novas_notif_sp], ignore_index=True)

# Remover linhas duplicadas
notificacoes_sp = notificacoes_sp.drop_duplicates(subset='Data')
display(notificacoes_sp)
notificacoes_sp.to_csv('/content/drive/My Drive/Colab Notebooks/API_SindromeGripal/data/total_sp.csv', index=False)
# Out:
#    Total de Notificações        Data
# 0              127966061         NaN
# 1               37377852  2023-04-19

# %% [markdown]
# ## Sintomas

# %% [markdown]
# #### Exploração e Preparação dos Dados

# %%
data_bra
# Out:
# {'_scroll_id': 'FGluY2x1ZGVfY29udGV4dF91dWlkDnF1ZXJ5VGhlbkZldGNoBBZPcERLa3BBUlRYcUp0aUpvZXdaOTdRAAAAAAERZQUWd0h6RldEczFTcmlSYnBTUklla2s1URZzVDc2YkxOYVFiMkVfQ2pDUWtVMklnAAAAAAPC6dYWeGZPSk8tUmFUaEMyb251ZmthbjBnURYweVFqS3pDV1NtSzRRb0tCM3hnemFBAAAAAAE1c_MWWmxsWTg0NkZSSmVkczdZWTJpemZTURZGMTZGT1pBMFRrMnUwOTVpaDNlZmlBAAAAAAT97WwWVTBiRW5JWGhTLWFkQWxFWHZYR1p0UQ==',
#  'took': 3754,
#  'timed_out': False,
#  '_shards': {'total': 4, 'successful': 4, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 127797732, 'relation': 'eq'},
#   'max_score': 0.0,
#   'hits': [{'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'WKgH29dvK3',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'GpsUiKYnVQ',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Febre, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'ma8ykx4vVF',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Febre, Coriza'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'ygCnKMrpa1',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Garganta, Outros, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'ikHE3vNRMP',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Febre, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'mP2whAkW0L',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Dor de Garganta, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '0wuqUIQvUp',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '7gGFwpQaPD',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'lM2JeALNzR',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'Da9aEqnAgB',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'ZSETBC305k',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Febre, Dispneia, Dor de Garganta, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'RpxaLxEq2s',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Febre, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'mXpq3QiHHD',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Febre, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'zYC7omGc8A',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'y7Z6FnQss5',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '7SKO8Jzttj',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça, Febre, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'ZSPGe5dR5Q',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Garganta, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '4Cwhfh8IUR',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'rZDELFqCbN',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Febre, Dor de Garganta, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'eZHPaAiZLV',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'ZrMgiGWKJn',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Dor de Garganta, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'wmR1GLBTgC',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'Arv2B5KTPo',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Dispneia, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '2GVE9KiXuw',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Febre, Dor de Garganta, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'cwdOVDS7vH',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'p8CNB4wVtE',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'X6ooteaFFO',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Febre, Coriza'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'eua1x69uq8',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça, Febre, Dor de Garganta, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'AYetoRff9d',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Febre, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'PvJwvI27iY',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Dor de Garganta, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '89BoyoDF3j',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Febre, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'hNAEG4c6vP',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Distúrbios Olfativos, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'FPJ2Amcx32',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Febre, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'mDHLVTf3gK',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'cp7BVBNfBj',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '88oVhBggN5',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Garganta, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '3nEVa2vjIw',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Dor de Garganta, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'UVnrMLM6B2',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '9rG5z5Nhf6',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'Q1HxV8xB2T',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'rCh8TO9hrf',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Garganta, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'zvHTktCPk8',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'srxftjTYkc',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'bKOHEi5Qvx',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'UBC45SsKhF',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'aGaG0R1Blr',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'ZjduqotR5z',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'JePhXTGMp2',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Dor de Garganta, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '47abyl4K8l',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'DaEQjI3Izp',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'f7yQbLzeYX',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Dor de Garganta, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'D1qHYjGB5D',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Febre, Dispneia'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'zf7wy8azDp',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '2M0aFrYSta',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'ctDgC8X2z0',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Tosse, Febre, Coriza'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'FgiwODTxXX',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'v2In1xpOE9',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Febre, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'LHjsXJEozg',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Distúrbios Olfativos, Dor de Cabeça, Tosse, Febre, Dor de Garganta, Outros, Distúrbios Gustativos'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'c0j9yd3cHO',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '9b6lNOrdK8',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Febre, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'mV2XZpGzqW',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'DRZBx8aYGr',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Febre, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'onPmeVcJ93',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '
',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Tosse, Febre, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'bofb4bB1CX',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Tosse, Dor de Garganta, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'N7dnlSTdrO',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'cV8m3cHyY4',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Distúrbios Gustativos, Dor de Cabeça, Tosse, Dispneia, Dor de Garganta, Distúrbios Olfativos'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '7BQzcOnGbF',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Dispneia'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'jrPW3SoFXj',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Tosse, Febre, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'BtjNDDDxzk',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Febre, Dor de Garganta, Coriza'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'c5f63XAgOx',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'omA91kOSga',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'SHZ5hiNRYW',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Tosse, Dor de Garganta, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'Mxw1YtU0B0',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'my8YEMznir',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Febre, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'yli9qKkfj9',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'TFOn6rz9Eo',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'TTrRMC0fgx',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'AIzd4IV3Pq',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'Wl6e6qAFZo',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Tosse, Febre, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'EHSK9riDXI',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'BzP34UyLAZ',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse, Febre, Dor de Garganta, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'OaUWHlvG7p',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Tosse, Dispneia'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'FCN68hra1P',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Febre, Dor de Garganta, Outros, Coriza'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'ke6OC1ugom',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Febre, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'XaK0YUuCBF',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Garganta, Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'XGvtxka9NX',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Tosse, Febre, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'V8q91gFjSK',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Febre, Tosse, Dor de Garganta, Coriza, Outros, Dispineia, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'ShUjIIQLEw',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'P0uFiJlhSN',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'h5vYMYqR4w',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Distúrbios Olfativos, Distúrbios Gustativos, Dor de Cabeça, Tosse, Dor de Garganta, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'Tmei8vYq4r',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'LvDDL3d5EI',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'kSmqWB4xKZ',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'yZNMiNLGnC',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'Iejy3Imx5S',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Dispneia'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'yoRmOPKaeZ',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'BMbFdCzRpf',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'wO2j68S4PS',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Febre, Dor de Garganta, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'meq0KKpqwI',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'khVvgBtZp6',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse, Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'JUrPan4FOY',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'DiHqcG3jnQ',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'ypraBICkvc',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'HeBjbnOR4m',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'cEkZWjzGIz',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'l2JAkgjLoC',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Garganta, Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'xQy96XZOU4',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'ItOXJab5QH',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Tosse, Febre, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'WmHscC80Ol',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Febre, Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'UXBwHuKNGK',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dispneia, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'ZxAieFCmRK',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Tosse, Febre, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'E4NkzzlX0U',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Tosse, Febre, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'VLhZ50px3f',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Tosse, Febre, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'UF1Sfc8EaG',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'yi4U8Pl59S',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'B0FrbFCG71',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'zxUlnqcKaO',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'fgV8vSExNz',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Distúrbios Olfativos, Tosse, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '0EUXpRShFl',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'T4f4KKVFLP',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '59rs2U2RzR',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Tosse, Febre, Dispneia, Coriza'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'W3lnkJ7LFu',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Dispneia, Dor de Garganta, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'rUBuhW9EzX',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'dJuxftno2F',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '0fCOO5wK8x',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'CpJfGvE9wx',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'ANfD3HJ5Dg',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'VQX66v2AjZ',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '0lj7ew7vOj',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse, Febre, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'grsRWX81QE',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'jE4Cta0p1I',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'wmLpKiV2U5',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'mWUpr00uQc',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Dor de Garganta, Coriza'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'SFanexd4Yc',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'AU08FQZdgF',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'ILSxbentbs',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Dispneia, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'o7EWxtqYV5',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Garganta, Tosse, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'mP1VFIFkjD',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'jUbg1OiIjY',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'GkzAk64Q3X',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'gybovWT8XM',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'NIhIj1zRHw',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dispneia, Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'RDntLsFo4w',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Tosse, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'SDH90aggbq',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Febre, Dor de Garganta, Coriza'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'TbXHDoAWkE',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'dIAUbGB38B',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'lWloH4FgTp',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'AtwEvFI3G2',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Dor de Garganta, Coriza'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'aZ4fzQDUoO',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '5HcS1xMlcm',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'Cd02KNt4wy',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Tosse, Febre, Dispneia'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'S73rBY8Y7W',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Dor de Garganta, Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'CwEgq7tgyn',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Tosse, Febre, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '9hoJR7Onkc',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse, Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'rEGDZcDgqW',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'BGRybZDO2e',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Tosse, Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'J7L3Ewn9WT',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '9DaCrbl9mN',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dispneia, Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'yWwbVCQIxW',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '5sYqpoQ2St',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'VhYWn2rkcj',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Febre, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '0s8iuJqRu3',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'uUABmRTxbi',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Garganta, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'nhbMc5A3HG',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Febre, Coriza'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'vP4ewzKk5A',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '5oUvB129oj',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça'}},
#  ...]

# %%
df_bra = pd.json_normalize(data_bra['hits']['hits'])

# %%
df_bra.columns
# Out:
# Index(['_index', '_type', '_id', '_score', '_source.sintomas'], dtype='object')

# %%
df_bra['_source.sintomas']
# Out:
# 0                                               Tosse
# 1               Coriza, Tosse, Febre, Dor de Garganta
# 2                        Dor de Cabeça, Febre, Coriza
# 3              Dor de Garganta, Outros, Dor de Cabeça
# 4                      Coriza, Febre, Dor de Garganta
#                             ...
# 9995                                    Coriza, Tosse
# 9996                   Coriza, Febre, Dor de Garganta
# 9997                     Coriza, Tosse, Dor de Cabeça
# 9998            Coriza, Tosse, Febre, Dor de Garganta
# 9999    Dor de Cabeça, Febre, Dor de Garganta, Outros
# Name: _source.sintomas, Length: 10000, dtype: object

# %%
# Tratamento do dataframe sintomas

# Separar os valores da coluna 'sintomas'
df_bra['_source.sintomas'] = df_bra['_source.sintomas'].str.split(r',\s|,')

# Transformar a coluna em uma coluna de lista e separá-la em múltiplas linhas
df_bra = df_bra.explode('_source.sintomas')

# %%
# Contagem das informações de sintomas
df_bra['_source.sintomas'].value_counts()
# Out:
# Tosse                    4752
# Coriza                   3778
# Dor de Cabeça            3605
# Dor de Garganta          3218
# Febre                    3183
# Assintomático            2597
# Outros                   1796
# Dispneia                  733
# Distúrbios Gustativos     320
# Distúrbios Olfativos      303
# Dispineia                   2
# Name: _source.sintomas, dtype: int64

# %%
# Tratamento de informações iguais
df_bra['_source.sintomas'] = df_bra['_source.sintomas'].replace({'Dispineia': 'Dispneia'})
df_bra['_source.sintomas'] = df_bra['_source.sintomas'].replace({'Outros: Paciente assintomático': 'Paciente assintomático'})

# %%
df_sintomas = df_bra['_source.sintomas'].value_counts()
df_sintomas = pd.DataFrame(df_sintomas)
df_sintomas = df_sintomas.reset_index()
# Renomeando colunas
df_sintomas = df_sintomas.rename(columns={'_source.sintomas': 'Total', 'index': 'Sintomas'}) 


display(df_sintomas)
# Out:
#                 Sintomas  Total
# 0                  Tosse   4752
# 1                 Coriza   3778
# 2          Dor de Cabeça   3605
# 3        Dor de Garganta   3218
# 4                  Febre   3183
# 5          Assintomático   2597
# 6                 Outros   1796
# 7               Dispneia    735
# 8  Distúrbios Gustativos    320
# 9   Distúrbios Olfativos    303

# %% [markdown]
# #### Armazenamento dos Dados

# %%
# Tratando o dataframe de testes para poder realizar um acompanhamento diário

# Inserindo a data no dataframe
data = date.today().strftime('%Y-%m-%d')
df_sintomas['data'] = data

# Transformando os testes em colunas e os números em linhas
df_sintomas = df_sintomas.pivot(index='data', columns='Sintomas', values='Total')

# Resetando o índice para obter a data como coluna
df_sintomas = df_sintomas.reset_index()

# Renomeando as colunas para o nome dos testes
df_sintomas.columns.name = None
display(df_sintomas)
# Out:
#          data  Assintomático  Coriza  Dispneia  Distúrbios Gustativos  \
# 0  2023-04-19           2597    3778       735                    320
#
#    Distúrbios Olfativos  Dor de Cabeça  Dor de Garganta  Febre  Outros  Tosse
# 0                   303           3605             3218   3183    1796   4752

# %%
 # Atualização dos dados em arquivo CSV: neste passo iremos atualizar os novos dados no arquivo CSV existente

# Leitura dos arquivos
notificacoes_sintomas = pd.read_csv('/content/drive/My Drive/Colab Notebooks/API_SindromeGripal/data/notificacoes_sintomas.csv')
novas_notif_sintomas = df_sintomas

# Concatenar os DataFrames verticalmente
notificacoes_sintomas = pd.concat([notificacoes_sintomas, novas_notif_sintomas], ignore_index=True)

# Remover linhas duplicadas
notificacoes_sintomas = notificacoes_sintomas.drop_duplicates(subset='data')
display(notificacoes_sintomas)
# Out:
#          data  Assintomático  Coriza  Dispneia  Distúrbios Gustativos  \
# 0  2023-04-12           1844    4106       851                    336
# 1  2023-04-13           1752    4129       855                    308
# 2  2023-04-14           3127    3407       709                    260
# 3  2023-04-18           2986    3499       693                    293
# 4  2023-04-19           2668    3866       752                    373
#
#    Distúrbios Olfativos  Dor de Cabeça  Dor de Garganta  Febre  Outros  Tosse
# 0                   311           3970             3430   3456    1964   5307
# 1                   289           3941             3476   3404    2026   5301
# 2                   240           3246             2886   2844    1644   4492
# 3                   265           3357             2908   3041    1668   4539
# 4                   333           3614             3178   3207    1801   4772

# %% [markdown]
# ## Testes

# %% [markdown]
# #### Exploração e Preparação dos Dados

# %%
# Explorando dados testes covid - visualização das colunas
df_testes = pd.json_normalize(data_testes)
df_testes.columns
# Out:
# Index(['took', 'timed_out', '_shards.total', '_shards.successful',
#        '_shards.skipped', '_shards.failed', 'hits.total.value',
#        'hits.total.relation', 'hits.max_score', 'hits.hits',
#        'aggregations.TopTestes.doc_count_error_upper_bound',
#        'aggregations.TopTestes.sum_other_doc_count',
#        'aggregations.TopTestes.buckets'],
#       dtype='object')

# %%
# Explorando e filtrando dados testes covid 
df_buckets = pd.json_normalize(df_testes['aggregations.TopTestes.buckets'])
df_buckets
# Out:
#                                                    0  \
# 0  {'key': 'TESTE RÁPIDO - ANTÍGENO', 'doc_count'...
#
#                                           1  \
# 0  {'key': 'RT-PCR', 'doc_count': 39164394}
#
#                                                    2  \
# 0  {'key': 'TESTE RÁPIDO - ANTICORPO IgG', 'doc_c...
#
#                                                    3  \
# 0  {'key': 'TESTE SOROLÓGICO IgG', 'doc_count': 1...
#
#                                                    4  \
# 0  {'key': 'TESTE SOROLÓGICO IgM', 'doc_count': 1...
#
#                                                    5  \
# 0  {'key': 'TESTE RÁPIDO - ANTICORPO IgM', 'doc_c...
#
#                                                    6  \
# 0  {'key': 'ANTICORPOS TOTAIS', 'doc_count': 455423}
#
#                                         7  \
# 0  {'key': 'RT-LAMP', 'doc_count': 83423}
#
#                                                    8  \
# 0  {'key': 'Imunoensaio por Eletroquimioluminescê...
#
#                                                    9
# 0  {'key': 'Enzimaimunoensaio - ELISA IgM', 'doc_...

# %%
# Transformando dados em dataframe

buckets = df_testes.at[0, 'aggregations.TopTestes.buckets']
df_buckets = pd.DataFrame(columns=['key', 'doc_count'])

# Filtrando dados no dataframe e organizando colunas
for i in range(len(buckets)):
    key_valor = buckets[i]['key']
    doc_count_valor = buckets[i]['doc_count']
    new_row = pd.DataFrame({'key': [key_valor], 'doc_count': [doc_count_valor]})
    df_buckets = pd.concat([df_buckets, new_row], ignore_index=True)

display(df_buckets)
# Out:
#                                                  key doc_count
# 0                            TESTE RÁPIDO - ANTÍGENO  52929959
# 1                                             RT-PCR  39164394
# 2                       TESTE RÁPIDO - ANTICORPO IgG  18466486
# 3                               TESTE SOROLÓGICO IgG   1656445
# 4                               TESTE SOROLÓGICO IgM   1496694
# 5                       TESTE RÁPIDO - ANTICORPO IgM    808335
# 6                                  ANTICORPOS TOTAIS    455423
# 7                                            RT-LAMP     83423
# 8  Imunoensaio por Eletroquimioluminescência - EC...     61566
# 9                      Enzimaimunoensaio - ELISA IgM     47070

# %% [markdown]
# #### Armazenamento dos Dados

# %%
# Tratando o dataframe de testes para poder realizar um acompanhamento diário

# Inserindo a data no dataframe
data = date.today().strftime('%Y-%m-%d')
df_buckets['data'] = data

# Transformando os testes em colunas e os números em linhas
df_buckets = df_buckets.pivot(index='data', columns='key', values='doc_count')

# Resetando o índice para obter a data como coluna
df_buckets = df_buckets.reset_index()

# Renomeando as colunas para o nome dos testes
df_buckets.columns.name = None
display(df_buckets)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'key'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-d785e18e560f> in <cell line: 8>()
#       6
#       7 # Transformando os testes em colunas e os números em linhas
# ----> 8 df_buckets = df_buckets.pivot(index='data', columns='key', values='doc_count')
#       9
#      10 # Resetando o índice para obter a data como coluna
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    8565         from pandas.core.reshape.pivot import pivot
#    8566
# -> 8567         return pivot(self, index=index, columns=columns, values=values)
#    8568
#    8569     _shared_docs[
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/reshape/pivot.py in pivot(data, index, columns, values)
#     523             index_list = [data[idx] for idx in com.convert_to_list_like(index)]
#     524
# --> 525         data_columns = [data[col] for col in columns_listlike]
#     526         index_list.extend(data_columns)
#     527         multiindex = MultiIndex.from_arrays(index_list)
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/reshape/pivot.py in <listcomp>(.0)
#     523             index_list = [data[idx] for idx in com.convert_to_list_like(index)]
#     524
# --> 525         data_columns = [data[col] for col in columns_listlike]
#     526         index_list.extend(data_columns)
#     527         multiindex = MultiIndex.from_arrays(index_list)
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'key'

# %%
# Atualização dos dados em arquivo CSV: neste passo iremos atualizar os novos dados no arquivo CSV existente

# Leitura dos arquivos
notificacoes_testes = pd.read_csv('/content/drive/My Drive/Colab Notebooks/API_SindromeGripal/data/notificacoes_testes.csv')
novas_notif_testes = df_buckets

# Concatenar os DataFrames verticalmente
notificacoes_testes = pd.concat([notificacoes_testes, novas_notif_testes], ignore_index=True)

# Remover linhas duplicadas
notificacoes_testes = notificacoes_testes.drop_duplicates(subset='data')
display(notificacoes_testes)
# Out:
#          data ANTICORPOS TOTAIS Enzimaimunoensaio - ELISA IgM  \
# 0  2023-04-12            454655                         47073
# 1  2023-04-13            454655                         47073
# 2  2023-04-14            454850                         47070
# 3  2023-04-18            455264                         47070
# 4  2023-04-19            455422                         47070
#
#   Imunoensaio por Eletroquimioluminescência - ECLIA IgG RT-LAMP    RT-PCR  \
# 0                                              61566      83148  39118987
# 1                                              61566      83149  39119258
# 2                                              61566      83241  39142189
# 3                                              61566      83392  39154018
# 4                                              61566      83423  39164358
#
#   TESTE RÁPIDO - ANTICORPO IgG TESTE RÁPIDO - ANTICORPO IgM  \
# 0                     18465955                       806350
# 1                     18466039                       806434
# 2                     18466021                       806938
# 3                     18466326                       807914
# 4                     18466485                       808332
#
#   TESTE RÁPIDO - ANTÍGENO TESTE SOROLÓGICO IgG TESTE SOROLÓGICO IgM
# 0                52674896              1656396              1496642
# 1                52676571              1656396              1496642
# 2                52772972              1656421              1496665
# 3                52890049              1656443              1496686
# 4                52929418              1656445              1496694

# %% [markdown]
# ## Verificação diária das Notificações

# %% [markdown]
# #### Exploração e Preparação dos Dados

# %%
# Explorando dados de notificações diárias
data = json.loads(json.dumps(data_dias))
data
# Out:
# {'took': 5,
#  'timed_out': False,
#  '_shards': {'total': 4, 'successful': 4, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 127660817, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []},
#  'aggregations': {'AtualizacaoDia': {'buckets': [{'key_as_string': '2022-11-21T00:00:00.000Z',
#      'key': 1668988800000,
#      'doc_count': 27632213},
#     {'key_as_string': '2022-11-22T00:00:00.000Z',
#      'key': 1669075200000,
#      'doc_count': 85902600},
#     {'key_as_string': '2022-11-23T00:00:00.000Z',
#      'key': 1669161600000,
#      'doc_count': 2731802},
#     {'key_as_string': '2022-11-24T00:00:00.000Z',
#      'key': 1669248000000,
#      'doc_count': 134057},
#     {'key_as_string': '2022-11-25T00:00:00.000Z',
#      'key': 1669334400000,
#      'doc_count': 153670},
#     {'key_as_string': '2022-11-26T00:00:00.000Z',
#      'key': 1669420800000,
#      'doc_count': 29874},
#     {'key_as_string': '2022-11-27T00:00:00.000Z',
#      'key': 1669507200000,
#      'doc_count': 17695},
#     {'key_as_string': '2022-11-28T00:00:00.000Z',
#      'key': 1669593600000,
#      'doc_count': 59590},
#     {'key_as_string': '2022-11-29T00:00:00.000Z',
#      'key': 1669680000000,
#      'doc_count': 94878},
#     {'key_as_string': '2022-11-30T00:00:00.000Z',
#      'key': 1669766400000,
#      'doc_count': 117379},
#     {'key_as_string': '2022-12-01T00:00:00.000Z',
#      'key': 1669852800000,
#      'doc_count': 152764},
#     {'key_as_string': '2022-12-02T00:00:00.000Z',
#      'key': 1669939200000,
#      'doc_count': 133895},
#     {'key_as_string': '2022-12-03T00:00:00.000Z',
#      'key': 1670025600000,
#      'doc_count': 42845},
#     {'key_as_string': '2022-12-04T00:00:00.000Z',
#      'key': 1670112000000,
#      'doc_count': 31593},
#     {'key_as_string': '2022-12-05T00:00:00.000Z',
#      'key': 1670198400000,
#      'doc_count': 130649},
#     {'key_as_string': '2022-12-06T00:00:00.000Z',
#      'key': 1670284800000,
#      'doc_count': 163403},
#     {'key_as_string': '2022-12-07T00:00:00.000Z',
#      'key': 1670371200000,
#      'doc_count': 170674},
#     {'key_as_string': '2022-12-08T00:00:00.000Z',
#      'key': 1670457600000,
#      'doc_count': 145799},
#     {'key_as_string': '2022-12-09T00:00:00.000Z',
#      'key': 1670544000000,
#      'doc_count': 74727},
#     {'key_as_string': '2022-12-10T00:00:00.000Z',
#      'key': 1670630400000,
#      'doc_count': 41553},
#     {'key_as_string': '2022-12-11T00:00:00.000Z',
#      'key': 1670716800000,
#      'doc_count': 25426},
#     {'key_as_string': '2022-12-12T00:00:00.000Z',
#      'key': 1670803200000,
#      'doc_count': 186261},
#     {'key_as_string': '2022-12-13T00:00:00.000Z',
#      'key': 1670889600000,
#      'doc_count': 134690},
#     {'key_as_string': '2022-12-14T00:00:00.000Z',
#      'key': 1670976000000,
#      'doc_count': 158714},
#     {'key_as_string': '2022-12-15T00:00:00.000Z',
#      'key': 1671062400000,
#      'doc_count': 180213},
#     {'key_as_string': '2022-12-16T00:00:00.000Z',
#      'key': 1671148800000,
#      'doc_count': 156054},
#     {'key_as_string': '2022-12-17T00:00:00.000Z',
#      'key': 1671235200000,
#      'doc_count': 40996},
#     {'key_as_string': '2022-12-18T00:00:00.000Z',
#      'key': 1671321600000,
#      'doc_count': 23054},
#     {'key_as_string': '2022-12-19T00:00:00.000Z',
#      'key': 1671408000000,
#      'doc_count': 172758},
#     {'key_as_string': '2022-12-20T00:00:00.000Z',
#      'key': 1671494400000,
#      'doc_count': 163285},
#     {'key_as_string': '2022-12-21T00:00:00.000Z',
#      'key': 1671580800000,
#      'doc_count': 154144},
#     {'key_as_string': '2022-12-22T00:00:00.000Z',
#      'key': 1671667200000,
#      'doc_count': 143215},
#     {'key_as_string': '2022-12-23T00:00:00.000Z',
#      'key': 1671753600000,
#      'doc_count': 99499},
#     {'key_as_string': '2022-12-24T00:00:00.000Z',
#      'key': 1671840000000,
#      'doc_count': 23538},
#     {'key_as_string': '2022-12-25T00:00:00.000Z',
#      'key': 1671926400000,
#      'doc_count': 12617},
#     {'key_as_string': '2022-12-26T00:00:00.000Z',
#      'key': 1672012800000,
#      'doc_count': 129267},
#     {'key_as_string': '2022-12-27T00:00:00.000Z',
#      'key': 1672099200000,
#      'doc_count': 152124},
#     {'key_as_string': '2022-12-28T00:00:00.000Z',
#      'key': 1672185600000,
#      'doc_count': 136230},
#     {'key_as_string': '2022-12-29T00:00:00.000Z',
#      'key': 1672272000000,
#      'doc_count': 119471},
#     {'key_as_string': '2022-12-30T00:00:00.000Z',
#      'key': 1672358400000,
#      'doc_count': 73434},
#     {'key_as_string': '2022-12-31T00:00:00.000Z',
#      'key': 1672444800000,
#      'doc_count': 19305},
#     {'key_as_string': '2023-01-01T00:00:00.000Z',
#      'key': 1672531200000,
#      'doc_count': 9359},
#     {'key_as_string': '2023-01-02T00:00:00.000Z',
#      'key': 1672617600000,
#      'doc_count': 103377},
#     {'key_as_string': '2023-01-03T00:00:00.000Z',
#      'key': 1672704000000,
#      'doc_count': 124449},
#     {'key_as_string': '2023-01-04T00:00:00.000Z',
#      'key': 1672790400000,
#      'doc_count': 128822},
#     {'key_as_string': '2023-01-05T00:00:00.000Z',
#      'key': 1672876800000,
#      'doc_count': 125743},
#     {'key_as_string': '2023-01-06T00:00:00.000Z',
#      'key': 1672963200000,
#      'doc_count': 106982},
#     {'key_as_string': '2023-01-07T00:00:00.000Z',
#      'key': 1673049600000,
#      'doc_count': 27614},
#     {'key_as_string': '2023-01-08T00:00:00.000Z',
#      'key': 1673136000000,
#      'doc_count': 15545},
#     {'key_as_string': '2023-01-09T00:00:00.000Z',
#      'key': 1673222400000,
#      'doc_count': 125973},
#     {'key_as_string': '2023-01-10T00:00:00.000Z',
#      'key': 1673308800000,
#      'doc_count': 115138},
#     {'key_as_string': '2023-01-11T00:00:00.000Z',
#      'key': 1673395200000,
#      'doc_count': 111794},
#     {'key_as_string': '2023-01-12T00:00:00.000Z',
#      'key': 1673481600000,
#      'doc_count': 105627},
#     {'key_as_string': '2023-01-13T00:00:00.000Z',
#      'key': 1673568000000,
#      'doc_count': 96533},
#     {'key_as_string': '2023-01-14T00:00:00.000Z',
#      'key': 1673654400000,
#      'doc_count': 24171},
#     {'key_as_string': '2023-01-15T00:00:00.000Z',
#      'key': 1673740800000,
#      'doc_count': 12119},
#     {'key_as_string': '2023-01-16T00:00:00.000Z',
#      'key': 1673827200000,
#      'doc_count': 105433},
#     {'key_as_string': '2023-01-17T00:00:00.000Z',
#      'key': 1673913600000,
#      'doc_count': 106948},
#     {'key_as_string': '2023-01-18T00:00:00.000Z',
#      'key': 1674000000000,
#      'doc_count': 101340},
#     {'key_as_string': '2023-01-19T00:00:00.000Z',
#      'key': 1674086400000,
#      'doc_count': 101814},
#     {'key_as_string': '2023-01-20T00:00:00.000Z',
#      'key': 1674172800000,
#      'doc_count': 88713},
#     {'key_as_string': '2023-01-21T00:00:00.000Z',
#      'key': 1674259200000,
#      'doc_count': 25188},
#     {'key_as_string': '2023-01-22T00:00:00.000Z',
#      'key': 1674345600000,
#      'doc_count': 14093},
#     {'key_as_string': '2023-01-23T00:00:00.000Z',
#      'key': 1674432000000,
#      'doc_count': 108995},
#     {'key_as_string': '2023-01-24T00:00:00.000Z',
#      'key': 1674518400000,
#      'doc_count': 98558},
#     {'key_as_string': '2023-01-25T00:00:00.000Z',
#      'key': 1674604800000,
#      'doc_count': 93611},
#     {'key_as_string': '2023-01-26T00:00:00.000Z',
#      'key': 1674691200000,
#      'doc_count': 94880},
#     {'key_as_string': '2023-01-27T00:00:00.000Z',
#      'key': 1674777600000,
#      'doc_count': 91377},
#     {'key_as_string': '2023-01-28T00:00:00.000Z',
#      'key': 1674864000000,
#      'doc_count': 26733},
#     {'key_as_string': '2023-01-29T00:00:00.000Z',
#      'key': 1674950400000,
#      'doc_count': 13258},
#     {'key_as_string': '2023-01-30T00:00:00.000Z',
#      'key': 1675036800000,
#      'doc_count': 100563},
#     {'key_as_string': '2023-01-31T00:00:00.000Z',
#      'key': 1675123200000,
#      'doc_count': 91460},
#     {'key_as_string': '2023-02-01T00:00:00.000Z',
#      'key': 1675209600000,
#      'doc_count': 91974},
#     {'key_as_string': '2023-02-02T00:00:00.000Z',
#      'key': 1675296000000,
#      'doc_count': 90850},
#     {'key_as_string': '2023-02-03T00:00:00.000Z',
#      'key': 1675382400000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-04T00:00:00.000Z',
#      'key': 1675468800000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-05T00:00:00.000Z',
#      'key': 1675555200000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-06T00:00:00.000Z',
#      'key': 1675641600000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-07T00:00:00.000Z',
#      'key': 1675728000000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-08T00:00:00.000Z',
#      'key': 1675814400000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-09T00:00:00.000Z',
#      'key': 1675900800000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-10T00:00:00.000Z',
#      'key': 1675987200000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-11T00:00:00.000Z',
#      'key': 1676073600000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-12T00:00:00.000Z',
#      'key': 1676160000000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-13T00:00:00.000Z',
#      'key': 1676246400000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-14T00:00:00.000Z',
#      'key': 1676332800000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-15T00:00:00.000Z',
#      'key': 1676419200000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-16T00:00:00.000Z',
#      'key': 1676505600000,
#      'doc_count': 79316},
#     {'key_as_string': '2023-02-17T00:00:00.000Z',
#      'key': 1676592000000,
#      'doc_count': 83415},
#     {'key_as_string': '2023-02-18T00:00:00.000Z',
#      'key': 1676678400000,
#      'doc_count': 20761},
#     {'key_as_string': '2023-02-19T00:00:00.000Z',
#      'key': 1676764800000,
#      'doc_count': 12766},
#     {'key_as_string': '2023-02-20T00:00:00.000Z',
#      'key': 1676851200000,
#      'doc_count': 22295},
#     {'key_as_string': '2023-02-21T00:00:00.000Z',
#      'key': 1676937600000,
#      'doc_count': 18175},
#     {'key_as_string': '2023-02-22T00:00:00.000Z',
#      'key': 1677024000000,
#      'doc_count': 51254},
#     {'key_as_string': '2023-02-23T00:00:00.000Z',
#      'key': 1677110400000,
#      'doc_count': 122577},
#     {'key_as_string': '2023-02-24T00:00:00.000Z',
#      'key': 1677196800000,
#      'doc_count': 110049},
#     {'key_as_string': '2023-02-25T00:00:00.000Z',
#      'key': 1677283200000,
#      'doc_count': 26979},
#     {'key_as_string': '2023-02-26T00:00:00.000Z',
#      'key': 1677369600000,
#      'doc_count': 34549},
#     {'key_as_string': '2023-02-27T00:00:00.000Z',
#      'key': 1677456000000,
#      'doc_count': 105215},
#     {'key_as_string': '2023-02-28T00:00:00.000Z',
#      'key': 1677542400000,
#      'doc_count': 112079},
#     {'key_as_string': '2023-03-01T00:00:00.000Z',
#      'key': 1677628800000,
#      'doc_count': 111014},
#     {'key_as_string': '2023-03-02T00:00:00.000Z',
#      'key': 1677715200000,
#      'doc_count': 99566},
#     {'key_as_string': '2023-03-03T00:00:00.000Z',
#      'key': 1677801600000,
#      'doc_count': 89234},
#     {'key_as_string': '2023-03-04T00:00:00.000Z',
#      'key': 1677888000000,
#      'doc_count': 39363},
#     {'key_as_string': '2023-03-05T00:00:00.000Z',
#      'key': 1677974400000,
#      'doc_count': 15654},
#     {'key_as_string': '2023-03-06T00:00:00.000Z',
#      'key': 1678060800000,
#      'doc_count': 110675},
#     {'key_as_string': '2023-03-07T00:00:00.000Z',
#      'key': 1678147200000,
#      'doc_count': 110849},
#     {'key_as_string': '2023-03-08T00:00:00.000Z',
#      'key': 1678233600000,
#      'doc_count': 88747},
#     {'key_as_string': '2023-03-09T00:00:00.000Z',
#      'key': 1678320000000,
#      'doc_count': 91871},
#     {'key_as_string': '2023-03-10T00:00:00.000Z',
#      'key': 1678406400000,
#      'doc_count': 99730},
#     {'key_as_string': '2023-03-11T00:00:00.000Z',
#      'key': 1678492800000,
#      'doc_count': 33196},
#     {'key_as_string': '2023-03-12T00:00:00.000Z',
#      'key': 1678579200000,
#      'doc_count': 14369},
#     {'key_as_string': '2023-03-13T00:00:00.000Z',
#      'key': 1678665600000,
#      'doc_count': 114258},
#     {'key_as_string': '2023-03-14T00:00:00.000Z',
#      'key': 1678752000000,
#      'doc_count': 101709},
#     {'key_as_string': '2023-03-15T00:00:00.000Z',
#      'key': 1678838400000,
#      'doc_count': 115060},
#     {'key_as_string': '2023-03-16T00:00:00.000Z',
#      'key': 1678924800000,
#      'doc_count': 108273},
#     {'key_as_string': '2023-03-17T00:00:00.000Z',
#      'key': 1679011200000,
#      'doc_count': 99323},
#     {'key_as_string': '2023-03-18T00:00:00.000Z',
#      'key': 1679097600000,
#      'doc_count': 37789},
#     {'key_as_string': '2023-03-19T00:00:00.000Z',
#      'key': 1679184000000,
#      'doc_count': 33568},
#     {'key_as_string': '2023-03-20T00:00:00.000Z',
#      'key': 1679270400000,
#      'doc_count': 102540},
#     {'key_as_string': '2023-03-21T00:00:00.000Z',
#      'key': 1679356800000,
#      'doc_count': 98420},
#     {'key_as_string': '2023-03-22T00:00:00.000Z',
#      'key': 1679443200000,
#      'doc_count': 116595},
#     {'key_as_string': '2023-03-23T00:00:00.000Z',
#      'key': 1679529600000,
#      'doc_count': 108015},
#     {'key_as_string': '2023-03-24T00:00:00.000Z',
#      'key': 1679616000000,
#      'doc_count': 89247},
#     {'key_as_string': '2023-03-25T00:00:00.000Z',
#      'key': 1679702400000,
#      'doc_count': 27568},
#     {'key_as_string': '2023-03-26T00:00:00.000Z',
#      'key': 1679788800000,
#      'doc_count': 14805},
#     {'key_as_string': '2023-03-27T00:00:00.000Z',
#      'key': 1679875200000,
#      'doc_count': 116653},
#     {'key_as_string': '2023-03-28T00:00:00.000Z',
#      'key': 1679961600000,
#      'doc_count': 112280},
#     {'key_as_string': '2023-03-29T00:00:00.000Z',
#      'key': 1680048000000,
#      'doc_count': 97583},
#     {'key_as_string': '2023-03-30T00:00:00.000Z',
#      'key': 1680134400000,
#      'doc_count': 121984},
#     {'key_as_string': '2023-03-31T00:00:00.000Z',
#      'key': 1680220800000,
#      'doc_count': 83135},
#     {'key_as_string': '2023-04-01T00:00:00.000Z',
#      'key': 1680307200000,
#      'doc_count': 35478},
#     {'key_as_string': '2023-04-02T00:00:00.000Z',
#      'key': 1680393600000,
#      'doc_count': 15623},
#     {'key_as_string': '2023-04-03T00:00:00.000Z',
#      'key': 1680480000000,
#      'doc_count': 98022},
#     {'key_as_string': '2023-04-04T00:00:00.000Z',
#      'key': 1680566400000,
#      'doc_count': 105701},
#     {'key_as_string': '2023-04-05T00:00:00.000Z',
#      'key': 1680652800000,
#      'doc_count': 93306},
#     {'key_as_string': '2023-04-06T00:00:00.000Z',
#      'key': 1680739200000,
#      'doc_count': 58477},
#     {'key_as_string': '2023-04-07T00:00:00.000Z',
#      'key': 1680825600000,
#      'doc_count': 39117},
#     {'key_as_string': '2023-04-08T00:00:00.000Z',
#      'key': 1680912000000,
#      'doc_count': 19937},
#     {'key_as_string': '2023-04-09T00:00:00.000Z',
#      'key': 1680998400000,
#      'doc_count': 11762},
#     {'key_as_string': '2023-04-10T00:00:00.000Z',
#      'key': 1681084800000,
#      'doc_count': 98994},
#     {'key_as_string': '2023-04-11T00:00:00.000Z',
#      'key': 1681171200000,
#      'doc_count': 116351},
#     {'key_as_string': '2023-04-12T00:00:00.000Z',
#      'key': 1681257600000,
#      'doc_count': 96993},
#     {'key_as_string': '2023-04-13T00:00:00.000Z',
#      'key': 1681344000000,
#      'doc_count': 97848},
#     {'key_as_string': '2023-04-14T00:00:00.000Z',
#      'key': 1681430400000,
#      'doc_count': 109960},
#     {'key_as_string': '2023-04-15T00:00:00.000Z',
#      'key': 1681516800000,
#      'doc_count': 29000},
#     {'key_as_string': '2023-04-16T00:00:00.000Z',
#      'key': 1681603200000,
#      'doc_count': 17151},
#     {'key_as_string': '2023-04-17T00:00:00.000Z',
#      'key': 1681689600000,
#      'doc_count': 99902},
#     {'key_as_string': '2023-04-18T00:00:00.000Z',
#      'key': 1681776000000,
#      'doc_count': 100060},
#     {'key_as_string': '2023-04-19T00:00:00.000Z',
#      'key': 1681862400000,
#      'doc_count': 69643}]}}}

# %%
# Explorando e filtrando dados de notificações diárias
df_dias = pd.json_normalize(data['aggregations']['AtualizacaoDia']['buckets'])
df_dias
# Out:
#                 key_as_string            key  doc_count
# 0    2022-11-21T00:00:00.000Z  1668988800000   27632213
# 1    2022-11-22T00:00:00.000Z  1669075200000   85902600
# 2    2022-11-23T00:00:00.000Z  1669161600000    2731802
# 3    2022-11-24T00:00:00.000Z  1669248000000     134057
# 4    2022-11-25T00:00:00.000Z  1669334400000     153670
# ..                        ...            ...        ...
# 145  2023-04-15T00:00:00.000Z  1681516800000      29000
# 146  2023-04-16T00:00:00.000Z  1681603200000      17151
# 147  2023-04-17T00:00:00.000Z  1681689600000      99902
# 148  2023-04-18T00:00:00.000Z  1681776000000     100060
# 149  2023-04-19T00:00:00.000Z  1681862400000      69643
#
# [150 rows x 3 columns]

# %%
# Criando dataframe para quantidade de notificações diárias
dados = []

for i in range(len(df_dias)):
    key_valor = df_dias.iloc[i]['key_as_string']
    doc_count_valor = df_dias.iloc[i]['doc_count']
    dados.append({'Data': key_valor, 'Total de Notificações': doc_count_valor})

df_notificacoes = pd.DataFrame(dados)

# Tratando coluna Data para datetime
df_notificacoes['Data'] = pd.to_datetime(df_notificacoes['Data'])
df_notificacoes['Data'] = df_notificacoes['Data'].dt.strftime('%d-%m-%Y')

display(df_notificacoes)

df_notificacoes.to_csv('/content/drive/My Drive/Colab Notebooks/API_SindromeGripal/data/notificacoes_diarias.csv', index=False)
# Out:
#            Data  Total de Notificações
# 0    21-11-2022               27632213
# 1    22-11-2022               85902600
# 2    23-11-2022                2731802
# 3    24-11-2022                 134057
# 4    25-11-2022                 153670
# ..          ...                    ...
# 145  15-04-2023                  29000
# 146  16-04-2023                  17151
# 147  17-04-2023                  99902
# 148  18-04-2023                 100060
# 149  19-04-2023                  69643
#
# [150 rows x 2 columns]

# %% [markdown]
# #### Armazenamento dos Dados

# %%
# Atualização dos dados em arquivo CSV: neste passo iremos atualizar os novos dados no arquivo CSV existente

# Leitura dos arquivos
notificacoes_diarias = pd.read_csv('/content/drive/My Drive/Colab Notebooks/API_SindromeGripal/data/notificacoes_diarias.csv')
novas_notif = df_notificacoes

# Concatenando os DataFrames
notificacoes_diarias = pd.concat([notificacoes_diarias, novas_notif], ignore_index=True)

# Remover linhas duplicadas
notificacoes_diarias = notificacoes_diarias.drop_duplicates(subset='Data')

# %%
# Salvando as novas informações no arquivo CSV

notificacoes_sintomas.to_csv('/content/drive/My Drive/Colab Notebooks/API_SindromeGripal/data/notificacoes_sintomas.csv', index=False)
notificacoes_testes.to_csv('/content/drive/My Drive/Colab Notebooks/API_SindromeGripal/data/notificacoes_testes.csv', index=False)
notificacoes_diarias.to_csv('/content/drive/My Drive/Colab Notebooks/API_SindromeGripal/data/notificacoes_diarias.csv', index=False)

# %% [markdown]
# #### Plotagem dos Dados

# %%
# Plotagem dos dados de notificações diárias para análise rápida
df_notificacoes.plot(x='Data', y='Total de Notificações', kind='line')
plt.title('Total de Notificações no Brasil por Dia')
# Out:
# Text(0.5, 1.0, 'Total de Notificações no Brasil por Dia')
