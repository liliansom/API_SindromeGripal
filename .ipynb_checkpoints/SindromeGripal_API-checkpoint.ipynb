# %%
import requests
import pandas as pd
import json

# %%
# Total de contagem de notificações no Brasil
url = 'https://elasticsearch-saps.saude.gov.br/desc-esus-notifica-estado-*/_count'
auth = ('user-public-notificacoes', 'Za4qNXdyQNSa9YaA')

response = requests.get(url, auth=auth)

if response.status_code == 200:
    data_br = response.json()
else:
    print(f"Erro na solicitação: {response.status_code}")

# %%
data_br = pd.json_normalize(data_br)

# %%
print(f"O total de notificações no Brasil é de {data_br['count'][0]}.")
# Out:
# O total de notificações no Brasil é de 127250713

# %%
# Total de contagem de notificações no Brasil
url = 'https://elasticsearch-saps.saude.gov.br/desc-esus-notifica-estado-sp/_count'
auth = ('user-public-notificacoes', 'Za4qNXdyQNSa9YaA')

response = requests.get(url, auth=auth)

if response.status_code == 200:
    data_sp = response.json()
else:
    print(f"Erro na solicitação: {response.status_code}")

# %%
data_sp = pd.json_normalize(data_sp)

# %%
print(f"O total de notificações no estado de São Paulo é de {data_sp['count'][0]}.")
# Out:
# O total de notificações no estado de São Paulo é de 37148649.

# %%
url = "https://elasticsearch-saps.saude.gov.br/desc-esus-notifica-estado-*/_search"

payload = json.dumps({
  "size": 10000
})
headers = {
  'Authorization': 'Basic dXNlci1wdWJsaWMtbm90aWZpY2Fjb2VzOlphNHFOWGR5UU5TYTlZYUE=',
  'Content-Type': 'application/json'
}

response = requests.request("POST", url, headers=headers, data=payload)

if response.status_code == 200:
    data_bra = response.json()
else:
    print(f"Erro na solicitação: {response.status_code}")

# %%
data_bra['hits']['hits']
# Out:
# [{'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'O5SO7HXRcz',
#   '_score': 1.0,
#   '_source': {'outrasCondicoes': None,
#    'municipio': 'São José do Rio Preto',
#    'resultadoTesteSorologicoIgM': None,
#    'laboratorioSegundaReforcoDose': None,
#    'dataTesteSorologico': None,
#    'codigoBuscaAtivaAssintomatico': None,
#    'recebeuAntiviral': None,
#    'profissionalSeguranca': 'Não',
#    'cbo': None,
#    'codigoRecebeuAntiviral': None,
#    'municipioNotificacaoIBGE': '3549805',
#    'profissionalSaude': 'Não',
#    'outroTriagemPopulacaoEspecifica': None,
#    'resultadoTeste': None,
#    'classificacaoFinal': 'Descartado',
#    'estadoIBGE': '35',
#    'estadoNotificacaoIBGE': '35',
#    'dataInicioTratamento': None,
#    '@version': '1',
#    'evolucaoCaso': 'Cura',
#    '@timestamp': '2023-04-05T03:40:00.465Z',
#    'municipioIBGE': '3549805',
#    'dataEncerramento': '2023-04-04T03:00:00.000Z',
#    'estado': 'São Paulo',
#    'resultadoTesteSorologicoIgG': None,
#    'dataReforcoDose': None,
#    'tipoTesteSorologico': None,
#    'qualAntiviral': None,
#    'estadoNotificacao': 'São Paulo',
#    'loteSegundaReforcoDose': None,
#    'id': 'O5SO7HXRcz',
#    'outroLocalRealizacaoTestagem': None,
#    'outroBuscaAtivaAssintomatico': None,
#    'dataSegundaReforcoDose': None,
#    'codigoTriagemPopulacaoEspecifica': None,
#    'condicoes': None,
#    'codigoDosesVacina': ['1'],
#    'idCollection': 'O5SO7HXRcz',
#    'estadoTeste': None,
#    'codigoLocalRealizacaoTestagem': '1',
#    'outroAntiviral': None,
#    'dataSegundaDose': None,
#    'codigoContemComunidadeTradicional': '2',
#    'tipoTeste': None,
#    'racaCor': 'Branca',
#    'codigoRecebeuVacina': '1',
#    'dataPrimeiraDose': '2021-11-10T03:00:00.000Z',
#    'dataTeste': None,
#    'registroAtual': True,
#    'dataNotificacao': '2022-07-15T03:00:00.000Z',
#    'dataInicioSintomas': '2022-07-14T03:00:00.000Z',
#    'municipioNotificacao': 'São José do Rio Preto',
#    'testes': [{'codigoEstadoTeste': '3',
#      'tipoTeste': 'TESTE RÁPIDO - ANTÍGENO',
#      'fabricanteTeste': 'INSTITUTO DE BIOLOGIA MOLECULAR DO PARANÁ',
#      'resultadoTeste': 'Não Reagente',
#      'codigoTipoTeste': '3',
#      'codigoFabricanteTeste': '715',
#      'codigoResultadoTeste': '2',
#      'dataColetaTeste': {'__type': 'Date', 'iso': '2022-07-15T03:00:00.000Z'},
#      'loteTeste': '220562Z029',
#      'estadoTeste': 'Concluído'}],
#    'idade': 24,
#    'resultadoTesteSorologicoTotais': None,
#    'codigoEstrategiaCovid': '1',
#    'outrosSintomas': None,
#    'codigoQualAntiviral': None,
#    'estrangeiro': None,
#    'resultadoTesteSorologicoIgA': None,
#    'sexo': 'Masculino',
#    'sintomas': 'Dor de Cabeça, Dor de Garganta, Coriza'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'zbuBI8GdLB',
#   '_score': 1.0,
#   '_source': {'outrasCondicoes': None,
#    'municipio': 'São José do Rio Preto',
#    'resultadoTesteSorologicoIgM': None,
#    'laboratorioSegundaReforcoDose': None,
#    'dataTesteSorologico': None,
#    'codigoBuscaAtivaAssintomatico': None,
#    'recebeuAntiviral': None,
#    'profissionalSeguranca': 'Não',
#    'cbo': None,
#    'codigoRecebeuAntiviral': None,
#    'municipioNotificacaoIBGE': '3549805',
#    'profissionalSaude': 'Não',
#    'outroTriagemPopulacaoEspecifica': None,
#    'resultadoTeste': None,
#    'classificacaoFinal': 'Descartado',
#    'estadoIBGE': '35',
#    'estadoNotificacaoIBGE': '35',
#    'dataInicioTratamento': None,
#    '@version': '1',
#    'evolucaoCaso': 'Cura',
#    '@timestamp': '2023-04-05T03:40:00.465Z',
#    'municipioIBGE': '3549805',
#    'dataEncerramento': '2023-04-04T03:00:00.000Z',
#    'estado': 'São Paulo',
#    'resultadoTesteSorologicoIgG': None,
#    'dataReforcoDose': None,
#    'tipoTesteSorologico': None,
#    'qualAntiviral': None,
#    'estadoNotificacao': 'São Paulo',
#    'loteSegundaReforcoDose': None,
#    'id': 'zbuBI8GdLB',
#    'outroLocalRealizacaoTestagem': None,
#    'outroBuscaAtivaAssintomatico': None,
#    'dataSegundaReforcoDose': None,
#    'codigoTriagemPopulacaoEspecifica': None,
#    'condicoes': None,
#    'codigoDosesVacina': ['1'],
#    'idCollection': 'zbuBI8GdLB',
#    'estadoTeste': None,
#    'codigoLocalRealizacaoTestagem': '1',
#    'outroAntiviral': None,
#    'dataSegundaDose': None,
#    'codigoContemComunidadeTradicional': '2',
#    'tipoTeste': None,
#    'racaCor': 'Parda',
#    'codigoRecebeuVacina': '1',
#    'dataPrimeiraDose': '2021-07-22T03:00:00.000Z',
#    'dataTeste': None,
#    'registroAtual': True,
#    'dataNotificacao': '2022-06-20T03:00:00.000Z',
#    'dataInicioSintomas': '2022-06-17T03:00:00.000Z',
#    'municipioNotificacao': 'São José do Rio Preto',
#    'testes': [{'codigoEstadoTeste': '3',
#      'tipoTeste': 'TESTE RÁPIDO - ANTÍGENO',
#      'fabricanteTeste': 'INSTITUTO DE BIOLOGIA MOLECULAR DO PARANÁ',
#      'resultadoTeste': 'Não Reagente',
#      'codigoTipoTeste': '3',
#      'codigoFabricanteTeste': '715',
#      'codigoResultadoTeste': '2',
#      'dataColetaTeste': {'__type': 'Date', 'iso': '2022-06-20T03:00:00.000Z'},
#      'loteTeste': '210562Z271',
#      'estadoTeste': 'Concluído'}],
#    'idade': 39,
#    'resultadoTesteSorologicoTotais': None,
#    'codigoEstrategiaCovid': '1',
#    'outrosSintomas': None,
#    'codigoQualAntiviral': None,
#    'estrangeiro': None,
#    'resultadoTesteSorologicoIgA': None,
#    'sexo': 'Masculino',
#    'sintomas': 'Dor de Cabeça, Febre, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'KSsSsPOBGT',
#   '_score': 1.0,
#   '_source': {'outrasCondicoes': None,
#    'municipio': 'São Paulo',
#    'resultadoTesteSorologicoIgM': None,
#    'laboratorioSegundaReforcoDose': None,
#    'dataTesteSorologico': None,
#    'codigoBuscaAtivaAssintomatico': None,
#    'recebeuAntiviral': None,
#    'profissionalSeguranca': 'Não',
#    'cbo': None,
#    'codigoRecebeuAntiviral': None,
#    'municipioNotificacaoIBGE': '3530607',
#    'profissionalSaude': 'Não',
#    'outroTriagemPopulacaoEspecifica': None,
#    'resultadoTeste': None,
#    'classificacaoFinal': None,
#    'estadoIBGE': '35',
#    'estadoNotificacaoIBGE': '35',
#    'dataInicioTratamento': None,
#    '@version': '1',
#    'evolucaoCaso': None,
#    '@timestamp': '2023-04-05T03:40:00.466Z',
#    'municipioIBGE': '3550308',
#    'dataEncerramento': None,
#    'estado': 'São Paulo',
#    'resultadoTesteSorologicoIgG': None,
#    'dataReforcoDose': None,
#    'tipoTesteSorologico': None,
#    'qualAntiviral': None,
#    'estadoNotificacao': 'São Paulo',
#    'loteSegundaReforcoDose': None,
#    'id': 'KSsSsPOBGT',
#    'outroLocalRealizacaoTestagem': None,
#    'outroBuscaAtivaAssintomatico': None,
#    'dataSegundaReforcoDose': None,
#    'codigoTriagemPopulacaoEspecifica': None,
#    'condicoes': None,
#    'codigoDosesVacina': [],
#    'idCollection': 'KSsSsPOBGT',
#    'estadoTeste': None,
#    'codigoLocalRealizacaoTestagem': '1',
#    'outroAntiviral': None,
#    'dataSegundaDose': None,
#    'codigoContemComunidadeTradicional': '2',
#    'tipoTeste': None,
#    'racaCor': 'Parda',
#    'codigoRecebeuVacina': '2',
#    'dataPrimeiraDose': None,
#    'dataTeste': None,
#    'registroAtual': True,
#    'dataNotificacao': '2023-04-04T03:00:43.114Z',
#    'dataInicioSintomas': None,
#    'municipioNotificacao': 'Mogi das Cruzes',
#    'testes': [{'codigoEstadoTeste': '3',
#      'tipoTeste': 'TESTE RÁPIDO - ANTÍGENO',
#      'fabricanteTeste': 'OUTRAS MARCAS',
#      'resultadoTeste': 'Não Reagente',
#      'codigoTipoTeste': '3',
#      'codigoFabricanteTeste': '915',
#      'codigoResultadoTeste': '2',
#      'dataColetaTeste': {'__type': 'Date', 'iso': '2023-04-04T03:00:00.000Z'},
#      'loteTeste': None,
#      'estadoTeste': 'Concluído'}],
#    'idade': 51,
#    'resultadoTesteSorologicoTotais': None,
#    'codigoEstrategiaCovid': '1',
#    'outrosSintomas': None,
#    'codigoQualAntiviral': None,
#    'estrangeiro': 'Não',
#    'resultadoTesteSorologicoIgA': None,
#    'sexo': 'Feminino',
#    'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'WVrCAjUIxN',
#   '_score': 1.0,
#   '_source': {'outrasCondicoes': None,
#    'municipio': 'São José do Rio Preto',
#    'resultadoTesteSorologicoIgM': None,
#    'laboratorioSegundaReforcoDose': None,
#    'dataTesteSorologico': None,
#    'codigoBuscaAtivaAssintomatico': None,
#    'recebeuAntiviral': None,
#    'profissionalSeguranca': 'Não',
#    'cbo': None,
#    'codigoRecebeuAntiviral': None,
#    'municipioNotificacaoIBGE': '3549805',
#    'profissionalSaude': 'Não',
#    'outroTriagemPopulacaoEspecifica': None,
#    'resultadoTeste': None,
#    'classificacaoFinal': 'Descartado',
#    'estadoIBGE': '35',
#    'estadoNotificacaoIBGE': '35',
#    'dataInicioTratamento': None,
#    '@version': '1',
#    'evolucaoCaso': 'Cura',
#    '@timestamp': '2023-04-05T03:40:00.466Z',
#    'municipioIBGE': '3549805',
#    'dataEncerramento': '2023-04-04T03:00:00.000Z',
#    'estado': 'São Paulo',
#    'resultadoTesteSorologicoIgG': None,
#    'dataReforcoDose': None,
#    'tipoTesteSorologico': None,
#    'qualAntiviral': None,
#    'estadoNotificacao': 'São Paulo',
#    'loteSegundaReforcoDose': None,
#    'id': 'WVrCAjUIxN',
#    'outroLocalRealizacaoTestagem': None,
#    'outroBuscaAtivaAssintomatico': None,
#    'dataSegundaReforcoDose': None,
#    'codigoTriagemPopulacaoEspecifica': None,
#    'condicoes': None,
#    'codigoDosesVacina': [],
#    'idCollection': 'WVrCAjUIxN',
#    'estadoTeste': None,
#    'codigoLocalRealizacaoTestagem': '1',
#    'outroAntiviral': None,
#    'dataSegundaDose': None,
#    'codigoContemComunidadeTradicional': '2',
#    'tipoTeste': None,
#    'racaCor': 'Branca',
#    'codigoRecebeuVacina': None,
#    'dataPrimeiraDose': None,
#    'dataTeste': None,
#    'registroAtual': True,
#    'dataNotificacao': '2023-01-19T03:00:26.313Z',
#    'dataInicioSintomas': '2023-01-16T03:00:00.000Z',
#    'municipioNotificacao': 'São José do Rio Preto',
#    'testes': [{'codigoEstadoTeste': '3',
#      'tipoTeste': 'TESTE RÁPIDO - ANTÍGENO',
#      'fabricanteTeste': 'BIO-MANGUINHOS/FIOCRUZ',
#      'resultadoTeste': 'Não Reagente',
#      'codigoTipoTeste': '3',
#      'codigoFabricanteTeste': '792',
#      'codigoResultadoTeste': '2',
#      'dataColetaTeste': {'__type': 'Date', 'iso': '2023-01-19T03:00:00.000Z'},
#      'loteTeste': '22KC006Z',
#      'estadoTeste': 'Concluído'}],
#    'idade': 85,
#    'resultadoTesteSorologicoTotais': None,
#    'codigoEstrategiaCovid': '1',
#    'outrosSintomas': 'FALTA DE APETITE, DIARRÉIA, DOR NO CORPO',
#    'codigoQualAntiviral': None,
#    'estrangeiro': None,
#    'resultadoTesteSorologicoIgA': None,
#    'sexo': 'Feminino',
#    'sintomas': 'Dor de Cabeça, Dor de Garganta, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'E8xFhm7HYH',
#   '_score': 1.0,
#   '_source': {'outrasCondicoes': None,
#    'municipio': 'São José do Rio Preto',
#    'resultadoTesteSorologicoIgM': None,
#    'laboratorioSegundaReforcoDose': None,
#    'dataTesteSorologico': None,
#    'codigoBuscaAtivaAssintomatico': None,
#    'recebeuAntiviral': 'Não',
#    'profissionalSeguranca': 'Não',
#    'cbo': None,
#    'codigoRecebeuAntiviral': '2',
#    'municipioNotificacaoIBGE': '3549805',
#    'profissionalSaude': 'Não',
#    'outroTriagemPopulacaoEspecifica': None,
#    'resultadoTeste': None,
#    'classificacaoFinal': None,
#    'estadoIBGE': '35',
#    'estadoNotificacaoIBGE': '35',
#    'dataInicioTratamento': None,
#    '@version': '1',
#    'evolucaoCaso': None,
#    '@timestamp': '2023-04-05T03:40:00.466Z',
#    'municipioIBGE': '3549805',
#    'dataEncerramento': None,
#    'estado': 'São Paulo',
#    'resultadoTesteSorologicoIgG': None,
#    'dataReforcoDose': None,
#    'tipoTesteSorologico': None,
#    'qualAntiviral': None,
#    'estadoNotificacao': 'São Paulo',
#    'loteSegundaReforcoDose': None,
#    'id': 'E8xFhm7HYH',
#    'outroLocalRealizacaoTestagem': None,
#    'outroBuscaAtivaAssintomatico': None,
#    'dataSegundaReforcoDose': None,
#    'codigoTriagemPopulacaoEspecifica': None,
#    'condicoes': None,
#    'codigoDosesVacina': ['1'],
#    'idCollection': 'E8xFhm7HYH',
#    'estadoTeste': None,
#    'codigoLocalRealizacaoTestagem': '1',
#    'outroAntiviral': None,
#    'dataSegundaDose': None,
#    'codigoContemComunidadeTradicional': '2',
#    'tipoTeste': None,
#    'racaCor': 'Branca',
#    'codigoRecebeuVacina': '1',
#    'dataPrimeiraDose': '2021-06-23T03:00:00.000Z',
#    'dataTeste': None,
#    'registroAtual': True,
#    'dataNotificacao': '2023-04-04T03:00:49.722Z',
#    'dataInicioSintomas': '2023-04-03T03:00:00.000Z',
#    'municipioNotificacao': 'São José do Rio Preto',
#    'testes': [{'codigoEstadoTeste': '2',
#      'tipoTeste': 'TESTE RÁPIDO - ANTÍGENO',
#      'fabricanteTeste': None,
#      'resultadoTeste': None,
#      'codigoTipoTeste': '3',
#      'codigoFabricanteTeste': None,
#      'codigoResultadoTeste': None,
#      'dataColetaTeste': {'__type': 'Date', 'iso': '2023-04-04T03:00:00.000Z'},
#      'loteTeste': None,
#      'estadoTeste': 'Coletado'}],
#    'idade': 34,
#    'resultadoTesteSorologicoTotais': None,
#    'codigoEstrategiaCovid': '1',
#    'outrosSintomas': None,
#    'codigoQualAntiviral': None,
#    'estrangeiro': None,
#    'resultadoTesteSorologicoIgA': None,
#    'sexo': 'Masculino',
#    'sintomas': 'Coriza, Tosse, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'xS8Xp4nrj4',
#   '_score': 1.0,
#   '_source': {'outrasCondicoes': 'estavel',
#    'municipio': 'Campo Grande',
#    'resultadoTesteSorologicoIgM': None,
#    'laboratorioSegundaReforcoDose': None,
#    'dataTesteSorologico': None,
#    'codigoBuscaAtivaAssintomatico': None,
#    'recebeuAntiviral': 'Ignorado',
#    'profissionalSeguranca': 'Não',
#    'cbo': None,
#    'codigoRecebeuAntiviral': '3',
#    'municipioNotificacaoIBGE': '4211306',
#    'profissionalSaude': 'Não',
#    'outroTriagemPopulacaoEspecifica': None,
#    'resultadoTeste': None,
#    'classificacaoFinal': 'Síndrome Gripal Não Especificada',
#    'estadoIBGE': '50',
#    'estadoNotificacaoIBGE': '42',
#    'dataInicioTratamento': None,
#    '@version': '1',
#    'evolucaoCaso': 'Cura',
#    '@timestamp': '2023-04-05T03:40:00.467Z',
#    'municipioIBGE': '5002704',
#    'dataEncerramento': '2023-04-04T04:00:00.000Z',
#    'estado': 'Mato Grosso do Sul',
#    'resultadoTesteSorologicoIgG': None,
#    'dataReforcoDose': None,
#    'tipoTesteSorologico': None,
#    'qualAntiviral': None,
#    'estadoNotificacao': 'Santa Catarina',
#    'loteSegundaReforcoDose': None,
#    'id': 'xS8Xp4nrj4',
#    'outroLocalRealizacaoTestagem': None,
#    'outroBuscaAtivaAssintomatico': None,
#    'dataSegundaReforcoDose': None,
#    'codigoTriagemPopulacaoEspecifica': None,
#    'condicoes': 'Outros',
#    'codigoDosesVacina': ['1'],
#    'idCollection': 'xS8Xp4nrj4',
#    'estadoTeste': None,
#    'codigoLocalRealizacaoTestagem': '1',
#    'outroAntiviral': None,
#    'dataSegundaDose': None,
#    'codigoContemComunidadeTradicional': '2',
#    'tipoTeste': None,
#    'racaCor': 'Branca',
#    'codigoRecebeuVacina': '1',
#    'dataPrimeiraDose': '2021-09-28T03:00:00.000Z',
#    'dataTeste': None,
#    'registroAtual': True,
#    'dataNotificacao': '2023-03-28T03:00:33.701Z',
#    'dataInicioSintomas': '2023-03-25T03:00:00.000Z',
#    'municipioNotificacao': 'Navegantes',
#    'testes': [{'codigoEstadoTeste': '3',
#      'tipoTeste': 'TESTE RÁPIDO - ANTÍGENO',
#      'fabricanteTeste': 'OUTRAS MARCAS',
#      'resultadoTeste': 'Não Reagente',
#      'codigoTipoTeste': '3',
#      'codigoFabricanteTeste': '915',
#      'codigoResultadoTeste': '2',
#      'dataColetaTeste': {'__type': 'Date', 'iso': '2023-03-28T03:00:00.000Z'},
#      'loteTeste': 'fmfc20211',
#      'estadoTeste': 'Concluído'}],
#    'idade': 17,
#    'resultadoTesteSorologicoTotais': None,
#    'codigoEstrategiaCovid': '1',
#    'outrosSintomas': None,
#    'codigoQualAntiviral': None,
#    'estrangeiro': None,
#    'resultadoTesteSorologicoIgA': None,
#    'sexo': 'Masculino',
#    'sintomas': 'Coriza, Tosse, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'wpxyuNWVRx',
#   '_score': 1.0,
#   '_source': {'outrasCondicoes': None,
#    'municipio': 'Aguaí',
#    'resultadoTesteSorologicoIgM': None,
#    'laboratorioSegundaReforcoDose': None,
#    'dataTesteSorologico': None,
#    'codigoBuscaAtivaAssintomatico': None,
#    'recebeuAntiviral': 'Ignorado',
#    'profissionalSeguranca': 'Não',
#    'cbo': None,
#    'codigoRecebeuAntiviral': '3',
#    'municipioNotificacaoIBGE': '3500303',
#    'profissionalSaude': 'Não',
#    'outroTriagemPopulacaoEspecifica': None,
#    'resultadoTeste': None,
#    'classificacaoFinal': None,
#    'estadoIBGE': '35',
#    'estadoNotificacaoIBGE': '35',
#    'dataInicioTratamento': None,
#    '@version': '1',
#    'evolucaoCaso': None,
#    '@timestamp': '2023-04-05T03:40:00.458Z',
#    'municipioIBGE': '3500303',
#    'dataEncerramento': None,
#    'estado': 'São Paulo',
#    'resultadoTesteSorologicoIgG': None,
#    'dataReforcoDose': None,
#    'tipoTesteSorologico': None,
#    'qualAntiviral': None,
#    'estadoNotificacao': 'São Paulo',
#    'loteSegundaReforcoDose': None,
#    'id': 'wpxyuNWVRx',
#    'outroLocalRealizacaoTestagem': None,
#    'outroBuscaAtivaAssintomatico': None,
#    'dataSegundaReforcoDose': None,
#    'codigoTriagemPopulacaoEspecifica': None,
#    'condicoes': None,
#    'codigoDosesVacina': [],
#    'idCollection': 'wpxyuNWVRx',
#    'estadoTeste': None,
#    'codigoLocalRealizacaoTestagem': '1',
#    'outroAntiviral': None,
#    'dataSegundaDose': None,
#    'codigoContemComunidadeTradicional': '2',
#    'tipoTeste': None,
#    'racaCor': 'Preta',
#    'codigoRecebeuVacina': None,
#    'dataPrimeiraDose': None,
#    'dataTeste': None,
#    'registroAtual': True,
#    'dataNotificacao': '2023-04-04T03:00:58.926Z',
#    'dataInicioSintomas': '2023-04-03T03:00:00.000Z',
#    'municipioNotificacao': 'Aguaí',
#    'testes': [{'codigoEstadoTeste': '3',
#      'tipoTeste': 'TESTE RÁPIDO - ANTÍGENO',
#      'fabricanteTeste': 'BIO-MANGUINHOS/FIOCRUZ',
#      'resultadoTeste': 'Não Reagente',
#      'codigoTipoTeste': '3',
#      'codigoFabricanteTeste': '792',
#      'codigoResultadoTeste': '2',
#      'dataColetaTeste': {'__type': 'Date', 'iso': '2023-04-04T03:00:00.000Z'},
#      'loteTeste': 'FMFA18211',
#      'estadoTeste': 'Concluído'}],
#    'idade': 12,
#    'resultadoTesteSorologicoTotais': None,
#    'codigoEstrategiaCovid': '1',
#    'outrosSintomas': None,
#    'codigoQualAntiviral': None,
#    'estrangeiro': 'Não',
#    'resultadoTesteSorologicoIgA': None,
#    'sexo': 'Feminino',
#    'sintomas': 'Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'upCGNkKZKI',
#   '_score': 1.0,
#   '_source': {'outrasCondicoes': None,
#    'municipio': 'Campo Grande',
#    'resultadoTesteSorologicoIgM': None,
#    'laboratorioSegundaReforcoDose': None,
#    'dataTesteSorologico': None,
#    'codigoBuscaAtivaAssintomatico': None,
#    'recebeuAntiviral': 'Ignorado',
#    'profissionalSeguranca': 'Não',
#    'cbo': None,
#    'codigoRecebeuAntiviral': '3',
#    'municipioNotificacaoIBGE': '5002704',
#    'profissionalSaude': 'Não',
#    'outroTriagemPopulacaoEspecifica': None,
#    'resultadoTeste': None,
#    'classificacaoFinal': 'Síndrome Gripal Não Especificada',
#    'estadoIBGE': '50',
#    'estadoNotificacaoIBGE': '50',
#    'dataInicioTratamento': None,
#    '@version': '1',
#    'evolucaoCaso': 'Cura',
#    '@timestamp': '2023-04-05T03:40:00.458Z',
#    'municipioIBGE': '5002704',
#    'dataEncerramento': '2023-04-04T04:00:00.000Z',
#    'estado': 'Mato Grosso do Sul',
#    'resultadoTesteSorologicoIgG': None,
#    'dataReforcoDose': None,
#    'tipoTesteSorologico': None,
#    'qualAntiviral': None,
#    'estadoNotificacao': 'Mato Grosso do Sul',
#    'loteSegundaReforcoDose': None,
#    'id': 'upCGNkKZKI',
#    'outroLocalRealizacaoTestagem': None,
#    'outroBuscaAtivaAssintomatico': None,
#    'dataSegundaReforcoDose': None,
#    'codigoTriagemPopulacaoEspecifica': None,
#    'condicoes': None,
#    'codigoDosesVacina': ['1', '2'],
#    'idCollection': 'upCGNkKZKI',
#    'estadoTeste': None,
#    'codigoLocalRealizacaoTestagem': '1',
#    'outroAntiviral': None,
#    'dataSegundaDose': '2021-07-13T04:00:00.000Z',
#    'codigoContemComunidadeTradicional': '2',
#    'tipoTeste': None,
#    'racaCor': 'Branca',
#    'codigoRecebeuVacina': '1',
#    'dataPrimeiraDose': '2021-06-19T04:00:00.000Z',
#    'dataTeste': None,
#    'registroAtual': True,
#    'dataNotificacao': '2023-03-27T04:00:57.763Z',
#    'dataInicioSintomas': '2023-03-21T04:00:00.000Z',
#    'municipioNotificacao': 'Campo Grande',
#    'testes': [{'codigoEstadoTeste': '3',
#      'tipoTeste': 'TESTE RÁPIDO - ANTÍGENO',
#      'fabricanteTeste': 'INSTITUTO DE BIOLOGIA MOLECULAR DO PARANÁ',
#      'resultadoTeste': 'Não Reagente',
#      'codigoTipoTeste': '3',
#      'codigoFabricanteTeste': '715',
#      'codigoResultadoTeste': '2',
#      'dataColetaTeste': {'__type': 'Date', 'iso': '2023-03-24T04:00:00.000Z'},
#      'loteTeste': '220562Z122',
#      'estadoTeste': 'Concluído'}],
#    'idade': 50,
#    'resultadoTesteSorologicoTotais': None,
#    'codigoEstrategiaCovid': '1',
#    'outrosSintomas': None,
#    'codigoQualAntiviral': None,
#    'estrangeiro': None,
#    'resultadoTesteSorologicoIgA': None,
#    'sexo': 'Feminino',
#    'sintomas': 'Coriza, Dor de Cabeça, Tosse, Dispneia, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'AxoqfoQTWR',
#   '_score': 1.0,
#   '_source': {'outrasCondicoes': None,
#    'municipio': 'Castanhal',
#    'resultadoTesteSorologicoIgM': None,
#    'laboratorioSegundaReforcoDose': 'ASTRAZENECA/FIOCRUZ',
#    'dataTesteSorologico': None,
#    'codigoBuscaAtivaAssintomatico': '4',
#    'recebeuAntiviral': 'Não',
#    'profissionalSeguranca': 'Não',
#    'cbo': None,
#    'codigoRecebeuAntiviral': '2',
#    'municipioNotificacaoIBGE': '1502400',
#    'profissionalSaude': 'Não',
#    'outroTriagemPopulacaoEspecifica': None,
#    'resultadoTeste': None,
#    'classificacaoFinal': None,
#    'estadoIBGE': '15',
#    'estadoNotificacaoIBGE': '15',
#    'dataInicioTratamento': None,
#    '@version': '1',
#    'evolucaoCaso': None,
#    '@timestamp': '2023-04-05T03:40:00.459Z',
#    'municipioIBGE': '1502400',
#    'dataEncerramento': None,
#    'estado': 'Pará',
#    'resultadoTesteSorologicoIgG': None,
#    'dataReforcoDose': '2022-01-21T03:00:00.000Z',
#    'tipoTesteSorologico': None,
#    'qualAntiviral': None,
#    'estadoNotificacao': 'Pará',
#    'loteSegundaReforcoDose': '222VCD054Z',
#    'id': 'AxoqfoQTWR',
#    'outroLocalRealizacaoTestagem': None,
#    'outroBuscaAtivaAssintomatico': 'transferencia',
#    'dataSegundaReforcoDose': '2022-09-27T03:00:00.000Z',
#    'codigoTriagemPopulacaoEspecifica': None,
#    'condicoes': None,
#    'codigoDosesVacina': ['1', '2', '3', '4'],
#    'idCollection': 'AxoqfoQTWR',
#    'estadoTeste': None,
#    'codigoLocalRealizacaoTestagem': '1',
#    'outroAntiviral': None,
#    'dataSegundaDose': None,
#    'codigoContemComunidadeTradicional': '2',
#    'tipoTeste': None,
#    'racaCor': 'Parda',
#    'codigoRecebeuVacina': '1',
#    'dataPrimeiraDose': '2021-06-10T03:00:00.000Z',
#    'dataTeste': None,
#    'registroAtual': True,
#    'dataNotificacao': '2023-04-04T03:00:34.403Z',
#    'dataInicioSintomas': None,
#    'municipioNotificacao': 'Castanhal',
#    'testes': [{'codigoEstadoTeste': '3',
#      'tipoTeste': 'TESTE RÁPIDO - ANTÍGENO',
#      'fabricanteTeste': 'BIO-MANGUINHOS/FIOCRUZ',
#      'resultadoTeste': 'Não Reagente',
#      'codigoTipoTeste': '3',
#      'codigoFabricanteTeste': '792',
#      'codigoResultadoTeste': '2',
#      'dataColetaTeste': {'__type': 'Date', 'iso': '2023-04-04T03:00:00.000Z'},
#      'loteTeste': '224kdo42z',
#      'estadoTeste': 'Concluído'}],
#    'idade': 42,
#    'resultadoTesteSorologicoTotais': None,
#    'codigoEstrategiaCovid': '2',
#    'outrosSintomas': None,
#    'codigoQualAntiviral': None,
#    'estrangeiro': None,
#    'resultadoTesteSorologicoIgA': None,
#    'sexo': 'Feminino',
#    'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'f5NHG90dJp',
#   '_score': 1.0,
#   '_source': {'outrasCondicoes': None,
#    'municipio': 'Cotia',
#    'resultadoTesteSorologicoIgM': None,
#    'laboratorioSegundaReforcoDose': 'ASTRAZENECA/FIOCRUZ',
#    'dataTesteSorologico': None,
#    'codigoBuscaAtivaAssintomatico': None,
#    'recebeuAntiviral': 'Não',
#    'profissionalSeguranca': 'Não',
#    'cbo': None,
#    'codigoRecebeuAntiviral': '2',
#    'municipioNotificacaoIBGE': '3513009',
#    'profissionalSaude': 'Não',
#    'outroTriagemPopulacaoEspecifica': None,
#    'resultadoTeste': None,
#    'classificacaoFinal': None,
#    'estadoIBGE': '35',
#    'estadoNotificacaoIBGE': '35',
#    'dataInicioTratamento': None,
#    '@version': '1',
#    'evolucaoCaso': None,
#    '@timestamp': '2023-04-05T03:40:00.459Z',
#    'municipioIBGE': '3513009',
#    'dataEncerramento': None,
#    'estado': 'São Paulo',
#    'resultadoTesteSorologicoIgG': None,
#    'dataReforcoDose': '2022-05-23T03:00:00.000Z',
#    'tipoTesteSorologico': None,
#    'qualAntiviral': None,
#    'estadoNotificacao': 'São Paulo',
#    'loteSegundaReforcoDose': '222VCD048Z',
#    'id': 'f5NHG90dJp',
#    'outroLocalRealizacaoTestagem': None,
#    'outroBuscaAtivaAssintomatico': None,
#    'dataSegundaReforcoDose': '2022-10-05T03:00:00.000Z',
#    'codigoTriagemPopulacaoEspecifica': '1',
#    'condicoes': None,
#    'codigoDosesVacina': ['1', '2', '3', '4'],
#    'idCollection': 'f5NHG90dJp',
#    'estadoTeste': None,
#    'codigoLocalRealizacaoTestagem': '1',
#    'outroAntiviral': None,
#    'dataSegundaDose': '2021-08-19T03:00:00.000Z',
#    'codigoContemComunidadeTradicional': '2',
#    'tipoTeste': None,
#    'racaCor': 'Parda',
#    'codigoRecebeuVacina': '1',
#    'dataPrimeiraDose': '2021-07-23T03:00:00.000Z',
#    'dataTeste': None,
#    'registroAtual': True,
#    'dataNotificacao': '2023-04-04T03:00:15.723Z',
#    'dataInicioSintomas': '2023-04-04T03:00:00.000Z',
#    'municipioNotificacao': 'Cotia',
#    'testes': [{'codigoEstadoTeste': '3',
#      'tipoTeste': 'TESTE RÁPIDO - ANTÍGENO',
#      'fabricanteTeste': 'OUTRAS MARCAS',
#      'resultadoTeste': 'Reagente',
#      'codigoTipoTeste': '3',
#      'codigoFabricanteTeste': '915',
#      'codigoResultadoTeste': '1',
#      'dataColetaTeste': {'__type': 'Date', 'iso': '2023-04-04T03:00:00.000Z'},
#      'loteTeste': 'SE2106091',
#      'estadoTeste': 'Concluído'}],
#    'idade': 31,
#    'resultadoTesteSorologicoTotais': None,
#    'codigoEstrategiaCovid': '3',
#    'outrosSintomas': None,
#    'codigoQualAntiviral': None,
#    'estrangeiro': None,
#    'resultadoTesteSorologicoIgA': None,
#    'sexo': 'Masculino',
#    'sintomas': 'Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'RgHTKL4Kjj',
#   '_score': 1.0,
#   '_source': {'outrasCondicoes': None,
#    'municipio': 'São José dos Campos',
#    'resultadoTesteSorologicoIgM': None,
#    'laboratorioSegundaReforcoDose': None,
#    'dataTesteSorologico': None,
#    'codigoBuscaAtivaAssintomatico': None,
#    'recebeuAntiviral': None,
#    'profissionalSeguranca': 'Não',
#    'cbo': None,
#    'codigoRecebeuAntiviral': None,
#    'municipioNotificacaoIBGE': '3549904',
#    'profissionalSaude': 'Não',
#    'outroTriagemPopulacaoEspecifica': None,
#    'resultadoTeste': None,
#    'classificacaoFinal': None,
#    'estadoIBGE': '35',
#    'estadoNotificacaoIBGE': '35',
#    'dataInicioTratamento': None,
#    '@version': '1',
#    'evolucaoCaso': None,
#    '@timestamp': '2023-04-05T03:40:00.459Z',
#    'municipioIBGE': '3549904',
#    'dataEncerramento': None,
#    'estado': 'São Paulo',
#    'resultadoTesteSorologicoIgG': None,
#    'dataReforcoDose': '2021-12-06T03:00:00.000Z',
#    'tipoTesteSorologico': None,
#    'qualAntiviral': None,
#    'estadoNotificacao': 'São Paulo',
#    'loteSegundaReforcoDose': None,
#    'id': 'RgHTKL4Kjj',
#    'outroLocalRealizacaoTestagem': None,
#    'outroBuscaAtivaAssintomatico': None,
#    'dataSegundaReforcoDose': None,
#    'codigoTriagemPopulacaoEspecifica': None,
#    'condicoes': 'Doenças cardíacas crônicas',
#    'codigoDosesVacina': ['1', '2', '3'],
#    'idCollection': 'RgHTKL4Kjj',
#    'estadoTeste': None,
#    'codigoLocalRealizacaoTestagem': '1',
#    'outroAntiviral': None,
#    'dataSegundaDose': '2021-05-03T03:00:00.000Z',
#    'codigoContemComunidadeTradicional': '2',
#    'tipoTeste': None,
#    'racaCor': 'Parda',
#    'codigoRecebeuVacina': '1',
#    'dataPrimeiraDose': '2021-03-30T03:00:00.000Z',
#    'dataTeste': None,
#    'registroAtual': True,
#    'dataNotificacao': '2023-04-04T03:00:00.287Z',
#    'dataInicioSintomas': '2023-04-04T03:00:00.000Z',
#    'municipioNotificacao': 'São José dos Campos',
#    'testes': [{'codigoEstadoTeste': '3',
#      'tipoTeste': 'TESTE RÁPIDO - ANTÍGENO',
#      'fabricanteTeste': 'OUTRAS MARCAS',
#      'resultadoTeste': 'Reagente',
#      'codigoTipoTeste': '3',
#      'codigoFabricanteTeste': '915',
#      'codigoResultadoTeste': '1',
#      'dataColetaTeste': {'__type': 'Date', 'iso': '2023-04-04T03:00:00.000Z'},
#      'loteTeste': 'A1722',
#      'estadoTeste': 'Concluído'}],
#    'idade': 74,
#    'resultadoTesteSorologicoTotais': None,
#    'codigoEstrategiaCovid': '1',
#    'outrosSintomas': None,
#    'codigoQualAntiviral': None,
#    'estrangeiro': None,
#    'resultadoTesteSorologicoIgA': None,
#    'sexo': 'Feminino',
#    'sintomas': 'Coriza, Tosse, Febre, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '4Yvf16wMlo',
#   '_score': 1.0,
#   '_source': {'outrasCondicoes': None,
#    'municipio': 'São José do Rio Preto',
#    'resultadoTesteSorologicoIgM': None,
#    'laboratorioSegundaReforcoDose': 'ASTRAZENECA/FIOCRUZ',
#    'dataTesteSorologico': None,
#    'codigoBuscaAtivaAssintomatico': None,
#    'recebeuAntiviral': None,
#    'profissionalSeguranca': 'Não',
#    'cbo': None,
#    'codigoRecebeuAntiviral': None,
#    'municipioNotificacaoIBGE': '3549805',
#    'profissionalSaude': 'Não',
#    'outroTriagemPopulacaoEspecifica': None,
#    'resultadoTeste': None,
#    'classificacaoFinal': 'Descartado',
#    'estadoIBGE': '35',
#    'estadoNotificacaoIBGE': '35',
#    'dataInicioTratamento': None,
#    '@version': '1',
#    'evolucaoCaso': 'Cura',
#    '@timestamp': '2023-04-05T03:40:00.459Z',
#    'municipioIBGE': '3549805',
#    'dataEncerramento': '2023-03-19T03:00:00.000Z',
#    'estado': 'São Paulo',
#    'resultadoTesteSorologicoIgG': None,
#    'dataReforcoDose': '2022-01-11T03:00:00.000Z',
#    'tipoTesteSorologico': None,
#    'qualAntiviral': None,
#    'estadoNotificacao': 'São Paulo',
#    'loteSegundaReforcoDose': '221VCD002Z',
#    'id': '4Yvf16wMlo',
#    'outroLocalRealizacaoTestagem': None,
#    'outroBuscaAtivaAssintomatico': None,
#    'dataSegundaReforcoDose': '2022-07-13T03:00:00.000Z',
#    'codigoTriagemPopulacaoEspecifica': None,
#    'condicoes': None,
#    'codigoDosesVacina': [],
#    'idCollection': '4Yvf16wMlo',
#    'estadoTeste': None,
#    'codigoLocalRealizacaoTestagem': '1',
#    'outroAntiviral': None,
#    'dataSegundaDose': None,
#    'codigoContemComunidadeTradicional': '2',
#    'tipoTeste': None,
#    'racaCor': 'Branca',
#    'codigoRecebeuVacina': '1',
#    'dataPrimeiraDose': None,
#    'dataTeste': None,
#    'registroAtual': True,
#    'dataNotificacao': '2023-02-09T03:00:30.369Z',
#    'dataInicioSintomas': '2023-02-06T03:00:00.000Z',
#    'municipioNotificacao': 'São José do Rio Preto',
#    'testes': [{'codigoEstadoTeste': '3',
#      'tipoTeste': 'TESTE RÁPIDO - ANTÍGENO',
#      'fabricanteTeste': 'OUTRAS MARCAS',
#      'resultadoTeste': 'Não Reagente',
#      'codigoTipoTeste': '3',
#      'codigoFabricanteTeste': '915',
#      'codigoResultadoTeste': '2',
#      'dataColetaTeste': {'__type': 'Date', 'iso': '2023-02-09T03:00:00.000Z'},
#      'loteTeste': 'FMFE10221',
#      'estadoTeste': 'Concluído'}],
#    'idade': 46,
#    'resultadoTesteSorologicoTotais': None,
#    'codigoEstrategiaCovid': '1',
#    'outrosSintomas': None,
#    'codigoQualAntiviral': None,
#    'estrangeiro': None,
#    'resultadoTesteSorologicoIgA': None,
#    'sexo': 'Masculino',
#    'sintomas': 'Dor de Garganta, Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '7G7nze6VU0',
#   '_score': 1.0,
#   '_source': {'outrasCondicoes': None,
#    'municipio': 'São José do Rio Preto',
#    'resultadoTesteSorologicoIgM': None,
#    'laboratorioSegundaReforcoDose': None,
#    'dataTesteSorologico': None,
#    'codigoBuscaAtivaAssintomatico': None,
#    'recebeuAntiviral': None,
#    'profissionalSeguranca': 'Não',
#    'cbo': None,
#    'codigoRecebeuAntiviral': None,
#    'municipioNotificacaoIBGE': '3549805',
#    'profissionalSaude': 'Não',
#    'outroTriagemPopulacaoEspecifica': None,
#    'resultadoTeste': None,
#    'classificacaoFinal': 'Descartado',
#    'estadoIBGE': '35',
#    'estadoNotificacaoIBGE': '35',
#    'dataInicioTratamento': None,
#    '@version': '1',
#    'evolucaoCaso': 'Cura',
#    '@timestamp': '2023-04-05T03:40:00.460Z',
#    'municipioIBGE': '3549805',
#    'dataEncerramento': '2023-04-04T03:00:00.000Z',
#    'estado': 'São Paulo',
#    'resultadoTesteSorologicoIgG': None,
#    'dataReforcoDose': None,
#    'tipoTesteSorologico': None,
#    'qualAntiviral': None,
#    'estadoNotificacao': 'São Paulo',
#    'loteSegundaReforcoDose': None,
#    'id': '7G7nze6VU0',
#    'outroLocalRealizacaoTestagem': None,
#    'outroBuscaAtivaAssintomatico': None,
#    'dataSegundaReforcoDose': None,
#    'codigoTriagemPopulacaoEspecifica': None,
#    'condicoes': None,
#    'codigoDosesVacina': ['1', '2'],
#    'idCollection': '7G7nze6VU0',
#    'estadoTeste': None,
#    'codigoLocalRealizacaoTestagem': '1',
#    'outroAntiviral': None,
#    'dataSegundaDose': '2021-10-02T03:00:00.000Z',
#    'codigoContemComunidadeTradicional': '2',
#    'tipoTeste': None,
#    'racaCor': 'Branca',
#    'codigoRecebeuVacina': '1',
#    'dataPrimeiraDose': '2021-07-05T03:00:00.000Z',
#    'dataTeste': None,
#    'registroAtual': True,
#    'dataNotificacao': '2023-01-18T03:00:26.739Z',
#    'dataInicioSintomas': '2023-01-17T03:00:00.000Z',
#    'municipioNotificacao': 'São José do Rio Preto',
#    'testes': [{'codigoEstadoTeste': '3',
#      'tipoTeste': 'TESTE RÁPIDO - ANTÍGENO',
#      'fabricanteTeste': 'BIO-MANGUINHOS/FIOCRUZ',
#      'resultadoTeste': 'Não Reagente',
#      'codigoTipoTeste': '3',
#      'codigoFabricanteTeste': '792',
#      'codigoResultadoTeste': '2',
#      'dataColetaTeste': {'__type': 'Date', 'iso': '2023-01-18T03:00:00.000Z'},
#      'loteTeste': '221KD002Z',
#      'estadoTeste': 'Concluído'}],
#    'idade': 44,
#    'resultadoTesteSorologicoTotais': None,
#    'codigoEstrategiaCovid': '1',
#    'outrosSintomas': None,
#    'codigoQualAntiviral': None,
#    'estrangeiro': None,
#    'resultadoTesteSorologicoIgA': None,
#    'sexo': 'Masculino',
#    'sintomas': 'Coriza, Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'vMFBaB2Ejk',
#   '_score': 1.0,
#   '_source': {'outrasCondicoes': None,
#    'municipio': 'Campo Grande',
#    'resultadoTesteSorologicoIgM': None,
#    'laboratorioSegundaReforcoDose': None,
#    'dataTesteSorologico': None,
#    'codigoBuscaAtivaAssintomatico': None,
#    'recebeuAntiviral': None,
#    'profissionalSeguranca': 'Não',
#    'cbo': None,
#    'codigoRecebeuAntiviral': None,
#    'municipioNotificacaoIBGE': '5002704',
#    'profissionalSaude': 'Não',
#    'outroTriagemPopulacaoEspecifica': None,
#    'resultadoTeste': None,
#    'classificacaoFinal': 'Síndrome Gripal Não Especificada',
#    'estadoIBGE': '50',
#    'estadoNotificacaoIBGE': '50',
#    'dataInicioTratamento': None,
#    '@version': '1',
#    'evolucaoCaso': 'Cura',
#    '@timestamp': '2023-04-05T03:40:00.460Z',
#    'municipioIBGE': '5002704',
#    'dataEncerramento': '2023-04-04T04:00:00.000Z',
#    'estado': 'Mato Grosso do Sul',
#    'resultadoTesteSorologicoIgG': None,
#    'dataReforcoDose': None,
#    'tipoTesteSorologico': None,
#    'qualAntiviral': None,
#    'estadoNotificacao': 'Mato Grosso do Sul',
#    'loteSegundaReforcoDose': None,
#    'id': 'vMFBaB2Ejk',
#    'outroLocalRealizacaoTestagem': None,
#    'outroBuscaAtivaAssintomatico': None,
#    'dataSegundaReforcoDose': None,
#    'codigoTriagemPopulacaoEspecifica': None,
#    'condicoes': None,
#    'codigoDosesVacina': ['1', '2'],
#    'idCollection': 'vMFBaB2Ejk',
#    'estadoTeste': None,
#    'codigoLocalRealizacaoTestagem': '1',
#    'outroAntiviral': None,
#    'dataSegundaDose': '2021-07-02T04:00:00.000Z',
#    'codigoContemComunidadeTradicional': '2',
#    'tipoTeste': None,
#    'racaCor': 'Branca',
#    'codigoRecebeuVacina': '1',
#    'dataPrimeiraDose': '2021-05-02T04:00:00.000Z',
#    'dataTeste': None,
#    'registroAtual': True,
#    'dataNotificacao': '2023-03-27T04:00:58.476Z',
#    'dataInicioSintomas': '2023-03-21T04:00:00.000Z',
#    'municipioNotificacao': 'Campo Grande',
#    'testes': [{'codigoEstadoTeste': '3',
#      'tipoTeste': 'TESTE RÁPIDO - ANTÍGENO',
#      'fabricanteTeste': 'BIO-MANGUINHOS/FIOCRUZ',
#      'resultadoTeste': 'Não Reagente',
#      'codigoTipoTeste': '3',
#      'codigoFabricanteTeste': '792',
#      'codigoResultadoTeste': '2',
#      'dataColetaTeste': {'__type': 'Date', 'iso': '2023-03-24T04:00:00.000Z'},
#      'loteTeste': '220562Z117',
#      'estadoTeste': 'Concluído'}],
#    'idade': 50,
#    'resultadoTesteSorologicoTotais': None,
#    'codigoEstrategiaCovid': '1',
#    'outrosSintomas': None,
#    'codigoQualAntiviral': None,
#    'estrangeiro': None,
#    'resultadoTesteSorologicoIgA': None,
#    'sexo': 'Feminino',
#    'sintomas': 'Febre, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 's7XjxICjaS',
#   '_score': 1.0,
#   '_source': {'outrasCondicoes': None,
#    'municipio': 'Guaramirim',
#    'resultadoTesteSorologicoIgM': None,
#    'laboratorioSegundaReforcoDose': None,
#    'dataTesteSorologico': None,
#    'codigoBuscaAtivaAssintomatico': None,
#    'recebeuAntiviral': 'Ignorado',
#    'profissionalSeguranca': 'Não',
#    'cbo': None,
#    'codigoRecebeuAntiviral': '3',
#    'municipioNotificacaoIBGE': '4206504',
#    'profissionalSaude': 'Não',
#    'outroTriagemPopulacaoEspecifica': None,
#    'resultadoTeste': None,
#    'classificacaoFinal': None,
#    'estadoIBGE': '42',
#    'estadoNotificacaoIBGE': '42',
#    'dataInicioTratamento': None,
#    '@version': '1',
#    'evolucaoCaso': None,
#    '@timestamp': '2023-04-05T03:40:00.460Z',
#    'municipioIBGE': '4206504',
#    'dataEncerramento': None,
#    'estado': 'Santa Catarina',
#    'resultadoTesteSorologicoIgG': None,
#    'dataReforcoDose': None,
#    'tipoTesteSorologico': None,
#    'qualAntiviral': None,
#    'estadoNotificacao': 'Santa Catarina',
#    'loteSegundaReforcoDose': None,
#    'id': 's7XjxICjaS',
#    'outroLocalRealizacaoTestagem': None,
#    'outroBuscaAtivaAssintomatico': None,
#    'dataSegundaReforcoDose': None,
#    'codigoTriagemPopulacaoEspecifica': None,
#    'condicoes': None,
#    'codigoDosesVacina': [],
#    'idCollection': 's7XjxICjaS',
#    'estadoTeste': None,
#    'codigoLocalRealizacaoTestagem': '1',
#    'outroAntiviral': None,
#    'dataSegundaDose': None,
#    'codigoContemComunidadeTradicional': '2',
#    'tipoTeste': None,
#    'racaCor': 'Ignorado',
#    'codigoRecebeuVacina': None,
#    'dataPrimeiraDose': None,
#    'dataTeste': None,
#    'registroAtual': True,
#    'dataNotificacao': '2022-12-21T03:00:00.000Z',
#    'dataInicioSintomas': '2022-12-17T03:00:00.000Z',
#    'municipioNotificacao': 'Guaramirim',
#    'testes': [{'codigoEstadoTeste': '3',
#      'tipoTeste': 'TESTE RÁPIDO - ANTÍGENO',
#      'fabricanteTeste': 'BIO-MANGUINHOS/FIOCRUZ',
#      'resultadoTeste': 'Reagente',
#      'codigoTipoTeste': '3',
#      'codigoFabricanteTeste': '792',
#      'codigoResultadoTeste': '1',
#      'dataColetaTeste': {'__type': 'Date', 'iso': '2022-12-21T03:00:00.000Z'},
#      'loteTeste': 'BE0042202085 ',
#      'estadoTeste': 'Concluído'}],
#    'idade': 42,
#    'resultadoTesteSorologicoTotais': None,
#    'codigoEstrategiaCovid': '1',
#    'outrosSintomas': None,
#    'codigoQualAntiviral': None,
#    'estrangeiro': 'Não',
#    'resultadoTesteSorologicoIgA': None,
#    'sexo': 'Masculino',
#    'sintomas': 'Coriza, Tosse, Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'QMzcs9av5F',
#   '_score': 1.0,
#   '_source': {'outrasCondicoes': None,
#    'municipio': 'São José do Rio Preto',
#    'resultadoTesteSorologicoIgM': None,
#    'laboratorioSegundaReforcoDose': None,
#    'dataTesteSorologico': None,
#    'codigoBuscaAtivaAssintomatico': None,
#    'recebeuAntiviral': None,
#    'profissionalSeguranca': 'Não',
#    'cbo': None,
#    'codigoRecebeuAntiviral': None,
#    'municipioNotificacaoIBGE': '3549805',
#    'profissionalSaude': 'Não',
#    'outroTriagemPopulacaoEspecifica': None,
#    'resultadoTeste': None,
#    'classificacaoFinal': 'Descartado',
#    'estadoIBGE': '35',
#    'estadoNotificacaoIBGE': '35',
#    'dataInicioTratamento': None,
#    '@version': '1',
#    'evolucaoCaso': 'Cura',
#    '@timestamp': '2023-04-05T03:40:00.461Z',
#    'municipioIBGE': '3549805',
#    'dataEncerramento': '2023-03-19T03:00:00.000Z',
#    'estado': 'São Paulo',
#    'resultadoTesteSorologicoIgG': None,
#    'dataReforcoDose': None,
#    'tipoTesteSorologico': None,
#    'qualAntiviral': None,
#    'estadoNotificacao': 'São Paulo',
#    'loteSegundaReforcoDose': None,
#    'id': 'QMzcs9av5F',
#    'outroLocalRealizacaoTestagem': None,
#    'outroBuscaAtivaAssintomatico': None,
#    'dataSegundaReforcoDose': None,
#    'codigoTriagemPopulacaoEspecifica': None,
#    'condicoes': 'Doenças cardíacas crônicas',
#    'codigoDosesVacina': ['2'],
#    'idCollection': 'QMzcs9av5F',
#    'estadoTeste': None,
#    'codigoLocalRealizacaoTestagem': '1',
#    'outroAntiviral': None,
#    'dataSegundaDose': '2021-10-20T03:00:00.000Z',
#    'codigoContemComunidadeTradicional': '2',
#    'tipoTeste': None,
#    'racaCor': 'Ignorado',
#    'codigoRecebeuVacina': '1',
#    'dataPrimeiraDose': None,
#    'dataTeste': None,
#    'registroAtual': True,
#    'dataNotificacao': '2023-02-09T03:00:20.427Z',
#    'dataInicioSintomas': '2023-02-08T03:00:00.000Z',
#    'municipioNotificacao': 'São José do Rio Preto',
#    'testes': [{'codigoEstadoTeste': '3',
#      'tipoTeste': 'TESTE RÁPIDO - ANTÍGENO',
#      'fabricanteTeste': 'BIO-MANGUINHOS/FIOCRUZ',
#      'resultadoTeste': 'Não Reagente',
#      'codigoTipoTeste': '3',
#      'codigoFabricanteTeste': '792',
#      'codigoResultadoTeste': '2',
#      'dataColetaTeste': {'__type': 'Date', 'iso': '2023-02-09T03:00:00.000Z'},
#      'loteTeste': '222KC006Z',
#      'estadoTeste': 'Concluído'}],
#    'idade': 52,
#    'resultadoTesteSorologicoTotais': None,
#    'codigoEstrategiaCovid': '1',
#    'outrosSintomas': 'MIALGIA, VOMITOS, DIARREIA',
#    'codigoQualAntiviral': None,
#    'estrangeiro': None,
#    'resultadoTesteSorologicoIgA': None,
#    'sexo': 'Feminino',
#    'sintomas': 'Outros, Coriza'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'Uk2zuEF4kK',
#   '_score': 1.0,
#   '_source': {'outrasCondicoes': None,
#    'municipio': 'Santana de Parnaíba',
#    'resultadoTesteSorologicoIgM': None,
#    'laboratorioSegundaReforcoDose': None,
#    'dataTesteSorologico': None,
#    'codigoBuscaAtivaAssintomatico': None,
#    'recebeuAntiviral': 'Ignorado',
#    'profissionalSeguranca': 'Não',
#    'cbo': None,
#    'codigoRecebeuAntiviral': '3',
#    'municipioNotificacaoIBGE': '3547304',
#    'profissionalSaude': 'Não',
#    'outroTriagemPopulacaoEspecifica': None,
#    'resultadoTeste': None,
#    'classificacaoFinal': None,
#    'estadoIBGE': '35',
#    'estadoNotificacaoIBGE': '35',
#    'dataInicioTratamento': None,
#    '@version': '1',
#    'evolucaoCaso': None,
#    '@timestamp': '2023-04-05T03:40:00.461Z',
#    'municipioIBGE': '3547304',
#    'dataEncerramento': None,
#    'estado': 'São Paulo',
#    'resultadoTesteSorologicoIgG': None,
#    'dataReforcoDose': None,
#    'tipoTesteSorologico': None,
#    'qualAntiviral': None,
#    'estadoNotificacao': 'São Paulo',
#    'loteSegundaReforcoDose': None,
#    'id': 'Uk2zuEF4kK',
#    'outroLocalRealizacaoTestagem': None,
#    'outroBuscaAtivaAssintomatico': None,
#    'dataSegundaReforcoDose': None,
#    'codigoTriagemPopulacaoEspecifica': None,
#    'condicoes': 'Doenças respiratórias crônicas descompensadas',
#    'codigoDosesVacina': ['1', '2'],
#    'idCollection': 'Uk2zuEF4kK',
#    'estadoTeste': None,
#    'codigoLocalRealizacaoTestagem': '1',
#    'outroAntiviral': None,
#    'dataSegundaDose': '2021-08-02T03:00:00.000Z',
#    'codigoContemComunidadeTradicional': '2',
#    'tipoTeste': None,
#    'racaCor': 'Parda',
#    'codigoRecebeuVacina': '1',
#    'dataPrimeiraDose': '2021-06-28T03:00:00.000Z',
#    'dataTeste': None,
#    'registroAtual': True,
#    'dataNotificacao': '2023-04-04T03:00:22.072Z',
#    'dataInicioSintomas': '2023-04-01T03:00:00.000Z',
#    'municipioNotificacao': 'Santana de Parnaíba',
#    'testes': [{'codigoEstadoTeste': '3',
#      'tipoTeste': 'TESTE RÁPIDO - ANTÍGENO',
#      'fabricanteTeste': 'BIO-MANGUINHOS/FIOCRUZ',
#      'resultadoTeste': 'Não Reagente',
#      'codigoTipoTeste': '3',
#      'codigoFabricanteTeste': '792',
#      'codigoResultadoTeste': '2',
#      'dataColetaTeste': {'__type': 'Date', 'iso': '2023-04-04T03:00:00.000Z'},
#      'loteTeste': 'COVGCF1039',
#      'estadoTeste': 'Concluído'}],
#    'idade': 51,
#    'resultadoTesteSorologicoTotais': None,
#    'codigoEstrategiaCovid': '1',
#    'outrosSintomas': None,
#    'codigoQualAntiviral': None,
#    'estrangeiro': None,
#    'resultadoTesteSorologicoIgA': None,
#    'sexo': 'Feminino',
#    'sintomas': 'Dor de Cabeça, Coriza'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'MRvuorbfju',
#   '_score': 1.0,
#   '_source': {'outrasCondicoes': None,
#    'municipio': 'São José do Rio Preto',
#    'resultadoTesteSorologicoIgM': None,
#    'laboratorioSegundaReforcoDose': None,
#    'dataTesteSorologico': None,
#    'codigoBuscaAtivaAssintomatico': None,
#    'recebeuAntiviral': None,
#    'profissionalSeguranca': 'Não',
#    'cbo': None,
#    'codigoRecebeuAntiviral': None,
#    'municipioNotificacaoIBGE': '3549805',
#    'profissionalSaude': 'Não',
#    'outroTriagemPopulacaoEspecifica': None,
#    'resultadoTeste': None,
#    'classificacaoFinal': 'Descartado',
#    'estadoIBGE': '35',
#    'estadoNotificacaoIBGE': '35',
#    'dataInicioTratamento': None,
#    '@version': '1',
#    'evolucaoCaso': 'Cura',
#    '@timestamp': '2023-04-05T03:40:00.462Z',
#    'municipioIBGE': '3549805',
#    'dataEncerramento': '2023-04-04T03:00:00.000Z',
#    'estado': 'São Paulo',
#    'resultadoTesteSorologicoIgG': None,
#    'dataReforcoDose': None,
#    'tipoTesteSorologico': None,
#    'qualAntiviral': None,
#    'estadoNotificacao': 'São Paulo',
#    'loteSegundaReforcoDose': None,
#    'id': 'MRvuorbfju',
#    'outroLocalRealizacaoTestagem': None,
#    'outroBuscaAtivaAssintomatico': None,
#    'dataSegundaReforcoDose': None,
#    'codigoTriagemPopulacaoEspecifica': None,
#    'condicoes': None,
#    'codigoDosesVacina': ['1', '2'],
#    'idCollection': 'MRvuorbfju',
#    'estadoTeste': None,
#    'codigoLocalRealizacaoTestagem': '1',
#    'outroAntiviral': None,
#    'dataSegundaDose': '2021-11-04T03:00:00.000Z',
#    'codigoContemComunidadeTradicional': '2',
#    'tipoTeste': None,
#    'racaCor': 'Parda',
#    'codigoRecebeuVacina': '1',
#    'dataPrimeiraDose': '2021-08-12T03:00:00.000Z',
#    'dataTeste': None,
#    'registroAtual': True,
#    'dataNotificacao': '2022-07-21T03:00:50.236Z',
#    'dataInicioSintomas': '2022-07-12T03:00:00.000Z',
#    'municipioNotificacao': 'São José do Rio Preto',
#    'testes': [{'codigoEstadoTeste': '3',
#      'tipoTeste': 'TESTE RÁPIDO - ANTÍGENO',
#      'fabricanteTeste': 'OUTRAS MARCAS',
#      'resultadoTeste': 'Não Reagente',
#      'codigoTipoTeste': '3',
#      'codigoFabricanteTeste': '915',
#      'codigoResultadoTeste': '2',
#      'dataColetaTeste': {'__type': 'Date', 'iso': '2022-07-21T03:00:00.000Z'},
#      'loteTeste': '20211209',
#      'estadoTeste': 'Concluído'}],
#    'idade': 31,
#    'resultadoTesteSorologicoTotais': None,
#    'codigoEstrategiaCovid': '1',
#    'outrosSintomas': None,
#    'codigoQualAntiviral': None,
#    'estrangeiro': None,
#    'resultadoTesteSorologicoIgA': None,
#    'sexo': 'Masculino',
#    'sintomas': 'Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'p0dEJGbb6g',
#   '_score': 1.0,
#   '_source': {'outrasCondicoes': None,
#    'municipio': 'São Paulo',
#    'resultadoTesteSorologicoIgM': None,
#    'laboratorioSegundaReforcoDose': 'PFIZER',
#    'dataTesteSorologico': None,
#    'codigoBuscaAtivaAssintomatico': None,
#    'recebeuAntiviral': 'Ignorado',
#    'profissionalSeguranca': 'Não',
#    'cbo': None,
#    'codigoRecebeuAntiviral': '3',
#    'municipioNotificacaoIBGE': '3550308',
#    'profissionalSaude': 'Não',
#    'outroTriagemPopulacaoEspecifica': None,
#    'resultadoTeste': None,
#    'classificacaoFinal': None,
#    'estadoIBGE': '35',
#    'estadoNotificacaoIBGE': '35',
#    'dataInicioTratamento': None,
#    '@version': '1',
#    'evolucaoCaso': None,
#    '@timestamp': '2023-04-05T03:40:00.462Z',
#    'municipioIBGE': '3550308',
#    'dataEncerramento': None,
#    'estado': 'São Paulo',
#    'resultadoTesteSorologicoIgG': None,
#    'dataReforcoDose': '2021-10-29T03:00:00.000Z',
#    'tipoTesteSorologico': None,
#    'qualAntiviral': None,
#    'estadoNotificacao': 'São Paulo',
#    'loteSegundaReforcoDose': 'FM2948',
#    'id': 'p0dEJGbb6g',
#    'outroLocalRealizacaoTestagem': None,
#    'outroBuscaAtivaAssintomatico': None,
#    'dataSegundaReforcoDose': '2022-06-14T03:00:00.000Z',
#    'codigoTriagemPopulacaoEspecifica': None,
#    'condicoes': None,
#    'codigoDosesVacina': ['1', '2', '3', '4'],
#    'idCollection': 'p0dEJGbb6g',
#    'estadoTeste': None,
# ...
#      'fabricanteTeste': 'BIO-MANGUINHOS/FIOCRUZ',
#      'resultadoTeste': 'Não Reagente',
#      'codigoTipoTeste': '3',
#      'codigoFabricanteTeste': '792',
#      'codigoResultadoTeste': '2',
#      'dataColetaTeste': {'__type': 'Date', 'iso': '2023-04-04T03:00:00.000Z'},
#      'loteTeste': 'COVGCF2003',
#      'estadoTeste': 'Concluído'}],
#    'idade': 40,
#    'resultadoTesteSorologicoTotais': None,
#    'codigoEstrategiaCovid': '1',
#    'outrosSintomas': 'ROWUIDÁO E NARIZ TRANCADO',
#    'codigoQualAntiviral': None,
#    'estrangeiro': None,
#    'resultadoTesteSorologicoIgA': None,
#    'sexo': 'Feminino',
#    'sintomas': 'Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'vfMhWxRGbG',
#   '_score': 1.0,
#   '_source': {'outrasCondicoes': None,
#    'municipio': 'Caxias do Sul',
#    'resultadoTesteSorologicoIgM': None,
#    'laboratorioSegundaReforcoDose': None,
#    'dataTesteSorologico': None,
#    'codigoBuscaAtivaAssintomatico': None,
#    'recebeuAntiviral': None,
#    'profissionalSeguranca': 'Não',
#    'cbo': None,
#    'codigoRecebeuAntiviral': None,
#    'municipioNotificacaoIBGE': '4305108',
#    'profissionalSaude': 'Não',
#    'outroTriagemPopulacaoEspecifica': None,
#    'resultadoTeste': None,
#    'classificacaoFinal': None,
#    'estadoIBGE': '43',
#    'estadoNotificacaoIBGE': '43',
#    'dataInicioTratamento': None,
#    '@version': '1',
#    'evolucaoCaso': None,
#    '@timestamp': '2023-04-05T03:00:00.300Z',
#    'municipioIBGE': '4305108',
#    'dataEncerramento': None,
#    'estado': 'Rio Grande do Sul',
#    'resultadoTesteSorologicoIgG': None,
#    'dataReforcoDose': None,
#    'tipoTesteSorologico': None,
#    'qualAntiviral': None,
#    'estadoNotificacao': 'Rio Grande do Sul',
#    'loteSegundaReforcoDose': None,
#    'id': 'vfMhWxRGbG',
#    'outroLocalRealizacaoTestagem': None,
#    'outroBuscaAtivaAssintomatico': None,
#    'dataSegundaReforcoDose': None,
#    'codigoTriagemPopulacaoEspecifica': None,
#    'condicoes': 'Doenças respiratórias crônicas descompensadas',
#    'codigoDosesVacina': ['1', '2'],
#    'idCollection': 'vfMhWxRGbG',
#    'estadoTeste': None,
#    'codigoLocalRealizacaoTestagem': '1',
#    'outroAntiviral': None,
#    'dataSegundaDose': '2021-11-16T03:00:00.000Z',
#    'codigoContemComunidadeTradicional': '2',
#    'tipoTeste': None,
#    'racaCor': 'Parda',
#    'codigoRecebeuVacina': '1',
#    'dataPrimeiraDose': '2021-08-23T03:00:00.000Z',
#    'dataTeste': None,
#    'registroAtual': True,
#    'dataNotificacao': '2023-04-04T03:00:48.576Z',
#    'dataInicioSintomas': '2023-04-02T03:00:00.000Z',
#    'municipioNotificacao': 'Caxias do Sul',
#    'testes': [{'codigoEstadoTeste': '3',
#      'tipoTeste': 'TESTE RÁPIDO - ANTÍGENO',
#      'fabricanteTeste': 'BIO-MANGUINHOS/FIOCRUZ',
#      'resultadoTeste': 'Não Reagente',
#      'codigoTipoTeste': '3',
#      'codigoFabricanteTeste': '792',
#      'codigoResultadoTeste': '2',
#      'dataColetaTeste': {'__type': 'Date', 'iso': '2023-04-04T03:00:00.000Z'},
#      'loteTeste': 'FMFE10221',
#      'estadoTeste': 'Concluído'}],
#    'idade': 21,
#    'resultadoTesteSorologicoTotais': None,
#    'codigoEstrategiaCovid': '1',
#    'outrosSintomas': None,
#    'codigoQualAntiviral': None,
#    'estrangeiro': None,
#    'resultadoTesteSorologicoIgA': None,
#    'sexo': 'Masculino',
#    'sintomas': 'Coriza, Dor de Cabeça, Tosse, Febre, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'wED9uqx0g5',
#   '_score': 1.0,
#   '_source': {'outrasCondicoes': None,
#    'municipio': 'Votuporanga',
#    'resultadoTesteSorologicoIgM': None,
#    'laboratorioSegundaReforcoDose': None,
#    'dataTesteSorologico': None,
#    'codigoBuscaAtivaAssintomatico': None,
#    'recebeuAntiviral': 'Ignorado',
#    'profissionalSeguranca': 'Não',
#    'cbo': None,
#    'codigoRecebeuAntiviral': '3',
#    'municipioNotificacaoIBGE': '3557105',
#    'profissionalSaude': 'Não',
#    'outroTriagemPopulacaoEspecifica': None,
#    'resultadoTeste': None,
#    'classificacaoFinal': None,
#    'estadoIBGE': '35',
#    'estadoNotificacaoIBGE': '35',
#    'dataInicioTratamento': None,
#    '@version': '1',
#    'evolucaoCaso': None,
#    '@timestamp': '2023-04-05T03:00:00.300Z',
#    'municipioIBGE': '3557105',
#    'dataEncerramento': None,
#    'estado': 'São Paulo',
#    'resultadoTesteSorologicoIgG': None,
#    'dataReforcoDose': None,
#    'tipoTesteSorologico': None,
#    'qualAntiviral': None,
#    'estadoNotificacao': 'São Paulo',
#    'loteSegundaReforcoDose': None,
#    'id': 'wED9uqx0g5',
#    'outroLocalRealizacaoTestagem': None,
#    'outroBuscaAtivaAssintomatico': None,
#    'dataSegundaReforcoDose': None,
#    'codigoTriagemPopulacaoEspecifica': None,
#    'condicoes': None,
#    'codigoDosesVacina': [],
#    'idCollection': 'wED9uqx0g5',
#    'estadoTeste': None,
#    'codigoLocalRealizacaoTestagem': '1',
#    'outroAntiviral': None,
#    'dataSegundaDose': None,
#    'codigoContemComunidadeTradicional': '2',
#    'tipoTeste': None,
#    'racaCor': 'Ignorado',
#    'codigoRecebeuVacina': None,
#    'dataPrimeiraDose': None,
#    'dataTeste': None,
#    'registroAtual': True,
#    'dataNotificacao': '2023-04-04T03:00:50.870Z',
#    'dataInicioSintomas': '2023-03-29T03:00:00.000Z',
#    'municipioNotificacao': 'Votuporanga',
#    'testes': [{'codigoEstadoTeste': '3',
#      'tipoTeste': 'TESTE RÁPIDO - ANTÍGENO',
#      'fabricanteTeste': 'BIO-MANGUINHOS/FIOCRUZ',
#      'resultadoTeste': 'Não Reagente',
#      'codigoTipoTeste': '3',
#      'codigoFabricanteTeste': '792',
#      'codigoResultadoTeste': '2',
#      'dataColetaTeste': {'__type': 'Date', 'iso': '2023-04-04T03:00:00.000Z'},
#      'loteTeste': '219KC19Z',
#      'estadoTeste': 'Concluído'}],
#    'idade': 70,
#    'resultadoTesteSorologicoTotais': None,
#    'codigoEstrategiaCovid': '1',
#    'outrosSintomas': 'MIALGIA',
#    'codigoQualAntiviral': None,
#    'estrangeiro': None,
#    'resultadoTesteSorologicoIgA': None,
#    'sexo': 'Masculino',
#    'sintomas': 'Coriza, Tosse, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'pnKedDqhpD',
#   '_score': 1.0,
#   '_source': {'outrasCondicoes': None,
#    'municipio': 'São José do Rio Preto',
#    'resultadoTesteSorologicoIgM': None,
#    'laboratorioSegundaReforcoDose': None,
#    'dataTesteSorologico': None,
#    'codigoBuscaAtivaAssintomatico': None,
#    'recebeuAntiviral': None,
#    'profissionalSeguranca': 'Não',
#    'cbo': None,
#    'codigoRecebeuAntiviral': None,
#    'municipioNotificacaoIBGE': '3549805',
#    'profissionalSaude': 'Não',
#    'outroTriagemPopulacaoEspecifica': None,
#    'resultadoTeste': None,
#    'classificacaoFinal': 'Descartado',
#    'estadoIBGE': '35',
#    'estadoNotificacaoIBGE': '35',
#    'dataInicioTratamento': None,
#    '@version': '1',
#    'evolucaoCaso': 'Cura',
#    '@timestamp': '2023-04-05T03:00:00.300Z',
#    'municipioIBGE': '3549805',
#    'dataEncerramento': '2023-04-04T03:00:00.000Z',
#    'estado': 'São Paulo',
#    'resultadoTesteSorologicoIgG': None,
#    'dataReforcoDose': None,
#    'tipoTesteSorologico': None,
#    'qualAntiviral': None,
#    'estadoNotificacao': 'São Paulo',
#    'loteSegundaReforcoDose': None,
#    'id': 'pnKedDqhpD',
#    'outroLocalRealizacaoTestagem': None,
#    'outroBuscaAtivaAssintomatico': None,
#    'dataSegundaReforcoDose': None,
#    'codigoTriagemPopulacaoEspecifica': None,
#    'condicoes': None,
#    'codigoDosesVacina': ['1', '2'],
#    'idCollection': 'pnKedDqhpD',
#    'estadoTeste': None,
#    'codigoLocalRealizacaoTestagem': '1',
#    'outroAntiviral': None,
#    'dataSegundaDose': '2022-04-29T03:00:00.000Z',
#    'codigoContemComunidadeTradicional': '2',
#    'tipoTeste': None,
#    'racaCor': 'Parda',
#    'codigoRecebeuVacina': '1',
#    'dataPrimeiraDose': '2022-02-26T03:00:00.000Z',
#    'dataTeste': None,
#    'registroAtual': True,
#    'dataNotificacao': '2023-02-24T03:00:38.436Z',
#    'dataInicioSintomas': '2023-02-23T03:00:00.000Z',
#    'municipioNotificacao': 'São José do Rio Preto',
#    'testes': [{'codigoEstadoTeste': '3',
#      'tipoTeste': 'TESTE RÁPIDO - ANTÍGENO',
#      'fabricanteTeste': 'BIO-MANGUINHOS/FIOCRUZ',
#      'resultadoTeste': 'Não Reagente',
#      'codigoTipoTeste': '3',
#      'codigoFabricanteTeste': '792',
#      'codigoResultadoTeste': '2',
#      'dataColetaTeste': {'__type': 'Date', 'iso': '2023-02-24T03:00:00.000Z'},
#      'loteTeste': '222KC006',
#      'estadoTeste': 'Concluído'}],
#    'idade': 11,
#    'resultadoTesteSorologicoTotais': None,
#    'codigoEstrategiaCovid': '1',
#    'outrosSintomas': 'DOR DE OUVIDO ',
#    'codigoQualAntiviral': None,
#    'estrangeiro': None,
#    'resultadoTesteSorologicoIgA': None,
#    'sexo': 'Feminino',
#    'sintomas': 'Coriza, Tosse, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'TN4b9NkIcN',
#   '_score': 1.0,
#   '_source': {'outrasCondicoes': None,
#    'municipio': 'Jacareí',
#    'resultadoTesteSorologicoIgM': None,
#    'laboratorioSegundaReforcoDose': None,
#    'dataTesteSorologico': None,
#    'codigoBuscaAtivaAssintomatico': '1',
#    'recebeuAntiviral': None,
#    'profissionalSeguranca': 'Não',
#    'cbo': None,
#    'codigoRecebeuAntiviral': None,
#    'municipioNotificacaoIBGE': '3524402',
#    'profissionalSaude': 'Não',
#    'outroTriagemPopulacaoEspecifica': None,
#    'resultadoTeste': None,
#    'classificacaoFinal': None,
#    'estadoIBGE': '35',
#    'estadoNotificacaoIBGE': '35',
#    'dataInicioTratamento': None,
#    '@version': '1',
#    'evolucaoCaso': None,
#    '@timestamp': '2023-04-05T03:00:00.301Z',
#    'municipioIBGE': '3524402',
#    'dataEncerramento': None,
#    'estado': 'São Paulo',
#    'resultadoTesteSorologicoIgG': None,
#    'dataReforcoDose': None,
#    'tipoTesteSorologico': None,
#    'qualAntiviral': None,
#    'estadoNotificacao': 'São Paulo',
#    'loteSegundaReforcoDose': None,
#    'id': 'TN4b9NkIcN',
#    'outroLocalRealizacaoTestagem': None,
#    'outroBuscaAtivaAssintomatico': None,
#    'dataSegundaReforcoDose': None,
#    'codigoTriagemPopulacaoEspecifica': None,
#    'condicoes': None,
#    'codigoDosesVacina': [],
#    'idCollection': 'TN4b9NkIcN',
#    'estadoTeste': None,
#    'codigoLocalRealizacaoTestagem': '1',
#    'outroAntiviral': None,
#    'dataSegundaDose': None,
#    'codigoContemComunidadeTradicional': '2',
#    'tipoTeste': None,
#    'racaCor': 'Branca',
#    'codigoRecebeuVacina': None,
#    'dataPrimeiraDose': None,
#    'dataTeste': None,
#    'registroAtual': True,
#    'dataNotificacao': '2023-04-04T03:00:05.005Z',
#    'dataInicioSintomas': None,
#    'municipioNotificacao': 'Jacareí',
#    'testes': [{'codigoEstadoTeste': '3',
#      'tipoTeste': 'TESTE RÁPIDO - ANTÍGENO',
#      'fabricanteTeste': 'OUTRAS MARCAS',
#      'resultadoTeste': 'Não Reagente',
#      'codigoTipoTeste': '3',
#      'codigoFabricanteTeste': '915',
#      'codigoResultadoTeste': '2',
#      'dataColetaTeste': {'__type': 'Date', 'iso': '2023-04-04T03:00:00.000Z'},
#      'loteTeste': 'NÃO INFORMADO',
#      'estadoTeste': 'Concluído'}],
#    'idade': 41,
#    'resultadoTesteSorologicoTotais': None,
#    'codigoEstrategiaCovid': '2',
#    'outrosSintomas': None,
#    'codigoQualAntiviral': None,
#    'estrangeiro': None,
#    'resultadoTesteSorologicoIgA': None,
#    'sexo': 'Feminino',
#    'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'ZIIUn7dGVO',
#   '_score': 1.0,
#   '_source': {'outrasCondicoes': None,
#    'municipio': 'Rio Branco',
#    'resultadoTesteSorologicoIgM': None,
#    'laboratorioSegundaReforcoDose': 'JANSSEN',
#    'dataTesteSorologico': None,
#    'codigoBuscaAtivaAssintomatico': None,
#    'recebeuAntiviral': 'Ignorado',
#    'profissionalSeguranca': 'Não',
#    'cbo': None,
#    'codigoRecebeuAntiviral': '3',
#    'municipioNotificacaoIBGE': '1200401',
#    'profissionalSaude': 'Não',
#    'outroTriagemPopulacaoEspecifica': None,
#    'resultadoTeste': None,
#    'classificacaoFinal': 'Confirmado Laboratorial',
#    'estadoIBGE': '12',
#    'estadoNotificacaoIBGE': '12',
#    'dataInicioTratamento': None,
#    '@version': '1',
#    'evolucaoCaso': 'Cura',
#    '@timestamp': '2023-04-05T03:00:00.294Z',
#    'municipioIBGE': '1200401',
#    'dataEncerramento': '2023-04-04T03:00:00.000Z',
#    'estado': 'Acre',
#    'resultadoTesteSorologicoIgG': None,
#    'dataReforcoDose': '2021-12-17T05:00:00.000Z',
#    'tipoTesteSorologico': None,
#    'qualAntiviral': None,
#    'estadoNotificacao': 'Acre',
#    'loteSegundaReforcoDose': '212J21A',
#    'id': 'ZIIUn7dGVO',
#    'outroLocalRealizacaoTestagem': None,
#    'outroBuscaAtivaAssintomatico': None,
#    'dataSegundaReforcoDose': '2022-07-01T05:00:00.000Z',
#    'codigoTriagemPopulacaoEspecifica': None,
#    'condicoes': None,
#    'codigoDosesVacina': ['1', '2', '3'],
#    'idCollection': 'ZIIUn7dGVO',
#    'estadoTeste': None,
#    'codigoLocalRealizacaoTestagem': '1',
#    'outroAntiviral': None,
#    'dataSegundaDose': None,
#    'codigoContemComunidadeTradicional': '2',
#    'tipoTeste': None,
#    'racaCor': 'Amarela',
#    'codigoRecebeuVacina': '1',
#    'dataPrimeiraDose': '2021-05-18T05:00:00.000Z',
#    'dataTeste': None,
#    'registroAtual': True,
#    'dataNotificacao': '2023-03-30T05:00:33.508Z',
#    'dataInicioSintomas': '2023-03-26T05:00:00.000Z',
#    'municipioNotificacao': 'Rio Branco',
#    'testes': [{'codigoEstadoTeste': '3',
#      'tipoTeste': 'TESTE RÁPIDO - ANTÍGENO',
#      'fabricanteTeste': 'OUTRAS MARCAS',
#      'resultadoTeste': 'Reagente',
#      'codigoTipoTeste': '3',
#      'codigoFabricanteTeste': '915',
#      'codigoResultadoTeste': '1',
#      'dataColetaTeste': {'__type': 'Date', 'iso': '2023-03-30T05:00:00.000Z'},
#      'loteTeste': 'CAGT22004',
#      'estadoTeste': 'Concluído'}],
#    'idade': 55,
#    'resultadoTesteSorologicoTotais': None,
#    'codigoEstrategiaCovid': '1',
#    'outrosSintomas': None,
#    'codigoQualAntiviral': None,
#    'estrangeiro': None,
#    'resultadoTesteSorologicoIgA': None,
#    'sexo': 'Feminino',
#    'sintomas': 'Dor de Cabeça, Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'FdrV4EU81E',
#   '_score': 1.0,
#   '_source': {'outrasCondicoes': None,
#    'municipio': 'São Paulo',
#    'resultadoTesteSorologicoIgM': None,
#    'laboratorioSegundaReforcoDose': None,
#    'dataTesteSorologico': None,
#    'codigoBuscaAtivaAssintomatico': None,
#    'recebeuAntiviral': 'Ignorado',
#    'profissionalSeguranca': 'Não',
#    'cbo': None,
#    'codigoRecebeuAntiviral': '3',
#    'municipioNotificacaoIBGE': '3550308',
#    'profissionalSaude': 'Não',
#    'outroTriagemPopulacaoEspecifica': None,
#    'resultadoTeste': None,
#    'classificacaoFinal': None,
#    'estadoIBGE': '35',
#    'estadoNotificacaoIBGE': '35',
#    'dataInicioTratamento': None,
#    '@version': '1',
#    'evolucaoCaso': None,
#    '@timestamp': '2023-04-05T03:00:00.301Z',
#    'municipioIBGE': '3550308',
#    'dataEncerramento': None,
#    'estado': 'São Paulo',
#    'resultadoTesteSorologicoIgG': None,
#    'dataReforcoDose': None,
#    'tipoTesteSorologico': None,
#    'qualAntiviral': None,
#    'estadoNotificacao': 'São Paulo',
#    'loteSegundaReforcoDose': None,
#    'id': 'FdrV4EU81E',
#    'outroLocalRealizacaoTestagem': None,
#    'outroBuscaAtivaAssintomatico': None,
#    'dataSegundaReforcoDose': None,
#    'codigoTriagemPopulacaoEspecifica': None,
#    'condicoes': None,
#    'codigoDosesVacina': [],
#    'idCollection': 'FdrV4EU81E',
#    'estadoTeste': None,
#    'codigoLocalRealizacaoTestagem': '1',
#    'outroAntiviral': None,
#    'dataSegundaDose': None,
#    'codigoContemComunidadeTradicional': '2',
#    'tipoTeste': None,
#    'racaCor': 'Parda',
#    'codigoRecebeuVacina': '2',
#    'dataPrimeiraDose': None,
#    'dataTeste': None,
#    'registroAtual': True,
#    'dataNotificacao': '2023-04-04T03:00:57.275Z',
#    'dataInicioSintomas': '2023-04-03T03:00:00.000Z',
#    'municipioNotificacao': 'São Paulo',
#    'testes': [{'codigoEstadoTeste': '3',
#      'tipoTeste': 'TESTE RÁPIDO - ANTÍGENO',
#      'fabricanteTeste': 'BIO-MANGUINHOS/FIOCRUZ',
#      'resultadoTeste': 'Não Reagente',
#      'codigoTipoTeste': '3',
#      'codigoFabricanteTeste': '792',
#      'codigoResultadoTeste': '2',
#      'dataColetaTeste': {'__type': 'Date', 'iso': '2023-04-04T03:00:00.000Z'},
#      'loteTeste': '224KD046Z',
#      'estadoTeste': 'Concluído'}],
#    'idade': 79,
#    'resultadoTesteSorologicoTotais': None,
#    'codigoEstrategiaCovid': '1',
#    'outrosSintomas': 'DOR NOS BRACOS E PERNAS',
#    'codigoQualAntiviral': None,
#    'estrangeiro': 'Não',
#    'resultadoTesteSorologicoIgA': None,
#    'sexo': 'Masculino',
#    'sintomas': 'Outros'}},
#  ...]

# %%
df_bra = pd.json_normalize(data_bra['hits']['hits'])

# %%
df_bra.columns
# Out:
# Index(['_index', '_type', '_id', '_score', '_source.outrasCondicoes',
#        '_source.municipio', '_source.resultadoTesteSorologicoIgM',
#        '_source.laboratorioSegundaReforcoDose', '_source.dataTesteSorologico',
#        '_source.codigoBuscaAtivaAssintomatico', '_source.recebeuAntiviral',
#        '_source.profissionalSeguranca', '_source.cbo',
#        '_source.codigoRecebeuAntiviral', '_source.municipioNotificacaoIBGE',
#        '_source.profissionalSaude', '_source.outroTriagemPopulacaoEspecifica',
#        '_source.resultadoTeste', '_source.classificacaoFinal',
#        '_source.estadoIBGE', '_source.estadoNotificacaoIBGE',
#        '_source.dataInicioTratamento', '_source.@version',
#        '_source.evolucaoCaso', '_source.@timestamp', '_source.municipioIBGE',
#        '_source.dataEncerramento', '_source.estado',
#        '_source.resultadoTesteSorologicoIgG', '_source.dataReforcoDose',
#        '_source.tipoTesteSorologico', '_source.qualAntiviral',
#        '_source.estadoNotificacao', '_source.loteSegundaReforcoDose',
#        '_source.id', '_source.outroLocalRealizacaoTestagem',
#        '_source.outroBuscaAtivaAssintomatico',
#        '_source.dataSegundaReforcoDose',
#        '_source.codigoTriagemPopulacaoEspecifica', '_source.condicoes',
#        '_source.codigoDosesVacina', '_source.idCollection',
#        '_source.estadoTeste', '_source.codigoLocalRealizacaoTestagem',
#        '_source.outroAntiviral', '_source.dataSegundaDose',
#        '_source.codigoContemComunidadeTradicional', '_source.tipoTeste',
#        '_source.racaCor', '_source.codigoRecebeuVacina',
#        '_source.dataPrimeiraDose', '_source.dataTeste',
#        '_source.registroAtual', '_source.dataNotificacao',
#        '_source.dataInicioSintomas', '_source.municipioNotificacao',
#        '_source.testes', '_source.idade',
#        '_source.resultadoTesteSorologicoTotais',
#        '_source.codigoEstrategiaCovid', '_source.outrosSintomas',
#        '_source.codigoQualAntiviral', '_source.estrangeiro',
#        '_source.resultadoTesteSorologicoIgA', '_source.sexo',
#        '_source.sintomas'],
#       dtype='object')

# %%
df_bra['_source.sintomas']
# Out:
# 0       Dor de Cabeça, Dor de Garganta, Coriza
# 1        Dor de Cabeça, Febre, Dor de Garganta
# 2                                Assintomático
# 3       Dor de Cabeça, Dor de Garganta, Outros
# 4               Coriza, Tosse, Dor de Garganta
#                          ...
# 9995                      Coriza, Tosse, Febre
# 9996                       Tosse,Dor de Cabeça
# 9997                     Coriza, Dor de Cabeça
# 9998                  Dor de Garganta,Dispneia
# 9999                             Assintomático
# Name: _source.sintomas, Length: 10000, dtype: object

# %%
import re

# Separar os valores da coluna 'sintomas' usando regex
df_bra['_source.sintomas'] = df_bra['_source.sintomas'].str.split(r',\s|,')

# Transformar a coluna em uma coluna de lista e separá-la em múltiplas linhas
df_bra = df_bra.explode('_source.sintomas')

# %%
df_bra['_source.sintomas'].value_counts()
# Out:
# Tosse                    4628
# Coriza                   3729
# Dor de Cabeça            3500
# Dor de Garganta          3170
# Febre                    3118
# Assintomático            2458
# Outros                   1806
# Dispneia                  810
# Distúrbios Gustativos     349
# Distúrbios Olfativos      274
# Dispineia                   2
# Name: _source.sintomas, dtype: int64

# %%
df_bra['_source.sintomas'] = df_bra['_source.sintomas'].replace({'Dispineia': 'Dispneia'})

# %%
df_bra['_source.sintomas'].value_counts()
# Out:
# Tosse                    4628
# Coriza                   3729
# Dor de Cabeça            3500
# Dor de Garganta          3170
# Febre                    3118
# Assintomático            2458
# Outros                   1806
# Dispneia                  812
# Distúrbios Gustativos     349
# Distúrbios Olfativos      274
# Name: _source.sintomas, dtype: int64
