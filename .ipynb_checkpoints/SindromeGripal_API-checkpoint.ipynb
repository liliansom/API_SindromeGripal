# %% [markdown]
# ## 1. Definição do Problema

# %% [markdown]
# A realização de notificações de Síndromes Gripais são obrigatórias para todos os casos suspeitos de Covid-19 e devem ser enviadas até 24 horas após a ocorrência de suspeita ou confirmação de doença, agravo ou evento de saúde pública.
#
# Os dados utilizados neste estudo são oriundos do sistema e-SUS NOTIFICA, que foi desenvolvido para registro de casos de Síndrome Gripal suspeitos de Covid-19, e contém dados referentes ao local de residência do paciente (campos: estado, município), independentemente de terem sido notificados em outro estado ou município (Campos: estadoNotificação, municípioNotificação), além de demográficos e clínicos epidemiológicos dos casos.

# %% [markdown]
# ### Questões Principais:<br>
# <li> Quantas são as notificações dos casos de síndrome gripal neste momento: no Brasil e em São Paulo?</li>
#
# ### Questões secundárias:<br>
# <li> Quais são os principais testes para detecção de COVID utilizados no país?</li>
# <li> Quais são os principais sintomas listados na notificação dos casos?</li>
# <li> Está ocorrendo um aumento dos casos de Covid-19 no Brasil?</li>

# %% [markdown]
# ## 2. Obtenção dos Dados
# Iremos realizar a importação das bibliotecas que serão utilizadas e, também, a ingestão da API locada no ElasticSearch com os dados de Notificações de Síndromes Gripais do Brasil.

# %%
import requests
import pandas as pd
import json
import datetime
import matplotlib.pyplot as plt
from datetime import date

# %matplotlib inline

# %%
# URL com Todos os Estados, /count
url = 'https://elasticsearch-saps.saude.gov.br/desc-esus-notifica-estado-*/_count'
auth = ('user-public-notificacoes', 'Za4qNXdyQNSa9YaA')

# Notificações BR
r_br = requests.get(url, auth=auth)

if r_br.status_code == 200:
    data_br = r_br.json()
else:
    print(f"Erro na solicitação: {r_br.status_code}")

# %%
# URL com estado de SP, /count
url_sp = 'https://elasticsearch-saps.saude.gov.br/desc-esus-notifica-estado-sp/_count'
auth = ('user-public-notificacoes', 'Za4qNXdyQNSa9YaA')

# Notificações SP

r_sp = requests.get(url_sp, auth=auth)

if r_sp.status_code == 200:
    data_sp = r_sp.json()
else:
    print(f"Erro na solicitação: {r_sp.status_code}")

# %%
# Importação BR Sintomas
# URL com Todos os Estados, /search, scroll (sintomas)
url_sint = "https://elasticsearch-saps.saude.gov.br/desc-esus-notifica-estado-*/_search?scroll=1m"

payload = json.dumps({
  "size": 10000,
  "_source": [
    "sintomas"
  ],
  "query": {
    "bool": {
      "filter": {
        "exists": {
          "field": "sintomas"
        }
      }
    }
  }
})
headers = {
  'Authorization': 'Basic dXNlci1wdWJsaWMtbm90aWZpY2Fjb2VzOlphNHFOWGR5UU5TYTlZYUE=',
  'Content-Type': 'application/json'
}

r_sint_br = requests.request("POST", url_sint, headers=headers, data=payload)

if r_sint_br.status_code == 200:
    data_bra = r_sint_br.json()
else:
    print(f"Erro na solicitação: {r_sint_br.status_code}")

# %%
#URL com todos os Estados, /search (testes e diário)
url_testes = "https://elasticsearch-saps.saude.gov.br/desc-esus-notifica-estado-*/_search"

# Importação Testes BR
payload = json.dumps({
  "track_total_hits": True,
  "size": 0,
  "query": {
    "term": {
      "registroAtual": {
        "value": True
      }
    }
  },
  "aggs": {
    "TopTestes": {
      "terms": {
        "field": "testes.tipoTeste.keyword",
        "size": 10
      }
    }
  }
})
headers = {
  'Authorization': 'Basic dXNlci1wdWJsaWMtbm90aWZpY2Fjb2VzOlphNHFOWGR5UU5TYTlZYUE=',
  'Content-Type': 'application/json'
}

r_testes_br = requests.request("POST", url_testes, headers=headers, data=payload)

if r_testes_br.status_code == 200:
    data_testes = r_testes_br.json()
else:
    print(f"Erro na solicitação: {r_testes_br.status_code}")

# %%
#URL com todos os Estados, /search (testes e diário)
url_testes = "https://elasticsearch-saps.saude.gov.br/desc-esus-notifica-estado-*/_search"

# Importação diário BR
payload = json.dumps({
  "track_total_hits": True,
  "size": 0,
  "query": {
    "bool": {
      "filter": [
        {
          "range": {
            "@timestamp": {
              "gte": "2021-08-20T00:00:00Z",
              "lte": "now",
              "time_zone": "-03:00"
            }
          }
        },
        {
          "term": {
            "registroAtual": {
              "value": True
            }
          }
        }
      ]
    }
  },
  "aggs": {
    "AtualizacaoDia": {
      "date_histogram": {
        "field": "@timestamp",
        "interval": "day"
      }
    }
  }
})
headers = {
  'Authorization': 'Basic dXNlci1wdWJsaWMtbm90aWZpY2Fjb2VzOlphNHFOWGR5UU5TYTlZYUE=',
  'Content-Type': 'application/json'
}

r_dia_br = requests.request("GET", url_testes, headers=headers, data=payload)

if r_dia_br.status_code == 200:
    data_dias = r_dia_br.json()
else:
    print(f"Erro na solicitação: {r_dia_br.status_code}")

# %% [markdown]
# ## 3. Exploração dos Dados e 4. Preparação dos Dados

# %% [markdown]
# ### Total de notificações

# %%
data_br = pd.json_normalize(data_br)

# %%
print(f"O total de notificações no Brasil é de {data_br['count'][0]}.")
# Out:
# O total de notificações no Brasil é de 127564986.

# %%
data_sp = pd.json_normalize(data_sp)
print(f"O total de notificações no estado de São Paulo é de {data_sp['count'][0]}.")
# Out:
# O total de notificações no estado de São Paulo é de 37255626.

# %% [markdown]
# ### Sintomas

# %%
data_bra
# Out:
# {'_scroll_id': 'FGluY2x1ZGVfY29udGV4dF91dWlkDnF1ZXJ5VGhlbkZldGNoBBZPcERLa3BBUlRYcUp0aUpvZXdaOTdRAAAAAAD7Ln0Wd0h6RldEczFTcmlSYnBTUklla2s1URZzVDc2YkxOYVFiMkVfQ2pDUWtVMklnAAAAAAOf_dgWeGZPSk8tUmFUaEMyb251ZmthbjBnURYweVFqS3pDV1NtSzRRb0tCM3hnemFBAAAAAAEkE1EWWmxsWTg0NkZSSmVkczdZWTJpemZTURZGMTZGT1pBMFRrMnUwOTVpaDNlZmlBAAAAAATRicwWVTBiRW5JWGhTLWFkQWxFWHZYR1p0UQ==',
#  'took': 3089,
#  'timed_out': False,
#  '_shards': {'total': 4, 'successful': 4, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 127395989, 'relation': 'eq'},
#   'max_score': 0.0,
#   'hits': [{'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '9yV1PEJdVI',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'WWrjknLqFa',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'pj50f1uGGA',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Dispneia, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'we139P3eYt',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Tosse, Febre, Dor de Garganta, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '4lIBQxiGNh',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Distúrbios Gustativos, Tosse, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'gKJ0h0dgoN',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'CaXWNRSwun',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'Tgl6083uXL',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'kzdV5QJleV',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Dor de Garganta, Coriza'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '5jNM4lDcp4',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '20EvLceEHT',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Tosse, Distúrbios Gustativos'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'cDarNTfhMv',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'c9trnD4inT',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'wp3ums4Dcb',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça, Febre, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '3CG0rq7ewu',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '2Ouf3Q9G2K',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'lw3oXb9PbB',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '2wh35dFF6Z',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'M9gy1MROe7',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'snzrO3ow4z',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça, Febre, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'jOGUdIjrVt',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Febre, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'lf9M4uE5Az',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'Mk1XIdla2B',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'RzfAdD6i4W',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Tosse, Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'Mtc3vFsnHc',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Outros, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'aJK6UA47GW',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'rgtXcdYV7h',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse, Febre, Dispneia, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'IJctkS6rQJ',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'e4qyUQ8WAg',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Febre, Dispneia'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'AMFMbUQOvR',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'nOgQAE8Jak',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Dor de Garganta, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'aeAS9O1IW9',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Tosse, Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'BcFOM8TqPJ',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Dispneia'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'jTwqYoJ7cP',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'zRpAtUdU7z',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '3dfDIqHkT3',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'ulMAbnyOV8',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'si3AetithW',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'TsWiWh8YlB',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Distúrbios Gustativos, Dor de Cabeça, Tosse, Dor de Garganta, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'URJ2GGoqeQ',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'Puiv7c3cAJ',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'jHdyrc6DYE',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça, Febre, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'OscUolDyuz',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'IE1tp2q8DL',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'FWAk22ylEz',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'f6O9fETEmX',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'jQHcQ06TCM',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Febre, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'iyX7Iiq9G5',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'pWh9aqDGky',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'drhqjUdaSC',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'Y97ftaoFDf',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'blidOR2yIu',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'qLOLzCIzIz',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'WjC6DQ7DSV',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'QH2Qg6ScpA',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Febre, Dor de Garganta, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'Lv8jaDBgjh',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Distúrbios Olfativos, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'R2zWH5fBht',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'Y87G8PrxOZ',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse, Febre, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'a6wcjn5oKZ',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Garganta, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'tY6muvTzUU',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'AVoG2p6GVM',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Febre, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '78mJ49afrK',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'n2gVWSoUCe',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'h5eyPyhx4s',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Tosse, Dor de Garganta, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'MjKSIUAMqB',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Distúrbios Gustativos, Dor de Cabeça, Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'bDKTlcELoD',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'M5zugAZHvg',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'u3RV8ZlYoq',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Coriza'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'fcVYPyTCET',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Tosse, Febre, Coriza'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '1z01judB2U',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'gobUjdKgjU',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '
',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '0TCbcVdDDz',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Tosse, Febre, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'LnH08ijubv',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'QctW7dzfvo',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'Jm82Yyrvqs',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Tosse, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'xJsetiN8Qb',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'xEyzZGloxe',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Distúrbios Olfativos, Dor de Cabeça, Tosse, Febre, Dor de Garganta, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '7NzlCGY9BD',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Garganta, Coriza'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'HwBn4G20ac',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Tosse, Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '17YnXHMioz',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse, Dor de Garganta, Outros, Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'dMQC1IWD6u',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Tosse, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'OaNF4D9iOi',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Febre, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'RjOFkRjzsH',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Febre, Dor de Garganta, Coriza'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'qRUe1VmNJf',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse, Outros, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'g6S7F5kq6A',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Febre, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'cjyfyVQvXN',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Febre, Coriza'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'ryJgOrgDbE',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'wbi0nzA8Kc',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '8ifYJtHexR',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse, Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'qyqcTwNpFz',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'gjQlCzCs46',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse, Dor de Garganta, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'MU6KRE9Nk4',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Febre, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'TgguYxenDo',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'cEmWIW7a8d',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Febre, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'gaj2Qhi5KB',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Garganta, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'vHRWABgpIS',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse, Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'HgX1Acsete',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse, Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'Bp1e0vS3oJ',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Febre, Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '8MndIy51SY',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'oBg9QW3JqP',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Tosse, Dor de Garganta, Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'zdD4w2cRIY',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Tosse, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'sboVwhy2MH',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Tosse, Dor de Garganta, Coriza'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'WR2JHSdFuJ',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'Jr3CF9hPSl',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'palzD8hhDL',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'vgcLGgX7bx',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dispneia'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '5u1YJEzEXE',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dispneia'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'UAmtLb7Mhw',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'ftz4tXPNl2',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse, Febre, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'atzxCrFdw5',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Febre, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'j1HjUKJUN6',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Tosse, Coriza'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'zUW42PwWFC',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Tosse, Febre, Dor de Garganta, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'no4SrwRFHy',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Garganta, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 's491XrreMH',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '1MZyoSgjJD',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'BDxnSV8fea',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'j8YBngEZXW',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Febre, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'OJW6xGphuI',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Tosse, Febre, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'oEmTwdNUQu',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Febre, Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'aX8Cb2pDaR',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse, Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'hKRNHAZ2Ak',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'jEn40jtDFs',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '4P9oMZhouv',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'LCVSriTYjE',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Tosse, Febre, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'JZ7HZjcp6E',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'm4NZXXEgNu',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'KmHIG4HQOS',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '8hTl8F8NS7',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'd4MtFkEjER',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Tosse, Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '0GAMUjYLVX',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Dor de Garganta, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'esx8sHAnQr',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse, Febre, Dispneia, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'Tbon5Vwucv',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Garganta, Outros, Coriza'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'stAYGZbyv9',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Distúrbios Gustativos, Tosse, Febre, Dor de Garganta, Coriza'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'lsu1Pf9ojB',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Febre, Dor de Garganta, Coriza'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'FBAa8efJpY',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '1Ezq6apjtM',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dispneia, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '4oIL0ZEswZ',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Febre, Dor de Garganta, Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '9O8O4cDtrQ',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'PYYHIaiNco',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '6LDmhw7Ocs',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Distúrbios Olfativos, Tosse, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'jdmBJdsWUG',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'nvuwbh8dYK',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'NjQCh7uoi7',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Tosse, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'Lqr30f91G1',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Garganta, Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '07awTNJo5I',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'hiItfsbZtI',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Tosse, Dor de Garganta, Coriza'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'FZloSXsa0j',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Distúrbios Gustativos, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'zibvY810E8',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Febre, Dor de Garganta, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'f8g1Lddnve',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Febre, Dor de Garganta, Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'icOncuzziA',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '8926IlRhT6',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'fDOSiM7mXm',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'brcjtB0MW1',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Febre, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'qllvJ26th5',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Garganta, Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '8MfepYqzlU',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'q5MUvTSsHu',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Dor de Garganta, Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'iKPuYEocqx',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Tosse, Febre, Dor de Garganta, Coriza'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'R0xV02atok',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '9dCfsU4UqY',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '1eXtGXARvN',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Outros, Dor de Cabeça'}},
#  ...]

# %%
df_bra = pd.json_normalize(data_bra['hits']['hits'])

# %%
df_bra.columns
# Out:
# Index(['_index', '_type', '_id', '_score', '_source.sintomas'], dtype='object')

# %%
df_bra['_source.sintomas']
# Out:
# 0                                                   Febre
# 1                                           Assintomático
# 2                        Tosse, Dispneia, Dor de Garganta
# 3       Dor de Cabeça, Tosse, Febre, Dor de Garganta, ...
# 4             Distúrbios Gustativos, Tosse, Dor de Cabeça
#                               ...
# 9995                                      Tosse, Dispneia
# 9996                                                Tosse
# 9997                                             Dispneia
# 9998                                        Assintomático
# 9999    Coriza, Distúrbios Olfativos, Distúrbios Gusta...
# Name: _source.sintomas, Length: 10000, dtype: object

# %%
# Tratamento do dataframe sintomas

# Separar os valores da coluna 'sintomas'
df_bra['_source.sintomas'] = df_bra['_source.sintomas'].str.split(r',\s|,')

# Transformar a coluna em uma coluna de lista e separá-la em múltiplas linhas
df_bra = df_bra.explode('_source.sintomas')

# %%
# Contagem das informações de sintomas
df_bra['_source.sintomas'].value_counts()
# Out:
# Tosse                             5221
# Coriza                            4137
# Dor de Cabeça                     3915
# Febre                             3434
# Dor de Garganta                   3388
# Outros                            1948
# Assintomático                     1836
# Dispneia                           804
# Distúrbios Gustativos              351
# Distúrbios Olfativos               307
# Outros: Paciente assintomático       5
# Name: _source.sintomas, dtype: int64

# %%
# Tratamento de informações iguais
df_bra['_source.sintomas'] = df_bra['_source.sintomas'].replace({'Dispineia': 'Dispneia'})

# %%
# 
df_sintomas = df_bra['_source.sintomas'].value_counts()
df_sintomas = pd.DataFrame(df_sintomas)
display(df_sintomas)
# Out:
#                                 _source.sintomas
# Tosse                                       5221
# Coriza                                      4137
# Dor de Cabeça                               3915
# Febre                                       3434
# Dor de Garganta                             3388
# Outros                                      1948
# Assintomático                               1836
# Dispneia                                     804
# Distúrbios Gustativos                        351
# Distúrbios Olfativos                         307
# Outros: Paciente assintomático                 5

# %% [markdown]
# ### Testes

# %%
# Explorando dados testes covid - visualização das colunas
df_testes = pd.json_normalize(data_testes)
df_testes.columns
# Out:
# Index(['took', 'timed_out', '_shards.total', '_shards.successful',
#        '_shards.skipped', '_shards.failed', 'hits.total.value',
#        'hits.total.relation', 'hits.max_score', 'hits.hits',
#        'aggregations.TopTestes.doc_count_error_upper_bound',
#        'aggregations.TopTestes.sum_other_doc_count',
#        'aggregations.TopTestes.buckets'],
#       dtype='object')

# %%
# Explorando e filtrando dados testes covid 
df_buckets = pd.json_normalize(df_testes['aggregations.TopTestes.buckets'])
df_buckets
# Out:
#                                                    0  \
# 0  {'key': 'TESTE RÁPIDO - ANTÍGENO', 'doc_count'...
#
#                                           1  \
# 0  {'key': 'RT-PCR', 'doc_count': 39113804}
#
#                                                    2  \
# 0  {'key': 'TESTE RÁPIDO - ANTICORPO IgG', 'doc_c...
#
#                                                    3  \
# 0  {'key': 'TESTE SOROLÓGICO IgG', 'doc_count': 1...
#
#                                                    4  \
# 0  {'key': 'TESTE SOROLÓGICO IgM', 'doc_count': 1...
#
#                                                    5  \
# 0  {'key': 'TESTE RÁPIDO - ANTICORPO IgM', 'doc_c...
#
#                                                    6  \
# 0  {'key': 'ANTICORPOS TOTAIS', 'doc_count': 454575}
#
#                                         7  \
# 0  {'key': 'RT-LAMP', 'doc_count': 83066}
#
#                                                    8  \
# 0  {'key': 'Imunoensaio por Eletroquimioluminescê...
#
#                                                    9
# 0  {'key': 'Enzimaimunoensaio - ELISA IgM', 'doc_...

# %%
# Transformando dados em dataframe

buckets = df_testes.at[0, 'aggregations.TopTestes.buckets']
df_buckets = pd.DataFrame(columns=['key', 'doc_count'])

# Filtrando dados no dataframe e organizando colunas
for i in range(len(buckets)):
    key_valor = buckets[i]['key']
    doc_count_valor = buckets[i]['doc_count']
    df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)

display(df_buckets)
# Out:
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_8840\427931777.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_8840\427931777.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_8840\427931777.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_8840\427931777.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_8840\427931777.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_8840\427931777.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_8840\427931777.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_8840\427931777.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_8840\427931777.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_8840\427931777.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
#                                                  key doc_count
# 0                            TESTE RÁPIDO - ANTÍGENO  52623570
# 1                                             RT-PCR  39113804
# 2                       TESTE RÁPIDO - ANTICORPO IgG  18465866
# 3                               TESTE SOROLÓGICO IgG   1656389
# 4                               TESTE SOROLÓGICO IgM   1496624
# 5                       TESTE RÁPIDO - ANTICORPO IgM    806002
# 6                                  ANTICORPOS TOTAIS    454575
# 7                                            RT-LAMP     83066
# 8  Imunoensaio por Eletroquimioluminescência - EC...     61566
# 9                      Enzimaimunoensaio - ELISA IgM     47073

# %%
# Transformando dados em dataframe
buckets = df_testes.at[0, 'aggregations.TopTestes.buckets']
df_buckets = pd.DataFrame(columns=['key', 'doc_count'])

# Filtrando dados no dataframe e organizando colunas
for i in range(len(buckets)):
    key_valor = buckets[i]['key']
    doc_count_valor = buckets[i]['doc_count']
    df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)

# Inserir a data no dataframe
data = date.today().strftime('%Y-%m-%d')
df_buckets['data'] = data

# Transformar os testes em colunas e os números em linhas
df_buckets = df_buckets.pivot(index='data', columns='key', values='doc_count')

# Resetar o índice para obter a data como coluna
df_buckets = df_buckets.reset_index()

# Renomear as colunas para o nome dos testes
df_buckets.columns.name = None

# Exibir o dataframe resultante
display(df_buckets)
# Out:
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_8840\2564382661.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_8840\2564382661.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_8840\2564382661.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_8840\2564382661.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_8840\2564382661.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_8840\2564382661.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_8840\2564382661.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_8840\2564382661.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_8840\2564382661.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_8840\2564382661.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
#          data ANTICORPOS TOTAIS Enzimaimunoensaio - ELISA IgM  \
# 0  2023-04-11            454575                         47073
#
#   Imunoensaio por Eletroquimioluminescência - ECLIA IgG RT-LAMP    RT-PCR  \
# 0                                              61566      83066  39113804
#
#   TESTE RÁPIDO - ANTICORPO IgG TESTE RÁPIDO - ANTICORPO IgM  \
# 0                     18465866                       806002
#
#   TESTE RÁPIDO - ANTÍGENO TESTE SOROLÓGICO IgG TESTE SOROLÓGICO IgM
# 0                52623570              1656389              1496624

# %% [markdown]
# ## Verificação diária das Notificações

# %%
# Explorando dados de notificações diárias
data = json.loads(json.dumps(data_dias))
data
# Out:
# {'took': 5833,
#  'timed_out': False,
#  '_shards': {'total': 4, 'successful': 4, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 127259250, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []},
#  'aggregations': {'AtualizacaoDia': {'buckets': [{'key_as_string': '2022-11-21T00:00:00.000Z',
#      'key': 1668988800000,
#      'doc_count': 27637150},
#     {'key_as_string': '2022-11-22T00:00:00.000Z',
#      'key': 1669075200000,
#      'doc_count': 86016411},
#     {'key_as_string': '2022-11-23T00:00:00.000Z',
#      'key': 1669161600000,
#      'doc_count': 2739125},
#     {'key_as_string': '2022-11-24T00:00:00.000Z',
#      'key': 1669248000000,
#      'doc_count': 134376},
#     {'key_as_string': '2022-11-25T00:00:00.000Z',
#      'key': 1669334400000,
#      'doc_count': 154059},
#     {'key_as_string': '2022-11-26T00:00:00.000Z',
#      'key': 1669420800000,
#      'doc_count': 29944},
#     {'key_as_string': '2022-11-27T00:00:00.000Z',
#      'key': 1669507200000,
#      'doc_count': 17743},
#     {'key_as_string': '2022-11-28T00:00:00.000Z',
#      'key': 1669593600000,
#      'doc_count': 59772},
#     {'key_as_string': '2022-11-29T00:00:00.000Z',
#      'key': 1669680000000,
#      'doc_count': 95232},
#     {'key_as_string': '2022-11-30T00:00:00.000Z',
#      'key': 1669766400000,
#      'doc_count': 117855},
#     {'key_as_string': '2022-12-01T00:00:00.000Z',
#      'key': 1669852800000,
#      'doc_count': 153232},
#     {'key_as_string': '2022-12-02T00:00:00.000Z',
#      'key': 1669939200000,
#      'doc_count': 134350},
#     {'key_as_string': '2022-12-03T00:00:00.000Z',
#      'key': 1670025600000,
#      'doc_count': 42948},
#     {'key_as_string': '2022-12-04T00:00:00.000Z',
#      'key': 1670112000000,
#      'doc_count': 31710},
#     {'key_as_string': '2022-12-05T00:00:00.000Z',
#      'key': 1670198400000,
#      'doc_count': 131147},
#     {'key_as_string': '2022-12-06T00:00:00.000Z',
#      'key': 1670284800000,
#      'doc_count': 164066},
#     {'key_as_string': '2022-12-07T00:00:00.000Z',
#      'key': 1670371200000,
#      'doc_count': 171281},
#     {'key_as_string': '2022-12-08T00:00:00.000Z',
#      'key': 1670457600000,
#      'doc_count': 146070},
#     {'key_as_string': '2022-12-09T00:00:00.000Z',
#      'key': 1670544000000,
#      'doc_count': 74845},
#     {'key_as_string': '2022-12-10T00:00:00.000Z',
#      'key': 1670630400000,
#      'doc_count': 41604},
#     {'key_as_string': '2022-12-11T00:00:00.000Z',
#      'key': 1670716800000,
#      'doc_count': 25462},
#     {'key_as_string': '2022-12-12T00:00:00.000Z',
#      'key': 1670803200000,
#      'doc_count': 186763},
#     {'key_as_string': '2022-12-13T00:00:00.000Z',
#      'key': 1670889600000,
#      'doc_count': 135342},
#     {'key_as_string': '2022-12-14T00:00:00.000Z',
#      'key': 1670976000000,
#      'doc_count': 159327},
#     {'key_as_string': '2022-12-15T00:00:00.000Z',
#      'key': 1671062400000,
#      'doc_count': 180741},
#     {'key_as_string': '2022-12-16T00:00:00.000Z',
#      'key': 1671148800000,
#      'doc_count': 156550},
#     {'key_as_string': '2022-12-17T00:00:00.000Z',
#      'key': 1671235200000,
#      'doc_count': 41156},
#     {'key_as_string': '2022-12-18T00:00:00.000Z',
#      'key': 1671321600000,
#      'doc_count': 23151},
#     {'key_as_string': '2022-12-19T00:00:00.000Z',
#      'key': 1671408000000,
#      'doc_count': 173274},
#     {'key_as_string': '2022-12-20T00:00:00.000Z',
#      'key': 1671494400000,
#      'doc_count': 163956},
#     {'key_as_string': '2022-12-21T00:00:00.000Z',
#      'key': 1671580800000,
#      'doc_count': 154761},
#     {'key_as_string': '2022-12-22T00:00:00.000Z',
#      'key': 1671667200000,
#      'doc_count': 143818},
#     {'key_as_string': '2022-12-23T00:00:00.000Z',
#      'key': 1671753600000,
#      'doc_count': 99884},
#     {'key_as_string': '2022-12-24T00:00:00.000Z',
#      'key': 1671840000000,
#      'doc_count': 23592},
#     {'key_as_string': '2022-12-25T00:00:00.000Z',
#      'key': 1671926400000,
#      'doc_count': 12639},
#     {'key_as_string': '2022-12-26T00:00:00.000Z',
#      'key': 1672012800000,
#      'doc_count': 129564},
#     {'key_as_string': '2022-12-27T00:00:00.000Z',
#      'key': 1672099200000,
#      'doc_count': 152614},
#     {'key_as_string': '2022-12-28T00:00:00.000Z',
#      'key': 1672185600000,
#      'doc_count': 136914},
#     {'key_as_string': '2022-12-29T00:00:00.000Z',
#      'key': 1672272000000,
#      'doc_count': 120075},
#     {'key_as_string': '2022-12-30T00:00:00.000Z',
#      'key': 1672358400000,
#      'doc_count': 73859},
#     {'key_as_string': '2022-12-31T00:00:00.000Z',
#      'key': 1672444800000,
#      'doc_count': 19388},
#     {'key_as_string': '2023-01-01T00:00:00.000Z',
#      'key': 1672531200000,
#      'doc_count': 9385},
#     {'key_as_string': '2023-01-02T00:00:00.000Z',
#      'key': 1672617600000,
#      'doc_count': 103635},
#     {'key_as_string': '2023-01-03T00:00:00.000Z',
#      'key': 1672704000000,
#      'doc_count': 124810},
#     {'key_as_string': '2023-01-04T00:00:00.000Z',
#      'key': 1672790400000,
#      'doc_count': 129261},
#     {'key_as_string': '2023-01-05T00:00:00.000Z',
#      'key': 1672876800000,
#      'doc_count': 126059},
#     {'key_as_string': '2023-01-06T00:00:00.000Z',
#      'key': 1672963200000,
#      'doc_count': 107261},
#     {'key_as_string': '2023-01-07T00:00:00.000Z',
#      'key': 1673049600000,
#      'doc_count': 27665},
#     {'key_as_string': '2023-01-08T00:00:00.000Z',
#      'key': 1673136000000,
#      'doc_count': 15565},
#     {'key_as_string': '2023-01-09T00:00:00.000Z',
#      'key': 1673222400000,
#      'doc_count': 126205},
#     {'key_as_string': '2023-01-10T00:00:00.000Z',
#      'key': 1673308800000,
#      'doc_count': 115289},
#     {'key_as_string': '2023-01-11T00:00:00.000Z',
#      'key': 1673395200000,
#      'doc_count': 112007},
#     {'key_as_string': '2023-01-12T00:00:00.000Z',
#      'key': 1673481600000,
#      'doc_count': 105771},
#     {'key_as_string': '2023-01-13T00:00:00.000Z',
#      'key': 1673568000000,
#      'doc_count': 96681},
#     {'key_as_string': '2023-01-14T00:00:00.000Z',
#      'key': 1673654400000,
#      'doc_count': 24208},
#     {'key_as_string': '2023-01-15T00:00:00.000Z',
#      'key': 1673740800000,
#      'doc_count': 12136},
#     {'key_as_string': '2023-01-16T00:00:00.000Z',
#      'key': 1673827200000,
#      'doc_count': 105664},
#     {'key_as_string': '2023-01-17T00:00:00.000Z',
#      'key': 1673913600000,
#      'doc_count': 107250},
#     {'key_as_string': '2023-01-18T00:00:00.000Z',
#      'key': 1674000000000,
#      'doc_count': 101536},
#     {'key_as_string': '2023-01-19T00:00:00.000Z',
#      'key': 1674086400000,
#      'doc_count': 102075},
#     {'key_as_string': '2023-01-20T00:00:00.000Z',
#      'key': 1674172800000,
#      'doc_count': 88967},
#     {'key_as_string': '2023-01-21T00:00:00.000Z',
#      'key': 1674259200000,
#      'doc_count': 25248},
#     {'key_as_string': '2023-01-22T00:00:00.000Z',
#      'key': 1674345600000,
#      'doc_count': 14127},
#     {'key_as_string': '2023-01-23T00:00:00.000Z',
#      'key': 1674432000000,
#      'doc_count': 109623},
#     {'key_as_string': '2023-01-24T00:00:00.000Z',
#      'key': 1674518400000,
#      'doc_count': 99036},
#     {'key_as_string': '2023-01-25T00:00:00.000Z',
#      'key': 1674604800000,
#      'doc_count': 93825},
#     {'key_as_string': '2023-01-26T00:00:00.000Z',
#      'key': 1674691200000,
#      'doc_count': 95109},
#     {'key_as_string': '2023-01-27T00:00:00.000Z',
#      'key': 1674777600000,
#      'doc_count': 91591},
#     {'key_as_string': '2023-01-28T00:00:00.000Z',
#      'key': 1674864000000,
#      'doc_count': 26827},
#     {'key_as_string': '2023-01-29T00:00:00.000Z',
#      'key': 1674950400000,
#      'doc_count': 13333},
#     {'key_as_string': '2023-01-30T00:00:00.000Z',
#      'key': 1675036800000,
#      'doc_count': 100928},
#     {'key_as_string': '2023-01-31T00:00:00.000Z',
#      'key': 1675123200000,
#      'doc_count': 91854},
#     {'key_as_string': '2023-02-01T00:00:00.000Z',
#      'key': 1675209600000,
#      'doc_count': 92288},
#     {'key_as_string': '2023-02-02T00:00:00.000Z',
#      'key': 1675296000000,
#      'doc_count': 91130},
#     {'key_as_string': '2023-02-03T00:00:00.000Z',
#      'key': 1675382400000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-04T00:00:00.000Z',
#      'key': 1675468800000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-05T00:00:00.000Z',
#      'key': 1675555200000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-06T00:00:00.000Z',
#      'key': 1675641600000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-07T00:00:00.000Z',
#      'key': 1675728000000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-08T00:00:00.000Z',
#      'key': 1675814400000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-09T00:00:00.000Z',
#      'key': 1675900800000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-10T00:00:00.000Z',
#      'key': 1675987200000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-11T00:00:00.000Z',
#      'key': 1676073600000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-12T00:00:00.000Z',
#      'key': 1676160000000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-13T00:00:00.000Z',
#      'key': 1676246400000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-14T00:00:00.000Z',
#      'key': 1676332800000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-15T00:00:00.000Z',
#      'key': 1676419200000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-16T00:00:00.000Z',
#      'key': 1676505600000,
#      'doc_count': 79857},
#     {'key_as_string': '2023-02-17T00:00:00.000Z',
#      'key': 1676592000000,
#      'doc_count': 84108},
#     {'key_as_string': '2023-02-18T00:00:00.000Z',
#      'key': 1676678400000,
#      'doc_count': 20975},
#     {'key_as_string': '2023-02-19T00:00:00.000Z',
#      'key': 1676764800000,
#      'doc_count': 12892},
#     {'key_as_string': '2023-02-20T00:00:00.000Z',
#      'key': 1676851200000,
#      'doc_count': 22509},
#     {'key_as_string': '2023-02-21T00:00:00.000Z',
#      'key': 1676937600000,
#      'doc_count': 18358},
#     {'key_as_string': '2023-02-22T00:00:00.000Z',
#      'key': 1677024000000,
#      'doc_count': 51562},
#     {'key_as_string': '2023-02-23T00:00:00.000Z',
#      'key': 1677110400000,
#      'doc_count': 123159},
#     {'key_as_string': '2023-02-24T00:00:00.000Z',
#      'key': 1677196800000,
#      'doc_count': 110634},
#     {'key_as_string': '2023-02-25T00:00:00.000Z',
#      'key': 1677283200000,
#      'doc_count': 27243},
#     {'key_as_string': '2023-02-26T00:00:00.000Z',
#      'key': 1677369600000,
#      'doc_count': 34696},
#     {'key_as_string': '2023-02-27T00:00:00.000Z',
#      'key': 1677456000000,
#      'doc_count': 105859},
#     {'key_as_string': '2023-02-28T00:00:00.000Z',
#      'key': 1677542400000,
#      'doc_count': 113137},
#     {'key_as_string': '2023-03-01T00:00:00.000Z',
#      'key': 1677628800000,
#      'doc_count': 111650},
#     {'key_as_string': '2023-03-02T00:00:00.000Z',
#      'key': 1677715200000,
#      'doc_count': 100347},
#     {'key_as_string': '2023-03-03T00:00:00.000Z',
#      'key': 1677801600000,
#      'doc_count': 90062},
#     {'key_as_string': '2023-03-04T00:00:00.000Z',
#      'key': 1677888000000,
#      'doc_count': 39712},
#     {'key_as_string': '2023-03-05T00:00:00.000Z',
#      'key': 1677974400000,
#      'doc_count': 15922},
#     {'key_as_string': '2023-03-06T00:00:00.000Z',
#      'key': 1678060800000,
#      'doc_count': 111560},
#     {'key_as_string': '2023-03-07T00:00:00.000Z',
#      'key': 1678147200000,
#      'doc_count': 111909},
#     {'key_as_string': '2023-03-08T00:00:00.000Z',
#      'key': 1678233600000,
#      'doc_count': 90211},
#     {'key_as_string': '2023-03-09T00:00:00.000Z',
#      'key': 1678320000000,
#      'doc_count': 93025},
#     {'key_as_string': '2023-03-10T00:00:00.000Z',
#      'key': 1678406400000,
#      'doc_count': 100639},
#     {'key_as_string': '2023-03-11T00:00:00.000Z',
#      'key': 1678492800000,
#      'doc_count': 33663},
#     {'key_as_string': '2023-03-12T00:00:00.000Z',
#      'key': 1678579200000,
#      'doc_count': 14647},
#     {'key_as_string': '2023-03-13T00:00:00.000Z',
#      'key': 1678665600000,
#      'doc_count': 115250},
#     {'key_as_string': '2023-03-14T00:00:00.000Z',
#      'key': 1678752000000,
#      'doc_count': 102817},
#     {'key_as_string': '2023-03-15T00:00:00.000Z',
#      'key': 1678838400000,
#      'doc_count': 116051},
#     {'key_as_string': '2023-03-16T00:00:00.000Z',
#      'key': 1678924800000,
#      'doc_count': 109190},
#     {'key_as_string': '2023-03-17T00:00:00.000Z',
#      'key': 1679011200000,
#      'doc_count': 100337},
#     {'key_as_string': '2023-03-18T00:00:00.000Z',
#      'key': 1679097600000,
#      'doc_count': 38277},
#     {'key_as_string': '2023-03-19T00:00:00.000Z',
#      'key': 1679184000000,
#      'doc_count': 33991},
#     {'key_as_string': '2023-03-20T00:00:00.000Z',
#      'key': 1679270400000,
#      'doc_count': 104159},
#     {'key_as_string': '2023-03-21T00:00:00.000Z',
#      'key': 1679356800000,
#      'doc_count': 100299},
#     {'key_as_string': '2023-03-22T00:00:00.000Z',
#      'key': 1679443200000,
#      'doc_count': 118451},
#     {'key_as_string': '2023-03-23T00:00:00.000Z',
#      'key': 1679529600000,
#      'doc_count': 110098},
#     {'key_as_string': '2023-03-24T00:00:00.000Z',
#      'key': 1679616000000,
#      'doc_count': 91373},
#     {'key_as_string': '2023-03-25T00:00:00.000Z',
#      'key': 1679702400000,
#      'doc_count': 28181},
#     {'key_as_string': '2023-03-26T00:00:00.000Z',
#      'key': 1679788800000,
#      'doc_count': 15243},
#     {'key_as_string': '2023-03-27T00:00:00.000Z',
#      'key': 1679875200000,
#      'doc_count': 118925},
#     {'key_as_string': '2023-03-28T00:00:00.000Z',
#      'key': 1679961600000,
#      'doc_count': 114153},
#     {'key_as_string': '2023-03-29T00:00:00.000Z',
#      'key': 1680048000000,
#      'doc_count': 99183},
#     {'key_as_string': '2023-03-30T00:00:00.000Z',
#      'key': 1680134400000,
#      'doc_count': 123838},
#     {'key_as_string': '2023-03-31T00:00:00.000Z',
#      'key': 1680220800000,
#      'doc_count': 85075},
#     {'key_as_string': '2023-04-01T00:00:00.000Z',
#      'key': 1680307200000,
#      'doc_count': 36047},
#     {'key_as_string': '2023-04-02T00:00:00.000Z',
#      'key': 1680393600000,
#      'doc_count': 16145},
#     {'key_as_string': '2023-04-03T00:00:00.000Z',
#      'key': 1680480000000,
#      'doc_count': 100883},
#     {'key_as_string': '2023-04-04T00:00:00.000Z',
#      'key': 1680566400000,
#      'doc_count': 108986},
#     {'key_as_string': '2023-04-05T00:00:00.000Z',
#      'key': 1680652800000,
#      'doc_count': 96686},
#     {'key_as_string': '2023-04-06T00:00:00.000Z',
#      'key': 1680739200000,
#      'doc_count': 61098},
#     {'key_as_string': '2023-04-07T00:00:00.000Z',
#      'key': 1680825600000,
#      'doc_count': 40206},
#     {'key_as_string': '2023-04-08T00:00:00.000Z',
#      'key': 1680912000000,
#      'doc_count': 20852},
#     {'key_as_string': '2023-04-09T00:00:00.000Z',
#      'key': 1680998400000,
#      'doc_count': 12634},
#     {'key_as_string': '2023-04-10T00:00:00.000Z',
#      'key': 1681084800000,
#      'doc_count': 104235},
#     {'key_as_string': '2023-04-11T00:00:00.000Z',
#      'key': 1681171200000,
#      'doc_count': 123177},
#     {'key_as_string': '2023-04-12T00:00:00.000Z',
#      'key': 1681257600000,
#      'doc_count': 2975}]}}}

# %%
# Explorando e filtrando dados de notificações diárias
df_dias = pd.json_normalize(data['aggregations']['AtualizacaoDia']['buckets'])
df_dias
# Out:
#                 key_as_string            key  doc_count
# 0    2022-11-21T00:00:00.000Z  1668988800000   27637150
# 1    2022-11-22T00:00:00.000Z  1669075200000   86016411
# 2    2022-11-23T00:00:00.000Z  1669161600000    2739125
# 3    2022-11-24T00:00:00.000Z  1669248000000     134376
# 4    2022-11-25T00:00:00.000Z  1669334400000     154059
# ..                        ...            ...        ...
# 138  2023-04-08T00:00:00.000Z  1680912000000      20852
# 139  2023-04-09T00:00:00.000Z  1680998400000      12634
# 140  2023-04-10T00:00:00.000Z  1681084800000     104235
# 141  2023-04-11T00:00:00.000Z  1681171200000     123177
# 142  2023-04-12T00:00:00.000Z  1681257600000       2975
#
# [143 rows x 3 columns]

# %%
# Explorando e filtrando dados de notificações diárias - criação de dicionário
dados = []

for i in range(len(df_dias)):
    key_valor = df_dias.iloc[i]['key_as_string']
    doc_count_valor = df_dias.iloc[i]['doc_count']
    dados.append({'Data': key_valor, 'Total de Notificações': doc_count_valor})

# Criando um novo DataFrame a partir da lista de dicionários
df_notificacoes = pd.DataFrame(dados)

# Tratando coluna Data para datetime
df_notificacoes['Data'] = pd.to_datetime(df_notificacoes['Data'])
df_notificacoes['Data'] = df_notificacoes['Data'].dt.strftime('%d-%m-%Y')


display(df_notificacoes)
df_notificacoes.to_csv("notificacoes_diarias.csv")
# Out:
#            Data  Total de Notificações
# 0    21-11-2022               27637150
# 1    22-11-2022               86016411
# 2    23-11-2022                2739125
# 3    24-11-2022                 134376
# 4    25-11-2022                 154059
# ..          ...                    ...
# 138  08-04-2023                  20852
# 139  09-04-2023                  12634
# 140  10-04-2023                 104235
# 141  11-04-2023                 123177
# 142  12-04-2023                   2975
#
# [143 rows x 2 columns]

# %%
df_notificacoes.plot(x='Data', y='Total de Notificações', kind='line')
# Out:
# <Axes: xlabel='Data'>
