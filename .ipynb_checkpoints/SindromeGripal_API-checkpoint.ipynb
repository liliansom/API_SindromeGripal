# %%
import requests
import pandas as pd
import json
import datetime
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Total de contagem de notificações no Brasil
url = 'https://elasticsearch-saps.saude.gov.br/desc-esus-notifica-estado-*/_count'
auth = ('user-public-notificacoes', 'Za4qNXdyQNSa9YaA')

response = requests.get(url, auth=auth)

if response.status_code == 200:
    data_br = response.json()
else:
    print(f"Erro na solicitação: {response.status_code}")

# %%
data_br = pd.json_normalize(data_br)

# %%
print(f"O total de notificações no Brasil é de {data_br['count'][0]}.")
# Out:
# O total de notificações no Brasil é de 127337164.

# %%
# Total de contagem de notificações no Brasil
url = 'https://elasticsearch-saps.saude.gov.br/desc-esus-notifica-estado-sp/_count'
auth = ('user-public-notificacoes', 'Za4qNXdyQNSa9YaA')

response = requests.get(url, auth=auth)

if response.status_code == 200:
    data_sp = response.json()
else:
    print(f"Erro na solicitação: {response.status_code}")

# %%
data_sp = pd.json_normalize(data_sp)
print(f"O total de notificações no estado de São Paulo é de {data_sp['count'][0]}.")
# Out:
# O total de notificações no estado de São Paulo é de 37180578.

# %%
import requests
import json

url = "https://elasticsearch-saps.saude.gov.br/desc-esus-notifica-estado-*/_search?scroll=1m"

payload = json.dumps({
  "size": 10000,
  "_source": [
    "sintomas"
  ],
  "query": {
    "bool": {
      "filter": {
        "exists": {
          "field": "sintomas"
        }
      }
    }
  }
})
headers = {
  'Authorization': 'Basic dXNlci1wdWJsaWMtbm90aWZpY2Fjb2VzOlphNHFOWGR5UU5TYTlZYUE=',
  'Content-Type': 'application/json'
}

response = requests.request("POST", url, headers=headers, data=payload)

if response.status_code == 200:
    data_bra = response.json()
else:
    print(f"Erro na solicitação: {response.status_code}")

# %%
data_bra
# Out:
# {'_scroll_id': '',
#  'took': 3384,
#  'timed_out': False,
#  '_shards': {'total': 4, 'successful': 4, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 127168166, 'relation': 'eq'},
#   'max_score': 0.0,
#   'hits': [{'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'T5yCUhq3r5',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Febre, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'LTzNRETGx1',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Garganta, Distúrbios Gustativos, Distúrbios Olfativos'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'HtAY14BMAu',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'OP23Bk4Xtg',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Febre, Dor de Garganta, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'KOJdRKpYEh',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'tQ3icmiIqA',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'snCZuBhyoq',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '5xnouVMMJq',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'LiWsbJpViZ',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'okKoCO5CBd',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '27ajxXvAvn',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Febre, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'u9esONLJvv',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'dLOHQ1a0pZ',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Dor de Garganta, Outros, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '1JQaOoAAwO',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'sAzk2lj2PD',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'jkTlvw8TI4',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'dDes6W9zYF',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Febre, Outros, Dispneia'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'BMkSEHRS5g',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Outros, Coriza'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'r0F8sXbP3X',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Febre, Dor de Garganta, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '2GsOr15BOc',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Tosse, Outros, Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'qMZNOQ9fxs',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Febre, Dispneia'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'GviF1OMAWW',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'YTLuid0XSS',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse, Febre, Dispneia, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'XLjRz0Hk7H',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'EH9pRyRJtN',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'pKHL262AEr',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'blEBiAv3tF',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'bOan7la2aH',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '8NT0SlzTas',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Febre, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'tEEP5Fw9Ce',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Garganta, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'CGWyqRmg6x',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'tvDwGRQzjA',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'xFQv3hzhYP',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'QWQjvXABfx',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '8fDtEUGurE',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 's5FnQYTddZ',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Dor de Garganta, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'kzqBV6i19S',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Distúrbios Olfativos, Distúrbios Gustativos, Dor de Cabeça, Tosse, Febre, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'PyvsnzpOtx',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'DqKZgoWoBS',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Dor de Garganta, Coriza'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '3WAaKsVot8',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Febre, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'Fs6kTHghwa',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Coriza'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'qBKAvynpnU',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse, Febre, Dor de Garganta, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'cuXgbcEFDe',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'i4BE9VsPKD',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Febre, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'zfuh4SxMCN',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '10bsK4iaVc',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'u97it2DzRx',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'NbCKg51F2D',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'UzCDKHkmPD',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Garganta, Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'oFS6aTMVUT',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'IQnyY8gBlG',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'm2IZAYX1eK',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '0Rw0wPqFhC',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Febre, Coriza'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'OuLsBrYngR',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'Ez4QHkxFEA',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'DUI77UfVkK',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Garganta, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'nAOrIGp1bt',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Garganta, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'faLDbHFRmu',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'uf9G00U5B9',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse, Febre, Dor de Garganta, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'BzZEAwXen2',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Febre, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'HSu8J4dPwd',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Dor de Garganta, Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'mRiFq83ny2',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dispneia, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '1GZi6kNOho',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '3qySL6bBpH',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'aPX2jndPbG',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Febre, Dor de Garganta, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'dIhYF01sBq',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'I3g2JNLzvS',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Dispneia, Dor de Garganta, Coriza'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'fDX8FvqYtR',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Garganta, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'yOsM1iUtON',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'LHl9uIiPsg',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça, Febre, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'raYAQTBD6w',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '65wJJWCYcl',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'AaXQJrazo0',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'ZalMjgnsO8',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse, Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'DHgDW79XJt',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'eejKcgzJoh',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'CLG6NmSA2F',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Coriza'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'zsuJHiyHnU',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'p3gcPQBPb2',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'a1txhxYFsV',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'Fp2nIF8RS4',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'b2Tw5oTId2',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'IbaePJFfEJ',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Febre, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'cI5lkfRKbL',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'aaaleqdRkC',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '590F6RrbV1',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'DmCMVF5GTA',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Febre, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'rS5iIzJkn0',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Distúrbios Gustativos, Tosse, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'v59koC12eB',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Dispneia, Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'TRkFF9N2Ua',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Coriza'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '
# Out:
# Index(['_index', '_type', '_id', '_score', '_source.sintomas'], dtype='object')

# %%
df_bra['_source.sintomas']
# Out:
# 0                            Dor de Cabeça, Febre, Outros
# 1       Dor de Garganta, Distúrbios Gustativos, Distúr...
# 2                                 Coriza, Dor de Garganta
# 3                           Febre, Dor de Garganta, Tosse
# 4                                           Assintomático
#                               ...
# 9995                 Coriza, Dor de Cabeça, Febre, Outros
# 9996                               Febre, Dor de Garganta
# 9997               Dor de Cabeça, Tosse, Dispneia, Coriza
# 9998                  Coriza, Dor de Cabeça, Tosse, Febre
# 9999                         Dor de Cabeça, Tosse, Outros
# Name: _source.sintomas, Length: 10000, dtype: object

# %%
# Separar os valores da coluna 'sintomas' usando regex
df_bra['_source.sintomas'] = df_bra['_source.sintomas'].str.split(r',\s|,')

# Transformar a coluna em uma coluna de lista e separá-la em múltiplas linhas
df_bra = df_bra.explode('_source.sintomas')

# %%
df_bra['_source.sintomas'].value_counts()
# Out:
# Tosse                    4619
# Coriza                   3753
# Dor de Cabeça            3453
# Dor de Garganta          3053
# Febre                    3021
# Assintomático            2706
# Outros                   1718
# Dispneia                  736
# Distúrbios Gustativos     348
# Distúrbios Olfativos      281
# Dispineia                   9
# Name: _source.sintomas, dtype: int64

# %%
df_bra['_source.sintomas'] = df_bra['_source.sintomas'].replace({'Dispineia': 'Dispneia'})

# %%
df_bra['_source.sintomas'].value_counts()
# Out:
# Tosse                    4619
# Coriza                   3753
# Dor de Cabeça            3453
# Dor de Garganta          3053
# Febre                    3021
# Assintomático            2706
# Outros                   1718
# Dispneia                  745
# Distúrbios Gustativos     348
# Distúrbios Olfativos      281
# Name: _source.sintomas, dtype: int64

# %%
url = "https://elasticsearch-saps.saude.gov.br/desc-esus-notifica-estado-*/_search"

payload = json.dumps({
  "track_total_hits": True,
  "size": 0,
  "query": {
    "term": {
      "registroAtual": {
        "value": True
      }
    }
  },
  "aggs": {
    "TopTestes": {
      "terms": {
        "field": "testes.tipoTeste.keyword",
        "size": 10
      }
    }
  }
})
headers = {
  'Authorization': 'Basic dXNlci1wdWJsaWMtbm90aWZpY2Fjb2VzOlphNHFOWGR5UU5TYTlZYUE=',
  'Content-Type': 'application/json'
}

response = requests.request("POST", url, headers=headers, data=payload)

if response.status_code == 200:
    data_testes = response.json()
else:
    print(f"Erro na solicitação: {response.status_code}")

# %%
df_testes = pd.json_normalize(data_testes)
df_testes.columns
# Out:
# Index(['took', 'timed_out', '_shards.total', '_shards.successful',
#        '_shards.skipped', '_shards.failed', 'hits.total.value',
#        'hits.total.relation', 'hits.max_score', 'hits.hits',
#        'aggregations.TopTestes.doc_count_error_upper_bound',
#        'aggregations.TopTestes.sum_other_doc_count',
#        'aggregations.TopTestes.buckets'],
#       dtype='object')

# %%
df_buckets = pd.json_normalize(df_testes['aggregations.TopTestes.buckets'])
df_buckets
# Out:
#                                                    0  \
# 0  {'key': 'TESTE RÁPIDO - ANTÍGENO', 'doc_count'...
#
#                                           1  \
# 0  {'key': 'RT-PCR', 'doc_count': 39075964}
#
#                                                    2  \
# 0  {'key': 'TESTE RÁPIDO - ANTICORPO IgG', 'doc_c...
#
#                                                    3  \
# 0  {'key': 'TESTE SOROLÓGICO IgG', 'doc_count': 1...
#
#                                                    4  \
# 0  {'key': 'TESTE SOROLÓGICO IgM', 'doc_count': 1...
#
#                                                    5  \
# 0  {'key': 'TESTE RÁPIDO - ANTICORPO IgM', 'doc_c...
#
#                                                    6  \
# 0  {'key': 'ANTICORPOS TOTAIS', 'doc_count': 454055}
#
#                                         7  \
# 0  {'key': 'RT-LAMP', 'doc_count': 82828}
#
#                                                    8  \
# 0  {'key': 'Imunoensaio por Eletroquimioluminescê...
#
#                                                    9
# 0  {'key': 'Enzimaimunoensaio - ELISA IgM', 'doc_...

# %%
buckets = df_testes.at[0, 'aggregations.TopTestes.buckets']
df_buckets = pd.DataFrame(columns=['key', 'doc_count'])

for i in range(len(buckets)):
    key_valor = buckets[i]['key']
    doc_count_valor = buckets[i]['doc_count']
    df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)

print(df_buckets)
# Out:
#                                                  key doc_count
# 0                            TESTE RÁPIDO - ANTÍGENO  52458836
# 1                                             RT-PCR  39075964
# 2                       TESTE RÁPIDO - ANTICORPO IgG  18465491
# 3                               TESTE SOROLÓGICO IgG   1656347
# 4                               TESTE SOROLÓGICO IgM   1496595
# 5                       TESTE RÁPIDO - ANTICORPO IgM    804719
# 6                                  ANTICORPOS TOTAIS    454055
# 7                                            RT-LAMP     82828
# 8  Imunoensaio por Eletroquimioluminescência - EC...     61567
# 9                      Enzimaimunoensaio - ELISA IgM     47073
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_12832\484078239.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_12832\484078239.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_12832\484078239.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_12832\484078239.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_12832\484078239.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_12832\484078239.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_12832\484078239.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_12832\484078239.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_12832\484078239.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_12832\484078239.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)

# %%
import requests
import json

url = "https://elasticsearch-saps.saude.gov.br/desc-esus-notifica-estado-*/_search"

payload = json.dumps({
  "track_total_hits": True,
  "size": 0,
  "query": {
    "bool": {
      "filter": [
        {
          "range": {
            "@timestamp": {
              "gte": "2021-08-20T00:00:00Z",
              "lte": "now",
              "time_zone": "-03:00"
            }
          }
        },
        {
          "term": {
            "registroAtual": {
              "value": True
            }
          }
        }
      ]
    }
  },
  "aggs": {
    "AtualizacaoDia": {
      "date_histogram": {
        "field": "@timestamp",
        "interval": "day"
      }
    }
  }
})
headers = {
  'Authorization': 'Basic dXNlci1wdWJsaWMtbm90aWZpY2Fjb2VzOlphNHFOWGR5UU5TYTlZYUE=',
  'Content-Type': 'application/json'
}

response = requests.request("GET", url, headers=headers, data=payload)

if response.status_code == 200:
    data_dias = response.json()
else:
    print(f"Erro na solicitação: {response.status_code}")

# %%
data = json.loads(json.dumps(data_dias))
data
# Out:
# {'took': 5590,
#  'timed_out': False,
#  '_shards': {'total': 4, 'successful': 4, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 127031530, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []},
#  'aggregations': {'AtualizacaoDia': {'buckets': [{'key_as_string': '2022-11-21T00:00:00.000Z',
#      'key': 1668988800000,
#      'doc_count': 27641986},
#     {'key_as_string': '2022-11-22T00:00:00.000Z',
#      'key': 1669075200000,
#      'doc_count': 86055913},
#     {'key_as_string': '2022-11-23T00:00:00.000Z',
#      'key': 1669161600000,
#      'doc_count': 2741040},
#     {'key_as_string': '2022-11-24T00:00:00.000Z',
#      'key': 1669248000000,
#      'doc_count': 134490},
#     {'key_as_string': '2022-11-25T00:00:00.000Z',
#      'key': 1669334400000,
#      'doc_count': 154184},
#     {'key_as_string': '2022-11-26T00:00:00.000Z',
#      'key': 1669420800000,
#      'doc_count': 30006},
#     {'key_as_string': '2022-11-27T00:00:00.000Z',
#      'key': 1669507200000,
#      'doc_count': 17797},
#     {'key_as_string': '2022-11-28T00:00:00.000Z',
#      'key': 1669593600000,
#      'doc_count': 59867},
#     {'key_as_string': '2022-11-29T00:00:00.000Z',
#      'key': 1669680000000,
#      'doc_count': 95378},
#     {'key_as_string': '2022-11-30T00:00:00.000Z',
#      'key': 1669766400000,
#      'doc_count': 117983},
#     {'key_as_string': '2022-12-01T00:00:00.000Z',
#      'key': 1669852800000,
#      'doc_count': 153308},
#     {'key_as_string': '2022-12-02T00:00:00.000Z',
#      'key': 1669939200000,
#      'doc_count': 134399},
#     {'key_as_string': '2022-12-03T00:00:00.000Z',
#      'key': 1670025600000,
#      'doc_count': 42962},
#     {'key_as_string': '2022-12-04T00:00:00.000Z',
#      'key': 1670112000000,
#      'doc_count': 31742},
#     {'key_as_string': '2022-12-05T00:00:00.000Z',
#      'key': 1670198400000,
#      'doc_count': 131266},
#     {'key_as_string': '2022-12-06T00:00:00.000Z',
#      'key': 1670284800000,
#      'doc_count': 164210},
#     {'key_as_string': '2022-12-07T00:00:00.000Z',
#      'key': 1670371200000,
#      'doc_count': 171460},
#     {'key_as_string': '2022-12-08T00:00:00.000Z',
#      'key': 1670457600000,
#      'doc_count': 146189},
#     {'key_as_string': '2022-12-09T00:00:00.000Z',
#      'key': 1670544000000,
#      'doc_count': 74873},
#     {'key_as_string': '2022-12-10T00:00:00.000Z',
#      'key': 1670630400000,
#      'doc_count': 41629},
#     {'key_as_string': '2022-12-11T00:00:00.000Z',
#      'key': 1670716800000,
#      'doc_count': 25488},
#     {'key_as_string': '2022-12-12T00:00:00.000Z',
#      'key': 1670803200000,
#      'doc_count': 186987},
#     {'key_as_string': '2022-12-13T00:00:00.000Z',
#      'key': 1670889600000,
#      'doc_count': 135422},
#     {'key_as_string': '2022-12-14T00:00:00.000Z',
#      'key': 1670976000000,
#      'doc_count': 159425},
#     {'key_as_string': '2022-12-15T00:00:00.000Z',
#      'key': 1671062400000,
#      'doc_count': 180864},
#     {'key_as_string': '2022-12-16T00:00:00.000Z',
#      'key': 1671148800000,
#      'doc_count': 156660},
#     {'key_as_string': '2022-12-17T00:00:00.000Z',
#      'key': 1671235200000,
#      'doc_count': 41186},
#     {'key_as_string': '2022-12-18T00:00:00.000Z',
#      'key': 1671321600000,
#      'doc_count': 23164},
#     {'key_as_string': '2022-12-19T00:00:00.000Z',
#      'key': 1671408000000,
#      'doc_count': 173364},
#     {'key_as_string': '2022-12-20T00:00:00.000Z',
#      'key': 1671494400000,
#      'doc_count': 164033},
#     {'key_as_string': '2022-12-21T00:00:00.000Z',
#      'key': 1671580800000,
#      'doc_count': 154819},
#     {'key_as_string': '2022-12-22T00:00:00.000Z',
#      'key': 1671667200000,
#      'doc_count': 143936},
#     {'key_as_string': '2022-12-23T00:00:00.000Z',
#      'key': 1671753600000,
#      'doc_count': 99916},
#     {'key_as_string': '2022-12-24T00:00:00.000Z',
#      'key': 1671840000000,
#      'doc_count': 23603},
#     {'key_as_string': '2022-12-25T00:00:00.000Z',
#      'key': 1671926400000,
#      'doc_count': 12640},
#     {'key_as_string': '2022-12-26T00:00:00.000Z',
#      'key': 1672012800000,
#      'doc_count': 129631},
#     {'key_as_string': '2022-12-27T00:00:00.000Z',
#      'key': 1672099200000,
#      'doc_count': 152726},
#     {'key_as_string': '2022-12-28T00:00:00.000Z',
#      'key': 1672185600000,
#      'doc_count': 137105},
#     {'key_as_string': '2022-12-29T00:00:00.000Z',
#      'key': 1672272000000,
#      'doc_count': 120305},
#     {'key_as_string': '2022-12-30T00:00:00.000Z',
#      'key': 1672358400000,
#      'doc_count': 74051},
#     {'key_as_string': '2022-12-31T00:00:00.000Z',
#      'key': 1672444800000,
#      'doc_count': 19418},
#     {'key_as_string': '2023-01-01T00:00:00.000Z',
#      'key': 1672531200000,
#      'doc_count': 9527},
#     {'key_as_string': '2023-01-02T00:00:00.000Z',
#      'key': 1672617600000,
#      'doc_count': 104001},
#     {'key_as_string': '2023-01-03T00:00:00.000Z',
#      'key': 1672704000000,
#      'doc_count': 125310},
#     {'key_as_string': '2023-01-04T00:00:00.000Z',
#      'key': 1672790400000,
#      'doc_count': 129641},
#     {'key_as_string': '2023-01-05T00:00:00.000Z',
#      'key': 1672876800000,
#      'doc_count': 126486},
#     {'key_as_string': '2023-01-06T00:00:00.000Z',
#      'key': 1672963200000,
#      'doc_count': 107722},
#     {'key_as_string': '2023-01-07T00:00:00.000Z',
#      'key': 1673049600000,
#      'doc_count': 27916},
#     {'key_as_string': '2023-01-08T00:00:00.000Z',
#      'key': 1673136000000,
#      'doc_count': 15651},
#     {'key_as_string': '2023-01-09T00:00:00.000Z',
#      'key': 1673222400000,
#      'doc_count': 126757},
#     {'key_as_string': '2023-01-10T00:00:00.000Z',
#      'key': 1673308800000,
#      'doc_count': 115660},
#     {'key_as_string': '2023-01-11T00:00:00.000Z',
#      'key': 1673395200000,
#      'doc_count': 112305},
#     {'key_as_string': '2023-01-12T00:00:00.000Z',
#      'key': 1673481600000,
#      'doc_count': 106094},
#     {'key_as_string': '2023-01-13T00:00:00.000Z',
#      'key': 1673568000000,
#      'doc_count': 96981},
#     {'key_as_string': '2023-01-14T00:00:00.000Z',
#      'key': 1673654400000,
#      'doc_count': 24371},
#     {'key_as_string': '2023-01-15T00:00:00.000Z',
#      'key': 1673740800000,
#      'doc_count': 12253},
#     {'key_as_string': '2023-01-16T00:00:00.000Z',
#      'key': 1673827200000,
#      'doc_count': 106071},
#     {'key_as_string': '2023-01-17T00:00:00.000Z',
#      'key': 1673913600000,
#      'doc_count': 107655},
#     {'key_as_string': '2023-01-18T00:00:00.000Z',
#      'key': 1674000000000,
#      'doc_count': 101831},
#     {'key_as_string': '2023-01-19T00:00:00.000Z',
#      'key': 1674086400000,
#      'doc_count': 102344},
#     {'key_as_string': '2023-01-20T00:00:00.000Z',
#      'key': 1674172800000,
#      'doc_count': 89187},
#     {'key_as_string': '2023-01-21T00:00:00.000Z',
#      'key': 1674259200000,
#      'doc_count': 25280},
#     {'key_as_string': '2023-01-22T00:00:00.000Z',
#      'key': 1674345600000,
#      'doc_count': 14134},
#     {'key_as_string': '2023-01-23T00:00:00.000Z',
#      'key': 1674432000000,
#      'doc_count': 109841},
#     {'key_as_string': '2023-01-24T00:00:00.000Z',
#      'key': 1674518400000,
#      'doc_count': 99298},
#     {'key_as_string': '2023-01-25T00:00:00.000Z',
#      'key': 1674604800000,
#      'doc_count': 94207},
#     {'key_as_string': '2023-01-26T00:00:00.000Z',
#      'key': 1674691200000,
#      'doc_count': 95445},
#     {'key_as_string': '2023-01-27T00:00:00.000Z',
#      'key': 1674777600000,
#      'doc_count': 92028},
#     {'key_as_string': '2023-01-28T00:00:00.000Z',
#      'key': 1674864000000,
#      'doc_count': 26894},
#     {'key_as_string': '2023-01-29T00:00:00.000Z',
#      'key': 1674950400000,
#      'doc_count': 13416},
#     {'key_as_string': '2023-01-30T00:00:00.000Z',
#      'key': 1675036800000,
#      'doc_count': 101256},
#     {'key_as_string': '2023-01-31T00:00:00.000Z',
#      'key': 1675123200000,
#      'doc_count': 92054},
#     {'key_as_string': '2023-02-01T00:00:00.000Z',
#      'key': 1675209600000,
#      'doc_count': 92493},
#     {'key_as_string': '2023-02-02T00:00:00.000Z',
#      'key': 1675296000000,
#      'doc_count': 91390},
#     {'key_as_string': '2023-02-03T00:00:00.000Z',
#      'key': 1675382400000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-04T00:00:00.000Z',
#      'key': 1675468800000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-05T00:00:00.000Z',
#      'key': 1675555200000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-06T00:00:00.000Z',
#      'key': 1675641600000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-07T00:00:00.000Z',
#      'key': 1675728000000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-08T00:00:00.000Z',
#      'key': 1675814400000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-09T00:00:00.000Z',
#      'key': 1675900800000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-10T00:00:00.000Z',
#      'key': 1675987200000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-11T00:00:00.000Z',
#      'key': 1676073600000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-12T00:00:00.000Z',
#      'key': 1676160000000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-13T00:00:00.000Z',
#      'key': 1676246400000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-14T00:00:00.000Z',
#      'key': 1676332800000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-15T00:00:00.000Z',
#      'key': 1676419200000,
#      'doc_count': 0},
#     {'key_as_string': '2023-02-16T00:00:00.000Z',
#      'key': 1676505600000,
#      'doc_count': 80148},
#     {'key_as_string': '2023-02-17T00:00:00.000Z',
#      'key': 1676592000000,
#      'doc_count': 84479},
#     {'key_as_string': '2023-02-18T00:00:00.000Z',
#      'key': 1676678400000,
#      'doc_count': 21117},
#     {'key_as_string': '2023-02-19T00:00:00.000Z',
#      'key': 1676764800000,
#      'doc_count': 12963},
#     {'key_as_string': '2023-02-20T00:00:00.000Z',
#      'key': 1676851200000,
#      'doc_count': 22598},
#     {'key_as_string': '2023-02-21T00:00:00.000Z',
#      'key': 1676937600000,
#      'doc_count': 18448},
#     {'key_as_string': '2023-02-22T00:00:00.000Z',
#      'key': 1677024000000,
#      'doc_count': 51797},
#     {'key_as_string': '2023-02-23T00:00:00.000Z',
#      'key': 1677110400000,
#      'doc_count': 123674},
#     {'key_as_string': '2023-02-24T00:00:00.000Z',
#      'key': 1677196800000,
#      'doc_count': 110946},
#     {'key_as_string': '2023-02-25T00:00:00.000Z',
#      'key': 1677283200000,
#      'doc_count': 27419},
#     {'key_as_string': '2023-02-26T00:00:00.000Z',
#      'key': 1677369600000,
#      'doc_count': 34827},
#     {'key_as_string': '2023-02-27T00:00:00.000Z',
#      'key': 1677456000000,
#      'doc_count': 106319},
#     {'key_as_string': '2023-02-28T00:00:00.000Z',
#      'key': 1677542400000,
#      'doc_count': 113665},
#     {'key_as_string': '2023-03-01T00:00:00.000Z',
#      'key': 1677628800000,
#      'doc_count': 112168},
#     {'key_as_string': '2023-03-02T00:00:00.000Z',
#      'key': 1677715200000,
#      'doc_count': 100922},
#     {'key_as_string': '2023-03-03T00:00:00.000Z',
#      'key': 1677801600000,
#      'doc_count': 90513},
#     {'key_as_string': '2023-03-04T00:00:00.000Z',
#      'key': 1677888000000,
#      'doc_count': 39972},
#     {'key_as_string': '2023-03-05T00:00:00.000Z',
#      'key': 1677974400000,
#      'doc_count': 16047},
#     {'key_as_string': '2023-03-06T00:00:00.000Z',
#      'key': 1678060800000,
#      'doc_count': 112119},
#     {'key_as_string': '2023-03-07T00:00:00.000Z',
#      'key': 1678147200000,
#      'doc_count': 112311},
#     {'key_as_string': '2023-03-08T00:00:00.000Z',
#      'key': 1678233600000,
#      'doc_count': 90860},
#     {'key_as_string': '2023-03-09T00:00:00.000Z',
#      'key': 1678320000000,
#      'doc_count': 93636},
#     {'key_as_string': '2023-03-10T00:00:00.000Z',
#      'key': 1678406400000,
#      'doc_count': 101167},
#     {'key_as_string': '2023-03-11T00:00:00.000Z',
#      'key': 1678492800000,
#      'doc_count': 33916},
#     {'key_as_string': '2023-03-12T00:00:00.000Z',
#      'key': 1678579200000,
#      'doc_count': 14762},
#     {'key_as_string': '2023-03-13T00:00:00.000Z',
#      'key': 1678665600000,
#      'doc_count': 115898},
#     {'key_as_string': '2023-03-14T00:00:00.000Z',
#      'key': 1678752000000,
#      'doc_count': 103353},
#     {'key_as_string': '2023-03-15T00:00:00.000Z',
#      'key': 1678838400000,
#      'doc_count': 116493},
#     {'key_as_string': '2023-03-16T00:00:00.000Z',
#      'key': 1678924800000,
#      'doc_count': 109768},
#     {'key_as_string': '2023-03-17T00:00:00.000Z',
#      'key': 1679011200000,
#      'doc_count': 101537},
#     {'key_as_string': '2023-03-18T00:00:00.000Z',
#      'key': 1679097600000,
#      'doc_count': 38540},
#     {'key_as_string': '2023-03-19T00:00:00.000Z',
#      'key': 1679184000000,
#      'doc_count': 34154},
#     {'key_as_string': '2023-03-20T00:00:00.000Z',
#      'key': 1679270400000,
#      'doc_count': 105092},
#     {'key_as_string': '2023-03-21T00:00:00.000Z',
#      'key': 1679356800000,
#      'doc_count': 101027},
#     {'key_as_string': '2023-03-22T00:00:00.000Z',
#      'key': 1679443200000,
#      'doc_count': 119460},
#     {'key_as_string': '2023-03-23T00:00:00.000Z',
#      'key': 1679529600000,
#      'doc_count': 111117},
#     {'key_as_string': '2023-03-24T00:00:00.000Z',
#      'key': 1679616000000,
#      'doc_count': 92551},
#     {'key_as_string': '2023-03-25T00:00:00.000Z',
#      'key': 1679702400000,
#      'doc_count': 28511},
#     {'key_as_string': '2023-03-26T00:00:00.000Z',
#      'key': 1679788800000,
#      'doc_count': 15468},
#     {'key_as_string': '2023-03-27T00:00:00.000Z',
#      'key': 1679875200000,
#      'doc_count': 120644},
#     {'key_as_string': '2023-03-28T00:00:00.000Z',
#      'key': 1679961600000,
#      'doc_count': 115751},
#     {'key_as_string': '2023-03-29T00:00:00.000Z',
#      'key': 1680048000000,
#      'doc_count': 100798},
#     {'key_as_string': '2023-03-30T00:00:00.000Z',
#      'key': 1680134400000,
#      'doc_count': 125517},
#     {'key_as_string': '2023-03-31T00:00:00.000Z',
#      'key': 1680220800000,
#      'doc_count': 86782},
#     {'key_as_string': '2023-04-01T00:00:00.000Z',
#      'key': 1680307200000,
#      'doc_count': 36556},
#     {'key_as_string': '2023-04-02T00:00:00.000Z',
#      'key': 1680393600000,
#      'doc_count': 16603},
#     {'key_as_string': '2023-04-03T00:00:00.000Z',
#      'key': 1680480000000,
#      'doc_count': 103537},
#     {'key_as_string': '2023-04-04T00:00:00.000Z',
#      'key': 1680566400000,
#      'doc_count': 112184},
#     {'key_as_string': '2023-04-05T00:00:00.000Z',
#      'key': 1680652800000,
#      'doc_count': 100144},
#     {'key_as_string': '2023-04-06T00:00:00.000Z',
#      'key': 1680739200000,
#      'doc_count': 42328}]}}}

# %%
df_dias = pd.json_normalize(data['aggregations']['AtualizacaoDia']['buckets'])
df_dias
# Out:
#                 key_as_string            key  doc_count
# 0    2022-11-21T00:00:00.000Z  1668988800000   27641986
# 1    2022-11-22T00:00:00.000Z  1669075200000   86055913
# 2    2022-11-23T00:00:00.000Z  1669161600000    2741040
# 3    2022-11-24T00:00:00.000Z  1669248000000     134490
# 4    2022-11-25T00:00:00.000Z  1669334400000     154184
# ..                        ...            ...        ...
# 132  2023-04-02T00:00:00.000Z  1680393600000      16603
# 133  2023-04-03T00:00:00.000Z  1680480000000     103537
# 134  2023-04-04T00:00:00.000Z  1680566400000     112184
# 135  2023-04-05T00:00:00.000Z  1680652800000     100144
# 136  2023-04-06T00:00:00.000Z  1680739200000      42328
#
# [137 rows x 3 columns]

# %%
dados = []

for i in range(len(df_dias)):
    key_valor = df_dias.iloc[i]['key_as_string']
    doc_count_valor = df_dias.iloc[i]['doc_count']
    dados.append({'dia': key_valor, 'notificacoes': doc_count_valor})

# Criar um novo DataFrame a partir da lista de dicionários
df_notificacoes = pd.DataFrame(dados)

# Tratar coluna dia
df_notificacoes['dia'] = pd.to_datetime(df_notificacoes['dia'])
df_notificacoes['dia'] = df_notificacoes['dia'].dt.strftime('%d-%m-%Y')


print(df_notificacoes)
# Out:
#             dia  notificacoes
# 0    21-11-2022      27641986
# 1    22-11-2022      86055913
# 2    23-11-2022       2741040
# 3    24-11-2022        134490
# 4    25-11-2022        154184
# ..          ...           ...
# 132  02-04-2023         16603
# 133  03-04-2023        103537
# 134  04-04-2023        112184
# 135  05-04-2023        100144
# 136  06-04-2023         42328
#
# [137 rows x 2 columns]

# %%
df_notificacoes.plot(x='dia', y='notificacoes', kind='line')
# Out:
# <Axes: xlabel='dia'>
