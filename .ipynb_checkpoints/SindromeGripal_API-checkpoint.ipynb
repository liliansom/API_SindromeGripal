# %%
import requests
import pandas as pd
import json
import datetime

# %%
# Total de contagem de notificações no Brasil
url = 'https://elasticsearch-saps.saude.gov.br/desc-esus-notifica-estado-*/_count'
auth = ('user-public-notificacoes', 'Za4qNXdyQNSa9YaA')

response = requests.get(url, auth=auth)

if response.status_code == 200:
    data_br = response.json()
else:
    print(f"Erro na solicitação: {response.status_code}")

# %%
data_br = pd.json_normalize(data_br)

# %%
print(f"O total de notificações no Brasil é de {data_br['count'][0]}.")
# Out:
# O total de notificações no Brasil é de 127314921.

# %%
# Total de contagem de notificações no Brasil
url = 'https://elasticsearch-saps.saude.gov.br/desc-esus-notifica-estado-sp/_count'
auth = ('user-public-notificacoes', 'Za4qNXdyQNSa9YaA')

response = requests.get(url, auth=auth)

if response.status_code == 200:
    data_sp = response.json()
else:
    print(f"Erro na solicitação: {response.status_code}")

# %%
data_sp = pd.json_normalize(data_sp)
print(f"O total de notificações no estado de São Paulo é de {data_sp['count'][0]}.")
# Out:
# O total de notificações no estado de São Paulo é de 37171000.

# %%
import requests
import json

url = "https://elasticsearch-saps.saude.gov.br/desc-esus-notifica-estado-*/_search?scroll=1m"

payload = json.dumps({
  "size": 10000,
  "_source": [
    "sintomas"
  ],
  "query": {
    "bool": {
      "filter": {
        "exists": {
          "field": "sintomas"
        }
      }
    }
  }
})
headers = {
  'Authorization': 'Basic dXNlci1wdWJsaWMtbm90aWZpY2Fjb2VzOlphNHFOWGR5UU5TYTlZYUE=',
  'Content-Type': 'application/json'
}

response = requests.request("POST", url, headers=headers, data=payload)

if response.status_code == 200:
    data_bra = response.json()
else:
    print(f"Erro na solicitação: {response.status_code}")

# %%
data_bra
# Out:
# {'_scroll_id': '',
#  'took': 4237,
#  'timed_out': False,
#  '_shards': {'total': 4, 'successful': 4, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 127145923, 'relation': 'eq'},
#   'max_score': 0.0,
#   'hits': [{'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'tSFTwaUTX8',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'jfYhQ0FWnl',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'zLNPXeggLg',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Tosse, Dispneia, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'MOgFVsCA2m',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Dor de Garganta, Coriza'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'XiCg5uWMJw',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'JhoPtHMV3G',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Dispneia, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'e19FYfdykc',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Distúrbios Gustativos, Tosse, Dor de Garganta, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'sdhhp4uDJQ',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Dispneia'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'TY9WCjGzLW',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'nRDLhjQjOH',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'xAG97X6eGe',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Garganta, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'ApEuzHA9JN',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Tosse, Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'fAD8rX0KfK',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'N3kaDq3Drg',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Garganta, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'Z7gqfsCnIK',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse, Dor de Garganta, Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'WOCStaIagK',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'OAqleuj3KF',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'dtSGewMep0',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Distúrbios Gustativos, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'Xkee38RJ6G',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '9O2rCuDSmV',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'kpDu3XIqau',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Febre, Coriza'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'WG5x9tVAHe',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Febre, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'u0mASw6gBA',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'sc9iE6lZnZ',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '1PFgIkzWAe',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Tosse, Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'kBLfhV8wC7',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'esBCDHS5un',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'wSCAcBTbQe',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'Kp7Y1G5QZx',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Tosse, Febre, Dispneia'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'r8yWwvry7D',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'vizBivgCAU',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'o76dB6oCxd',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Garganta, Dispneia'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'lCZnsZToMq',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'QNfvuNLg0k',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'iN9Aa07dzy',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Dispneia, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'iapnc1Ezex',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'TsgrTEv52S',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'GNlRRHRABR',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'fKWWr9CYEp',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'lKETSND9aw',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'l8qtiYFI0y',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '6K0nPjXSUV',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'fWhBP7t0de',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'ylFhkoIqYT',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Tosse, Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'QcjSxV8Lw4',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Febre, Coriza'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'JxpPwUno43',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'DoQ6OSHWka',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '4Vfl8iv8e9',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Outros, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'TvrD5skdh9',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Distúrbios Olfativos, Distúrbios Gustativos, Dor de Cabeça, Febre, Dispneia'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'FdmXtGpGDt',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'XwxpuNbbit',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'PLG6URAzhq',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'BRCWGTL9Ys',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'BNgznTRVtY',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Febre, Coriza'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'BCBdB3sjWc',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'OBCICqAqS2',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'MssCITYSwk',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'HNVCaMeEO3',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Garganta, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'luJQgBBg1H',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Febre, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'e5phVsZCgS',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'fBYyD9a3p3',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Tosse, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'KpJg94vUPl',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Tosse, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'Q7qkcC7cIK',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse, Dispneia, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'DxEmN8M0e9',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Febre, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'uMvV8dEDpw',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'zVMzAy064R',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Tosse, Febre, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '01FvY50TWA',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'GhzbepIQPR',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Febre, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'TzwLJPgkTE',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'stcyfEMFyN',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Febre, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'CPRxtH9x0H',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Dor de Garganta, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'shqFTJW9fe',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'CYSCMfiJX4',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'o8AuINzCRV',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '1gpLaHLBAw',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'GZdXOB2Tks',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Febre, Dispneia'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'SpdFZWA7It',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'bIbOZgR8Bg',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '6NGeDlVBMj',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'XCaY9SFQlb',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'QsSdoBLrfn',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Tosse, Coriza'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'ynRuGUtbNK',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Distúrbios Gustativos, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'EwvI9yCaYL',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Tosse, Dor de Garganta'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'kNfMoeCh7i',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Assintomático'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'tqvYjRmPEN',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'NOE8ijLjea',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Tosse, Dor de Garganta, Dor de Cabeça'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'sATGw3VOgR',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dor de Cabeça, Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'kIjnUnFrgb',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse, Outros'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'Q3ULyZuCZz',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Dispneia'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': 'CTWYnJqE2W',
#     '_score': 0.0,
#     '_source': {'sintomas': 'Outros, Febre'}},
#    {'_index': 'desc-esusve_v8',
#     '_type': '_doc',
#     '_id': '

#   '_score': 0.0,
#   '_source': {'sintomas': 'Febre, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'fXxYvCOp9f',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Dor de Garganta, Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'CEYmon9qkd',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Dor de Garganta, Coriza'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'BDJeZ3rkRV',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'l8hXYe8qNP',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'e5zE5GKPtp',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'GuLLxpHnUS',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Garganta, Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'spYPdFLG8m',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'Kv6LwKAGsp',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Dor de Cabeça, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'r6VrtY2TS4',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Distúrbios Olfativos, Dor de Cabeça, Tosse, Febre, Dispneia, Dor de Garganta, Distúrbios Gustativos'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'Ne6tIAFNOs',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '0oDAIEUaVq',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'dixNQa4r68',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Tosse, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'epgxUvt6Cb',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Tosse, Dispneia, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '7tXoUCCSdF',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Febre, Outros, Dispneia'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '0f6QN9mKbF',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'DwL0tOJkwn',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'YERn4JAGHs',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Dor de Garganta, Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'XVg3Cplgvp',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'EBZTbQ8j0Y',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'FbeLMHO46E',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Tosse, Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'YSSwivFbU2',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse, Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'ZzVcXviKeA',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'XYhjfl3TSD',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'WYz29bSNGs',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Garganta, Coriza'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'tTPdP3LAnr',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'wK8ZFFPbim',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'sO3HxsAI87',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Dor de Garganta, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'htoBdDjVrL',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Garganta, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'gG7FE3K70I',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Febre, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'G70iZXacwm',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Febre, Dor de Garganta, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'oY2D5xWStd',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Tosse, Febre, Dispneia'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'xgInwERugc',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Garganta, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'g9KITQnRhw',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse, Dor de Garganta, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'nsuXLL4zjU',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '8YYUMryYjO',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'YlIfeoBzos',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Garganta, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'AjyfFmRAKt',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'dcZGoNZbGv',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Tosse, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'PHuc0wKFXc',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'cBbsWPKNqH',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'S9czK9P4W1',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'AxKZFHTb73',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'S0SHEFika9',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Tosse, Febre, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'zeDtEsMivI',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Dor de Garganta, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'NLXgdgsALL',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'MTOXeK5yVA',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'JB9r0BWgcL',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Febre, Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'McUp7jfkmf',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'pUeOqeRc34',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '7rQGV4rotv',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Dispneia, Distúrbios Olfativos'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'yjVijKyQuR',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'JPTIrSNDoA',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'CrgSkYQFum',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'M6dx90H13n',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Tosse, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '37jE6tPNcU',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Dor de Garganta, Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'OZGVER0xGD',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Distúrbios Olfativos, Distúrbios Gustativos, Dispneia, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'ZyHAHQBAR2',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'UNKxlOKS4K',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Febre, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'MQGw6cc7xv',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Febre, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'eLvr1OvSL7',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dispneia, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'SqKkNPZcIn',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'H4JhTHDBB6',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'OrJurNZzKj',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '6UPGUtvQ0Q',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'c56kekghnC',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Coriza'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'FPtj5otduF',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '7ETs4k3A3e',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Tosse, Dor de Garganta, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'A0Aqq19FP4',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Coriza'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'Z1gAyMRzHJ',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Febre, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'WQEoBLeb61',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Outros'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'S47XAMInlS',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'J7MuhRn1As',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'qsqrC6hsPU',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Tosse, Dor de Garganta, Febre'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'C5IjNTt53J',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'F9EJXvoQqR',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Tosse, Febre, Dor de Garganta, Dor de Cabeça'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'xTcAQvTse6',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'yczDOGWUSA',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Distúrbios Olfativos, Dor de Cabeça, Dor de Garganta'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': '4g5fD7lKNw',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Assintomático'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'zOTs8T8aXL',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Coriza, Dor de Cabeça, Febre, Dor de Garganta, Tosse'}},
#  {'_index': 'desc-esusve_v8',
#   '_type': '_doc',
#   '_id': 'unpgEjACcl',
#   '_score': 0.0,
#   '_source': {'sintomas': 'Dor de Cabeça, Dor de Garganta, Febre'}},
#  ...]

# %%
df_bra = pd.json_normalize(data_bra['hits']['hits'])

# %%
df_bra.columns
# Out:
# Index(['_index', '_type', '_id', '_score', '_source.sintomas'], dtype='object')

# %%
df_bra['_source.sintomas']
# Out:
# 0               Coriza, Tosse, Dor de Garganta
# 1               Dor de Cabeça, Dor de Garganta
# 2       Dor de Cabeça, Tosse, Dispneia, Outros
# 3               Tosse, Dor de Garganta, Coriza
# 4                               Coriza, Outros
#                          ...
# 9995                             Assintomático
# 9996                      Tosse, Febre, Coriza
# 9997              Coriza, Tosse, Dor de Cabeça
# 9998                             Assintomático
# 9999                             Dor de Cabeça
# Name: _source.sintomas, Length: 10000, dtype: object

# %%
# Separar os valores da coluna 'sintomas' usando regex
df_bra['_source.sintomas'] = df_bra['_source.sintomas'].str.split(r',\s|,')

# Transformar a coluna em uma coluna de lista e separá-la em múltiplas linhas
df_bra = df_bra.explode('_source.sintomas')

# %%
df_bra['_source.sintomas'].value_counts()
# Out:
# Tosse                    5016
# Coriza                   4017
# Dor de Cabeça            3741
# Dor de Garganta          3412
# Febre                    3333
# Outros                   2012
# Assintomático            1939
# Dispneia                  781
# Distúrbios Gustativos     331
# Distúrbios Olfativos      283
# Dispineia                   2
# Name: _source.sintomas, dtype: int64

# %%
df_bra['_source.sintomas'] = df_bra['_source.sintomas'].replace({'Dispineia': 'Dispneia'})

# %%
df_bra['_source.sintomas'].value_counts()
# Out:
# Tosse                    5016
# Coriza                   4017
# Dor de Cabeça            3741
# Dor de Garganta          3412
# Febre                    3333
# Outros                   2012
# Assintomático            1939
# Dispneia                  783
# Distúrbios Gustativos     331
# Distúrbios Olfativos      283
# Name: _source.sintomas, dtype: int64

# %%
url = "https://elasticsearch-saps.saude.gov.br/desc-esus-notifica-estado-*/_search"

payload = json.dumps({
  "track_total_hits": True,
  "size": 0,
  "query": {
    "term": {
      "registroAtual": {
        "value": True
      }
    }
  },
  "aggs": {
    "TopTestes": {
      "terms": {
        "field": "testes.tipoTeste.keyword",
        "size": 10
      }
    }
  }
})
headers = {
  'Authorization': 'Basic dXNlci1wdWJsaWMtbm90aWZpY2Fjb2VzOlphNHFOWGR5UU5TYTlZYUE=',
  'Content-Type': 'application/json'
}

response = requests.request("POST", url, headers=headers, data=payload)

if response.status_code == 200:
    data_testes = response.json()
else:
    print(f"Erro na solicitação: {response.status_code}")

# %%
df_testes = pd.json_normalize(data_testes)
df_testes.columns
# Out:
# Index(['took', 'timed_out', '_shards.total', '_shards.successful',
#        '_shards.skipped', '_shards.failed', 'hits.total.value',
#        'hits.total.relation', 'hits.max_score', 'hits.hits',
#        'aggregations.TopTestes.doc_count_error_upper_bound',
#        'aggregations.TopTestes.sum_other_doc_count',
#        'aggregations.TopTestes.buckets'],
#       dtype='object')

# %%
df_buckets = pd.json_normalize(df_testes['aggregations.TopTestes.buckets'])
df_buckets
# Out:
#                                                    0  \
# 0  {'key': 'TESTE RÁPIDO - ANTÍGENO', 'doc_count'...
#
#                                           1  \
# 0  {'key': 'RT-PCR', 'doc_count': 39074208}
#
#                                                    2  \
# 0  {'key': 'TESTE RÁPIDO - ANTICORPO IgG', 'doc_c...
#
#                                                    3  \
# 0  {'key': 'TESTE SOROLÓGICO IgG', 'doc_count': 1...
#
#                                                    4  \
# 0  {'key': 'TESTE SOROLÓGICO IgM', 'doc_count': 1...
#
#                                                    5  \
# 0  {'key': 'TESTE RÁPIDO - ANTICORPO IgM', 'doc_c...
#
#                                                    6  \
# 0  {'key': 'ANTICORPOS TOTAIS', 'doc_count': 454041}
#
#                                         7  \
# 0  {'key': 'RT-LAMP', 'doc_count': 82798}
#
#                                                    8  \
# 0  {'key': 'Imunoensaio por Eletroquimioluminescê...
#
#                                                    9
# 0  {'key': 'Enzimaimunoensaio - ELISA IgM', 'doc_...

# %%
primeiro_dict = df_buckets.iloc[0,4]
primeiro_dict
# Out:
# {'key': 'TESTE SOROLÓGICO IgM', 'doc_count': 1496594}

# %%
buckets = df_testes.at[0, 'aggregations.TopTestes.buckets']
df_buckets = pd.DataFrame(columns=['key', 'doc_count'])

for i in range(len(buckets)):
    key_valor = buckets[i]['key']
    doc_count_valor = buckets[i]['doc_count']
    df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)

print(df_buckets)
# Out:
#                                                  key doc_count
# 0                            TESTE RÁPIDO - ANTÍGENO  52441397
# 1                                             RT-PCR  39074208
# 2                       TESTE RÁPIDO - ANTICORPO IgG  18465476
# 3                               TESTE SOROLÓGICO IgG   1656344
# 4                               TESTE SOROLÓGICO IgM   1496594
# 5                       TESTE RÁPIDO - ANTICORPO IgM    804624
# 6                                  ANTICORPOS TOTAIS    454041
# 7                                            RT-LAMP     82798
# 8  Imunoensaio por Eletroquimioluminescência - EC...     61567
# 9                      Enzimaimunoensaio - ELISA IgM     47073
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_5612\484078239.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_5612\484078239.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_5612\484078239.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_5612\484078239.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_5612\484078239.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_5612\484078239.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_5612\484078239.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_5612\484078239.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_5612\484078239.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_5612\484078239.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_buckets = df_buckets.append({'key': key_valor, 'doc_count': doc_count_valor}, ignore_index=True)

# %%
#Exemplo manual

# %%
data_dia

# %%
df_dia = pd.json_normalize(data_dia)

# %%
df_dia.columns

# %%
buckets = df_dia.at[0, 'aggregations.AtualizacaoDia.buckets']
buckets
